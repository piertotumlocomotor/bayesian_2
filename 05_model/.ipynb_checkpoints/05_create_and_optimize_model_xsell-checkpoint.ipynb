# %% [markdown]
# ### prueba de parametros skopt

# %% [markdown]
# ### 0. Load Kedro context:
# - This is only necessary to run a notebook within a Kedro project, not needed in production code when running nodes/pipelines

# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")
from re import search
import random
from aa_engine_pkg.assets.utils import *
from aa_engine_pkg.assets.core.data.kedro.catalog_expansion.partitioned_sql import SQLPartitionedDataSet
from sklearn import model_selection
from functools import partial
from skopt import space
from skopt import gp_minimize
# Out:
# ---------------------------------------------------------------------------
# KedroContextError                         Traceback (most recent call last)
# <ipython-input-1-759b03a59853> in <module>
#       7 current_dir = Path.cwd()
#       8 proj_path = current_dir.parent.parent
# ----> 9 context = load_context(proj_path)
#      10 catalog = context.catalog
#      11 credentials = context.config_loader.get("credentials*","credentials*/**")
#
# /u01/miniconda3/envs/uypo37/lib/python3.7/site-packages/kedro/framework/context/context.py in load_context(project_path, **kwargs)
#     947     """
#     948     project_path = Path(project_path).expanduser().resolve()
# --> 949     static_data = get_static_project_data(project_path)
#     950
#     951     source_dir = static_data["source_dir"]
#
# /u01/miniconda3/envs/uypo37/lib/python3.7/site-packages/kedro/framework/context/context.py in get_static_project_data(project_path)
#     821         configs = ", ".join(KEDRO_CONFIGS)
#     822         raise KedroContextError(
# --> 823             f"Could not find any of configuration files '{configs}' in {project_path}. "
#     824             f"If you have created your project with Kedro "
#     825             f"version <0.15.0, make sure to update your project template. "
#
# KedroContextError: Could not find any of configuration files '.kedro.yml, pyproject.toml' in /u01/share/cesar. If you have created your project with Kedro version <0.15.0, make sure to update your project template. See https://github.com/quantumblacklabs/kedro/blob/master/RELEASE.md#migration-guide-from-kedro-014-to-kedro-0150 for how to migrate your Kedro project.

# %%
context

# %%
# -------------------------------- UPSELL MODEL --------------------------------
# Using temporal division
# Initialize logger
log = initialize_logger()
log.info(f"[TRAIN_MODEL] Creating model...")

# Loading parameters
model = "retention"
model_type = "binary"
if model == "":
    model = parameters["models"]["model"]
if model_type == "":
    model = parameters["models"][model]["model_type"]
model_path = parameters["paths"]["model_path"]
n_threads = parameters["models"]["n_threads"]

random_time=False
downsample=False
# Out:
# 2020-11-26 18:07:12,022 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Creating model...

# %%
train_periods = parameters["models"][model][model_type]["train_periods"]
dev_periods = parameters["models"][model][model_type]["dev_periods"]
test_periods = parameters["models"][model][model_type]["test_periods"]
id_vars = parameters["models"][model][model_type]["id_vars"]
period_vars = parameters["models"][model][model_type]["period_vars"]
target_var = parameters["models"][model][model_type]["target_var"]
score_var = parameters["models"][model][model_type]["score_var"]
load_subsample = parameters["models"][model][model_type]["load_subsample"]
fill_na_with = parameters["models"][model][model_type]["fill_na_with"]

# %%
test_periods
# Out:
# ['20200629', '20200727']

# %%
if type(fill_na_with) == str:
    fill_na_with = eval(fill_na_with)

# Join periods
model_periods = list(np.unique(train_periods + dev_periods))
if len(model_periods) < (len(train_periods) + len(dev_periods)):
    log.warning(f"Validation periods and train periods overlap")

# Set maximum number of threads
os.environ["NUMEXPR_MAX_THREADS"] = str(n_threads)

# %% [markdown]
# ### 1. Random periods and downsample

# %%
#Random periods
if random_time == True:
    random.seed(4)
    l=train_periods+dev_periods+test_periods
    ix=list(range(len(l)-1))
    sampled_list = random.sample(ix, int(0.8*len(ix)))
    train_list = [l[i] for i in sampled_list ] 
    test_list = [l[i] for i in ix if i not in sampled_list ] 
else:
    train_list=train_periods+dev_periods
    test_list=test_periods
    
print(f"----------- train periods -------------")
print(f"{train_list}")
print(f"----------- test periods -------------")
print(f"{test_list}")
# Out:
# ----------- train periods -------------
# ['20190114', '20190211', '20190311', '20190408', '20190506', '20190603', '20190701', '20190729', '20190826', '20190923', '20191021', '20191118', '20191216', '20200113', '20200210', '20200309', '20200406', '20200504', '20200601']
# ----------- test periods -------------
# ['20200629', '20200727']

# %%
test_list
# Out:
# ['20200629', '20200727']

# %%
#Downsample
ratio_noevents_vs_events=4
if downsample==True:
    random.seed(4)
    df_all = load_and_merge_tables(model=model,
                                     model_type=model_type,
                                     periods=train_list+test_list,
                                     parameters=parameters,
                                     load_subsample=load_subsample,
                                     load_target=True)
    df_all.reset_index(drop=True,inplace=True)
    df_down_sample=[]
    for date in df_all.DATE_CALC.unique():
        if date not in test_list:
            idx_target=df_all.loc[(df_all.TARGET==1) & (df_all.DATE_CALC==date)].index
            n_target=df_all.loc[(df_all.TARGET==1) & (df_all.DATE_CALC==date)].shape[0]

            idx_no_target=df_all.loc[(df_all.TARGET==0) & (df_all.DATE_CALC==date)].index
            n_no_target=df_all.loc[(df_all.TARGET==0) & (df_all.DATE_CALC==date)].shape[0]
            
            n=np.where(n_target*ratio_noevents_vs_events<n_no_target,n_target*ratio_noevents_vs_events,n_no_target)

            random_indices = np.random.choice( idx_no_target, n , replace=False)
            down_sample_indices = np.concatenate([idx_target,random_indices])
            aux=df_all.loc[down_sample_indices].copy()
            
            print(f"ratio 1/0 {date}: { np.round(aux.TARGET.mean(),2) }")
            df_down_sample.append(aux)

        df_down=pd.concat(df_down_sample)
        df_train=df_down.loc[df_down.DATE_CALC.isin(train_list)].copy()
        
    df_test=df_all.loc[df_all.DATE_CALC.isin(test_list)].copy()
else:
    print("-----------No downsample ------------------")
    # Load datasets
    df_train = load_and_merge_tables(model=model,
                                     model_type=model_type,
                                     periods=train_list,
                                     parameters=parameters,
                                     load_subsample=load_subsample,
                                     load_target=True)
    print(f"ratio 1/0 {df_train.groupby('DATE_CALC').agg({'TARGET':'mean'})}")
    df_test = load_and_merge_tables(model=model,
                                    model_type=model_type,
                                    periods=test_list,
                                    parameters=parameters,
                                    load_subsample=False,
                                    load_target=True)

print(f"ratio 1/0 {df_test.groupby('DATE_CALC').agg({'TARGET':'mean'})}")
# Out:
# -----------No downsample ------------------
# 2020-11-26 18:07:18,113 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190114
# 2020-11-26 18:07:18,822 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190211
# 2020-11-26 18:07:19,547 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190311
# 2020-11-26 18:07:20,302 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190408
# 2020-11-26 18:07:21,080 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190506
# 2020-11-26 18:07:21,920 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190603
# 2020-11-26 18:07:22,678 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190701
# 2020-11-26 18:07:23,414 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190729
# 2020-11-26 18:07:24,152 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190826
# 2020-11-26 18:07:24,981 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190923
# 2020-11-26 18:07:25,811 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20191021
# 2020-11-26 18:07:26,622 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20191118
# 2020-11-26 18:07:27,461 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20191216
# 2020-11-26 18:07:28,204 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200113
# 2020-11-26 18:07:28,973 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200210
# 2020-11-26 18:07:29,728 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200309
# 2020-11-26 18:07:30,477 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200406
# 2020-11-26 18:07:31,392 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200504
# 2020-11-26 18:07:32,158 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200601
# ratio 1/0              TARGET
# DATE_CALC
# 20190114   0.133481
# 20190211   0.156356
# 20190311   0.130650
# 20190408   0.140543
# 20190506   0.132832
# 20190603   0.110148
# 20190701   0.158028
# 20190729   0.147879
# 20190826   0.159325
# 20190923   0.159911
# 20191021   0.134913
# 20191118   0.119049
# 20191216   0.116710
# 20200113   0.113209
# 20200210   0.090072
# 20200309   0.053421
# 20200406   0.071140
# 20200504   0.062572
# 20200601   0.066082
# 2020-11-26 18:07:35,788 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200629
# 2020-11-26 18:07:36,619 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200727
# ratio 1/0              TARGET
# DATE_CALC
# 20200629   0.077933
# 20200727   0.220116

# %%
df_test.groupby("DATE_CALC").TARGET.sum()
# Out:
# DATE_CALC
# 20200629    1354
# 20200727    3773
# Name: TARGET, dtype: int32

# %% [markdown]
# ### 2. Split

# %%
# Split train and dev sets
X_train, X_dev, y_train, y_dev = model_pipeline.create_train_test_datasets(df_train, df_train[target_var], test_size=0.2)
df_train = X_train
df_train[target_var] = y_train
df_dev = X_dev
df_dev[target_var] = y_dev
del X_train, y_train, X_dev, y_dev; gc.collect()

if model_type == "binary":
    for df, name in zip([df_train, df_dev, df_test], ["TRAIN", "DEV", "TEST"]):
        log.info(f"{name}:")
        log.info(pd.crosstab(df["DATE_CALC"], df["TARGET"]).reset_index().apply(lambda x: x[1] / (x[1] + x[0]),axis=1))
            
elif model_type == "multiclass":
    for df, name in zip([df_train, df_dev, df_test], ["TRAIN", "DEV", "TEST"]):
        for idx, cat in enumerate(df[target_var].unique()):
            log.info(f"{name}:")
            log.info(f"{cat}:")
            log.info(pd.crosstab(df["DATE_CALC"], df[target_var]).apply(lambda x: x[idx] / (x[0] + x[1] + x[2]), axis=1))

# Exclude vars
vars_to_exclude = []
num_vars = df_train.select_dtypes(include=[np.number]).columns.tolist()

# Select vars to use for training
vars_to_model = list(set(num_vars) - set(id_vars + period_vars + [target_var] + vars_to_exclude))

del df; gc.collect()

df_dev = add_selected_variables(df_dev, vars_to_model, fill_na_with)
df_test = add_selected_variables(df_test, vars_to_model, fill_na_with)
# Out:
# 2020-11-26 18:07:39,141 - aa_engine_pkg.assets.utils.utilities - INFO - TRAIN:
# 2020-11-26 18:07:39,181 - aa_engine_pkg.assets.utils.utilities - INFO - 0     0.133570
# 1     0.158412
# 2     0.131328
# 3     0.140780
# 4     0.131936
# 5     0.107409
# 6     0.155888
# 7     0.148059
# 8     0.156457
# 9     0.159922
# 10    0.133427
# 11    0.119016
# 12    0.117997
# 13    0.114954
# 14    0.089037
# 15    0.053293
# 16    0.072233
# 17    0.062564
# 18    0.066859
# dtype: float64
# 2020-11-26 18:07:39,184 - aa_engine_pkg.assets.utils.utilities - INFO - DEV:
# 2020-11-26 18:07:39,205 - aa_engine_pkg.assets.utils.utilities - INFO - 0     0.133128
# 1     0.147971
# 2     0.127934
# 3     0.139596
# 4     0.136380
# 5     0.121787
# 6     0.166527
# 7     0.147167
# 8     0.170220
# 9     0.159870
# 10    0.140835
# 11    0.119185
# 12    0.111552
# 13    0.106277
# 14    0.094205
# 15    0.053913
# 16    0.066636
# 17    0.062607
# 18    0.062872
# dtype: float64
# 2020-11-26 18:07:39,208 - aa_engine_pkg.assets.utils.utilities - INFO - TEST:
# 2020-11-26 18:07:39,227 - aa_engine_pkg.assets.utils.utilities - INFO - 0    0.077933
# 1    0.220116
# dtype: float64
# [] not found in df
# ['EVE_CAT_COMBINED_123_3_nansum_14', 'EVE_CAT_COMBINED_100133_5_nansum_14', 'EVE_CAT_COMBINED_123_3_nansum_168', 'EVE_CAT_COMBINED_100133_3_nansum_14', 'EVE_CAT_COMBINED_100133_3_nansum_336', 'EVE_CAT_COMBINED_123_3_nansum_336', 'EVE_CAT_COMBINED_100133_OTHER_nansum_336', 'EVE_CAT_COMBINED_123_3_nansum_84', 'MAN_SUBSTYPENAME_ID_D_nansum_28', 'EVE_CAT_COMBINED_100133_OTHER_nansum_28', 'EVE_CAT_COMBINED_100133_1_nansum_28', 'EVE_CAT_COMBINED_100133_5_nansum_336', 'EVE_CAT_COMBINED_100133_OTHER_nansum_84', 'EVE_CAT_COMBINED_100133_5_nansum_28', 'EVE_CAT_COMBINED_100133_3_nansum_28', 'MAN_SUBSTYPENAME_ID_D_nansum_14', 'MAN_SUBSTYPENAME_ID_D_nansum_84', 'EVE_CAT_COMBINED_100133_1_nansum_14', 'EVE_CAT_COMBINED_100133_5_nansum_84', 'MAN_SUBSTYPENAME_ID_D_nansum_168', 'EVE_CAT_COMBINED_123_3_nansum_252', 'EVE_CAT_COMBINED_100133_1_nansum_84', 'EVE_CAT_COMBINED_100133_OTHER_nansum_252', 'EVE_CAT_COMBINED_100133_OTHER_nansum_14', 'EVE_CAT_COMBINED_100133_OTHER_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_252', 'EVE_CAT_COMBINED_100133_3_nansum_84', 'EVE_CAT_COMBINED_100133_1_nansum_21', 'EVE_CAT_COMBINED_100133_3_nansum_168', 'EVE_CAT_COMBINED_100133_5_nansum_21', 'EVE_CAT_COMBINED_100133_5_nansum_168', 'EVE_CAT_COMBINED_100133_3_nansum_21', 'EVE_CAT_COMBINED_100133_1_nansum_336', 'EVE_CAT_COMBINED_100133_5_nansum_252', 'EVE_CAT_COMBINED_123_3_nansum_21', 'EVE_CAT_COMBINED_100133_3_nansum_252', 'EVE_CAT_COMBINED_100133_1_nansum_168', 'EVE_CAT_COMBINED_123_3_nansum_28', 'EVE_CAT_COMBINED_100133_OTHER_nansum_21'] not found in df

# %%
# LGB datasets
if model_type == "multiclass":
    xlgb_train = lgbm.Dataset(df_train[vars_to_model], label=df_train[target_var].cat.codes)
    xlgb_dev = lgbm.Dataset(df_dev[vars_to_model], label=df_dev[target_var].cat.codes)
elif model_type == "binary":
    xlgb_train = lgbm.Dataset(df_train[vars_to_model], label=df_train[target_var])
    xlgb_dev = lgbm.Dataset(df_dev[vars_to_model], label=df_dev[target_var])
valid_sets = [xlgb_train, xlgb_dev]
log.info(f"[TRAIN_MODEL] Training model")
# Out:
# 2020-11-26 18:07:40,386 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model

# %% [markdown]
# ### 3. Using Bayesian Optimization
#
# keaggle example: [link1](https://www.kaggle.com/a31314431/bayesian-optimization-lightgbm)
#
#
# youtube: [link2](https://www.youtube.com/watch?v=5nYqK-HaoKY)

# %% [markdown]
# ### 3.1 check params [link](https://colab.research.google.com/github/lmassaron/kaggledays-2019-gbdt/blob/master/Kaggle%20Days%20Paris%20-%20%20GBDT%20workshop.ipynb#scrollTo=dJI3_YbYVzBb)

# %%
#List of search space dimensions
param_space=[
#     space.Categorical(["goss","gbdt"], name='boosting_type'),
     space.Categorical(["gbdt"], name='boosting_type'),
     space.Real(10**-2, 10**0, "log-uniform", name='learning_rate'),
     space.Integer(3,7,prior="uniform",name="feature_fraction"),
     space.Integer(3,7,prior="uniform",name="bagging_fraction"),
     space.Integer(3,15,name="num_leaves"),
     space.Integer(3,10,name="min_child_weight"),
 ]

# %% [markdown]
# #### self-defined eval metric
# #### Precision-Recall Curves and AUC
# Precision is a metric that quantifies the number of correct positive predictions made.
# It is calculated as the number of true positives divided by the total number of true positives and false positives.
# Recall is a metric that quantifies the number of correct positive predictions made out of all positive predictions that could have been made.
# Both the precision and the recall are focused on the positive class (the minority class) and are unconcerned with the true negatives (majority class).
# [check](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-imbalanced-classification/#:~:text=The%20Precision%2DRecall%20AUC%20is,a%20model%20with%20perfect%20skill)

# %%
# self-defined eval metric
# f(preds: array, train_data: Dataset) -> name: string, eval_result: float, is_higher_better: bool
# binary error
# NOTE: when you do customized loss function, the default prediction value is margin
# This may make built-in evalution metric calculate wrong results
# For example, we are doing log likelihood loss, the prediction is score before logistic transformation
# Keep this in mind when you use the customization
def f_pr_auc(probas_pred, y_true):
    probas_pred=1. / (1. + np.exp(-probas_pred))
    labels=y_true.get_label()
    p, r, _ = skmetrics.precision_recall_curve(labels, probas_pred)
    score=skmetrics.auc(r,p)
    return "pr_auc", score, True

# %%
def var_to_minimize(param):
    
    model_params= {
    "boosting_type": param[0],
    "objective": "binary",
    "metric": ["auc"],
    "seed": 9520,
    "learning_rate": param[1],
    "feature_fraction": param[2]/10,
    "bagging_fraction": param[3]/10,
    "num_leaves": param[4],
    "min_child_weight": param[5],
    "num_threads": n_threads}
    
    log.info(f"[TRAIN_MODEL] Training model")
    print('\nNext set of params.....',model_params)
    
    eval_results = {}
    cb_evaluation = lgbm.record_evaluation(eval_results)
    # Train model
    lgbmodel = lgbm.train(model_params,
                          xlgb_train,
                          valid_sets=valid_sets,
                          #feval =f_pr_auc,
                          early_stopping_rounds=10,
                          verbose_eval=False,
                          num_boost_round=500,
                          callbacks=[cb_evaluation])
    
    preds=lgbmodel.predict(df_test[vars_to_model])
    metric=skmetrics.roc_auc_score(df_test[target_var], preds)
    
    p, r, _=skmetrics.precision_recall_curve(df_test[target_var], preds)
    pr_auc=skmetrics.auc(r,p)
    
   
    print(f"auc roc: {np.round(metric,4)} | auc pr: {np.round(pr_auc,4)} | ratio of the test set {np.round(df_test.TARGET.mean(),4)} | iteration: {lgbmodel.current_iteration()}")
    return -1*(metric)

# %%
res_gp = gp_minimize(var_to_minimize, 
                     param_space, n_calls=100,
                     random_state=0,n_random_starts=10)
# Out:
# 2020-11-26 18:07:40,439 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.4881255012149711, 'feature_fraction': 0.6, 'bagging_fraction': 0.6, 'num_leaves': 10, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.7658 | auc pr: 0.4264 | ratio of the test set 0.1485 | iteration: 30
# 2020-11-26 18:07:54,001 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.012984521643751776, 'feature_fraction': 0.4, 'bagging_fraction': 0.5, 'num_leaves': 13, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.7681 | auc pr: 0.4288 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:08:22,148 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.4700645792732058, 'feature_fraction': 0.4, 'bagging_fraction': 0.6, 'num_leaves': 7, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7579 | auc pr: 0.4139 | ratio of the test set 0.1485 | iteration: 58
# 2020-11-26 18:08:25,335 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.5497617455119916, 'feature_fraction': 0.5, 'bagging_fraction': 0.6, 'num_leaves': 9, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.7496 | auc pr: 0.4096 | ratio of the test set 0.1485 | iteration: 33
# 2020-11-26 18:08:27,946 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.14589472312361856, 'feature_fraction': 0.5, 'bagging_fraction': 0.6, 'num_leaves': 4, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.7636 | auc pr: 0.4257 | ratio of the test set 0.1485 | iteration: 359
# 2020-11-26 18:08:43,156 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.2977394311301938, 'feature_fraction': 0.4, 'bagging_fraction': 0.4, 'num_leaves': 7, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7656 | auc pr: 0.4243 | ratio of the test set 0.1485 | iteration: 75
# 2020-11-26 18:08:47,052 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05928952380648088, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'num_leaves': 10, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7716 | auc pr: 0.4321 | ratio of the test set 0.1485 | iteration: 305
# 2020-11-26 18:09:06,878 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.8701981095758312, 'feature_fraction': 0.6, 'bagging_fraction': 0.4, 'num_leaves': 7, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.751 | auc pr: 0.4075 | ratio of the test set 0.1485 | iteration: 23
# 2020-11-26 18:09:09,117 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04467807553356735, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 15, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.7734 | auc pr: 0.4361 | ratio of the test set 0.1485 | iteration: 322
# 2020-11-26 18:09:24,264 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.9785863088320509, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'num_leaves': 9, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7344 | auc pr: 0.3729 | ratio of the test set 0.1485 | iteration: 23
# 2020-11-26 18:09:26,833 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.027471327107809057, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'num_leaves': 4, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7632 | auc pr: 0.4196 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:09:51,012 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07371891564136251, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7711 | auc pr: 0.4324 | ratio of the test set 0.1485 | iteration: 154
# 2020-11-26 18:09:59,882 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.6, 'bagging_fraction': 0.4, 'num_leaves': 3, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.7453 | auc pr: 0.4027 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:10:21,088 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.16193284865484886, 'feature_fraction': 0.4, 'bagging_fraction': 0.6, 'num_leaves': 15, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7681 | auc pr: 0.4297 | ratio of the test set 0.1485 | iteration: 106
# 2020-11-26 18:10:27,842 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.24236494639932243, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7647 | auc pr: 0.4254 | ratio of the test set 0.1485 | iteration: 48
# 2020-11-26 18:10:33,184 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.027202088564678553, 'feature_fraction': 0.6, 'bagging_fraction': 0.6, 'num_leaves': 15, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.7726 | auc pr: 0.4354 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:11:06,150 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03626057449660859, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'num_leaves': 15, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7728 | auc pr: 0.4348 | ratio of the test set 0.1485 | iteration: 398
# 2020-11-26 18:11:35,797 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7664 | auc pr: 0.428 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:12:10,472 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.06933972787904143, 'feature_fraction': 0.4, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7613 | auc pr: 0.4187 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:12:27,556 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07879840858655385, 'feature_fraction': 0.6, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7697 | auc pr: 0.4318 | ratio of the test set 0.1485 | iteration: 165
# 2020-11-26 18:12:39,474 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.024320980502082454, 'feature_fraction': 0.7, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7721 | auc pr: 0.4327 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:13:15,898 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02428466080892215, 'feature_fraction': 0.4, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7718 | auc pr: 0.4338 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:13:42,926 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.031230935278250715, 'feature_fraction': 0.5, 'bagging_fraction': 0.6, 'num_leaves': 7, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7694 | auc pr: 0.4287 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:14:07,880 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.11237202639711978, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 10, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7708 | auc pr: 0.4289 | ratio of the test set 0.1485 | iteration: 184
# 2020-11-26 18:14:20,612 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.28890892628877723, 'feature_fraction': 0.5, 'bagging_fraction': 0.6, 'num_leaves': 3, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.753 | auc pr: 0.4126 | ratio of the test set 0.1485 | iteration: 145
# 2020-11-26 18:14:27,517 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04792871582678898, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 9, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7691 | auc pr: 0.4301 | ratio of the test set 0.1485 | iteration: 384
# 2020-11-26 18:14:48,025 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.20104919658504103, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 12, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7672 | auc pr: 0.4274 | ratio of the test set 0.1485 | iteration: 72
# 2020-11-26 18:14:52,783 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.010004745066137348, 'feature_fraction': 0.6, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7388 | auc pr: 0.397 | ratio of the test set 0.1485 | iteration: 12
# 2020-11-26 18:14:55,657 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.184927477288598, 'feature_fraction': 0.4, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7699 | auc pr: 0.4309 | ratio of the test set 0.1485 | iteration: 92
# 2020-11-26 18:15:02,307 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.0868405584676438, 'feature_fraction': 0.4, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7711 | auc pr: 0.4331 | ratio of the test set 0.1485 | iteration: 203
# 2020-11-26 18:15:14,267 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01624793222806903, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.749 | auc pr: 0.4049 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:15:30,500 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05353902955794862, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7729 | auc pr: 0.4345 | ratio of the test set 0.1485 | iteration: 267
# 2020-11-26 18:15:51,441 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05290057935429763, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7704 | auc pr: 0.4352 | ratio of the test set 0.1485 | iteration: 303
# 2020-11-26 18:16:09,659 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.044897412524157264, 'feature_fraction': 0.4, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.7745 | auc pr: 0.438 | ratio of the test set 0.1485 | iteration: 419
# 2020-11-26 18:16:30,992 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.08234094977986878, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7702 | auc pr: 0.4316 | ratio of the test set 0.1485 | iteration: 148
# 2020-11-26 18:16:43,777 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03413494703176542, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.772 | auc pr: 0.4349 | ratio of the test set 0.1485 | iteration: 429
# 2020-11-26 18:17:10,156 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04608382292684635, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7719 | auc pr: 0.4351 | ratio of the test set 0.1485 | iteration: 326
# 2020-11-26 18:17:26,050 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07797618446506928, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7597 | auc pr: 0.4161 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:17:41,785 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04343293920771462, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7714 | auc pr: 0.4339 | ratio of the test set 0.1485 | iteration: 279
# 2020-11-26 18:18:03,978 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04347003889856791, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7712 | auc pr: 0.4342 | ratio of the test set 0.1485 | iteration: 367
# 2020-11-26 18:18:21,509 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.3345562231531484, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.7663 | auc pr: 0.4244 | ratio of the test set 0.1485 | iteration: 36
# 2020-11-26 18:18:25,225 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.12640117121292702, 'feature_fraction': 0.7, 'bagging_fraction': 0.6, 'num_leaves': 15, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.77 | auc pr: 0.4322 | ratio of the test set 0.1485 | iteration: 103
# 2020-11-26 18:18:35,639 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.09645106817905691, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7707 | auc pr: 0.4347 | ratio of the test set 0.1485 | iteration: 217
# 2020-11-26 18:18:51,174 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7459 | auc pr: 0.4034 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:19:15,893 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.037005596619030155, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 13, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7725 | auc pr: 0.4346 | ratio of the test set 0.1485 | iteration: 442
# 2020-11-26 18:19:35,632 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.016579714376861288, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 11, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7684 | auc pr: 0.4289 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:19:59,652 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.37151866843858644, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.7615 | auc pr: 0.4159 | ratio of the test set 0.1485 | iteration: 266
# 2020-11-26 18:20:14,231 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.022822044733272488, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.7725 | auc pr: 0.4343 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:20:54,858 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03327179458297952, 'feature_fraction': 0.4, 'bagging_fraction': 0.3, 'num_leaves': 9, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7707 | auc pr: 0.4307 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:21:20,063 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.21638880763839063, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.757 | auc pr: 0.4149 | ratio of the test set 0.1485 | iteration: 231
# 2020-11-26 18:21:30,952 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.9991575063911866, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.754 | auc pr: 0.4087 | ratio of the test set 0.1485 | iteration: 15
# 2020-11-26 18:21:34,516 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04904898391225691, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 10, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7711 | auc pr: 0.4329 | ratio of the test set 0.1485 | iteration: 489
# 2020-11-26 18:22:00,314 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.11973550932332556, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7598 | auc pr: 0.4179 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:22:21,688 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03311774268780823, 'feature_fraction': 0.4, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.742 | auc pr: 0.4076 | ratio of the test set 0.1485 | iteration: 27
# 2020-11-26 18:22:24,856 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.08650619262971629, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 6, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.7689 | auc pr: 0.4295 | ratio of the test set 0.1485 | iteration: 308
# 2020-11-26 18:22:43,750 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.048758102921628146, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 13, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7712 | auc pr: 0.4337 | ratio of the test set 0.1485 | iteration: 307
# 2020-11-26 18:22:58,856 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.18786924485686904, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 10, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7713 | auc pr: 0.4309 | ratio of the test set 0.1485 | iteration: 82
# 2020-11-26 18:23:07,179 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.1050003712946978, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 7, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.767 | auc pr: 0.4262 | ratio of the test set 0.1485 | iteration: 201
# 2020-11-26 18:23:21,600 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 8, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7641 | auc pr: 0.4228 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:23:57,881 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 1.0, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7547 | auc pr: 0.4068 | ratio of the test set 0.1485 | iteration: 96
# 2020-11-26 18:24:04,527 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.08941681163986985, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 8, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7641 | auc pr: 0.4277 | ratio of the test set 0.1485 | iteration: 200
# 2020-11-26 18:24:14,169 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02394488262451324, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7724 | auc pr: 0.433 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:24:50,917 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.30583517150200423, 'feature_fraction': 0.6, 'bagging_fraction': 0.3, 'num_leaves': 11, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7669 | auc pr: 0.4272 | ratio of the test set 0.1485 | iteration: 65
# 2020-11-26 18:24:57,125 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.4, 'bagging_fraction': 0.3, 'num_leaves': 11, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7659 | auc pr: 0.4269 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:25:26,359 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05441418507444857, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 5, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7671 | auc pr: 0.4261 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:25:53,675 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.5515834307614241, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7557 | auc pr: 0.4135 | ratio of the test set 0.1485 | iteration: 19
# 2020-11-26 18:25:57,913 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.06925402322977248, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7689 | auc pr: 0.4332 | ratio of the test set 0.1485 | iteration: 273
# 2020-11-26 18:26:10,895 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01999266535997871, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 14, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7724 | auc pr: 0.4341 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:26:36,028 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 6, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7594 | auc pr: 0.4181 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:26:56,583 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.12985059257466994, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 13, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7679 | auc pr: 0.4283 | ratio of the test set 0.1485 | iteration: 179
# 2020-11-26 18:27:06,004 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01680442888237482, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 9, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7702 | auc pr: 0.4293 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:27:42,756 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03507267030300727, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 11, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.7718 | auc pr: 0.4348 | ratio of the test set 0.1485 | iteration: 489
# 2020-11-26 18:28:04,565 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02910139944791081, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 14, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7735 | auc pr: 0.4355 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:28:27,782 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.20069379539326462, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 5, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7653 | auc pr: 0.4243 | ratio of the test set 0.1485 | iteration: 137
# 2020-11-26 18:28:37,545 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.059456242709177466, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 14, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7716 | auc pr: 0.4351 | ratio of the test set 0.1485 | iteration: 343
# 2020-11-26 18:28:53,408 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.021638555316840627, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 10, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7725 | auc pr: 0.4313 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:29:29,659 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.22344096666355484, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 6, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7656 | auc pr: 0.4245 | ratio of the test set 0.1485 | iteration: 109
# 2020-11-26 18:29:38,655 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.4, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.7657 | auc pr: 0.4267 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:30:09,232 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02969559594430899, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 6, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7672 | auc pr: 0.4262 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:30:35,851 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.24232483162632865, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 10, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7664 | auc pr: 0.4217 | ratio of the test set 0.1485 | iteration: 61
# 2020-11-26 18:30:41,514 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.0783647614619024, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 11, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7712 | auc pr: 0.4323 | ratio of the test set 0.1485 | iteration: 285
# 2020-11-26 18:31:02,931 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.024063431538415413, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 13, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7714 | auc pr: 0.4321 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:31:26,694 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.09820371104552943, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 10, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7664 | auc pr: 0.4289 | ratio of the test set 0.1485 | iteration: 241
# 2020-11-26 18:31:43,206 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.9683216177735303, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7516 | auc pr: 0.413 | ratio of the test set 0.1485 | iteration: 111
# 2020-11-26 18:31:50,511 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02956831909555835, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 11, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.7723 | auc pr: 0.4313 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:32:26,552 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.0351529753893481, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'num_leaves': 13, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7731 | auc pr: 0.4344 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:33:03,446 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02719015765401242, 'feature_fraction': 0.7, 'bagging_fraction': 0.4, 'num_leaves': 9, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7725 | auc pr: 0.4311 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:33:38,741 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.19708503286539586, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 9, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.7709 | auc pr: 0.429 | ratio of the test set 0.1485 | iteration: 80
# 2020-11-26 18:33:47,672 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.21702012763655196, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7687 | auc pr: 0.4275 | ratio of the test set 0.1485 | iteration: 60
# 2020-11-26 18:33:55,356 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.5483501089622078, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 5, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7575 | auc pr: 0.4199 | ratio of the test set 0.1485 | iteration: 61
# 2020-11-26 18:34:02,407 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.026988362611704002, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7728 | auc pr: 0.4343 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:34:27,830 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.2129988083222049, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 8, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.7708 | auc pr: 0.4284 | ratio of the test set 0.1485 | iteration: 86
# 2020-11-26 18:34:37,690 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03527746378817829, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 12, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7709 | auc pr: 0.4324 | ratio of the test set 0.1485 | iteration: 447
# 2020-11-26 18:35:12,110 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.028385172730935725, 'feature_fraction': 0.7, 'bagging_fraction': 0.6, 'num_leaves': 10, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7722 | auc pr: 0.4319 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:35:50,521 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.020617070666237445, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 8, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.7692 | auc pr: 0.4277 | ratio of the test set 0.1485 | iteration: 500
# 2020-11-26 18:36:20,873 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.3215718040203836, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 10, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7683 | auc pr: 0.4253 | ratio of the test set 0.1485 | iteration: 41
# 2020-11-26 18:36:27,940 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04196598932504259, 'feature_fraction': 0.6, 'bagging_fraction': 0.3, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.774 | auc pr: 0.4336 | ratio of the test set 0.1485 | iteration: 381
# 2020-11-26 18:36:55,493 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.08216857985912969, 'feature_fraction': 0.4, 'bagging_fraction': 0.3, 'num_leaves': 10, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.7692 | auc pr: 0.4289 | ratio of the test set 0.1485 | iteration: 189
# 2020-11-26 18:37:07,974 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.041380203062215, 'feature_fraction': 0.6, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7733 | auc pr: 0.4361 | ratio of the test set 0.1485 | iteration: 424
# 2020-11-26 18:37:37,486 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 9, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7647 | auc pr: 0.4256 | ratio of the test set 0.1485 | iteration: 500

# %%
"Best score=%.4f" % res_gp.fun
# Out:
# 'Best score=-0.7746'

# %% [markdown]
# ### 3. Training model with the best params

# %%
model_parameters= {
    "boosting_type": res_gp.x[0],
    "objective": "binary",
    "metric": ["auc"],
    "seed": 9520,
    "learning_rate": res_gp.x[1],
    "feature_fraction": res_gp.x[2]/10,
    "bagging_fraction": res_gp.x[3]/10,
    "num_leaves": res_gp.x[4],
    "min_child_weight": res_gp.x[5],
    "num_threads": n_threads}
model_parameters
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'metric': ['auc'],
#  'seed': 9520,
#  'learning_rate': 0.044897412524157264,
#  'feature_fraction': 0.4,
#  'bagging_fraction': 0.7,
#  'num_leaves': 15,
#  'min_child_weight': 8,
#  'num_threads': 28}

# %%
eval_results = {}
cb_evaluation = lgbm.record_evaluation(eval_results)
lgbmodel = lgbm.train(model_parameters,
                      xlgb_train,
                      valid_sets=valid_sets,
                      early_stopping_rounds=10,
                      verbose_eval=10,
                      num_boost_round=1000,
                      callbacks=[cb_evaluation])
preds=lgbmodel.predict(df_test[vars_to_model])
metric=skmetrics.roc_auc_score(df_test[target_var], preds)

p, r, _=skmetrics.precision_recall_curve(df_test[target_var], preds)
pr_auc=skmetrics.auc(r,p)

print(f"TEST auc roc: {np.round(metric,4)} | auc pr: {np.round(pr_auc,4)} | ratio of the test set {np.round(df_test.TARGET.mean(),4)} | iteration: {lgbmodel.current_iteration()}")
# Out:
# Training until validation scores don't improve for 10 rounds
# [10]	training's auc: 0.722674	valid_1's auc: 0.718546
# [20]	training's auc: 0.727772	valid_1's auc: 0.7234
# [30]	training's auc: 0.73171	valid_1's auc: 0.726541
# [40]	training's auc: 0.734976	valid_1's auc: 0.728329
# [50]	training's auc: 0.739849	valid_1's auc: 0.73266
# [60]	training's auc: 0.743942	valid_1's auc: 0.73618
# [70]	training's auc: 0.747712	valid_1's auc: 0.738844
# [80]	training's auc: 0.751685	valid_1's auc: 0.74285
# [90]	training's auc: 0.755611	valid_1's auc: 0.747278
# [100]	training's auc: 0.759242	valid_1's auc: 0.750543
# [110]	training's auc: 0.762736	valid_1's auc: 0.753638
# [120]	training's auc: 0.765885	valid_1's auc: 0.756159
# [130]	training's auc: 0.768016	valid_1's auc: 0.758321
# [140]	training's auc: 0.770377	valid_1's auc: 0.760586
# [150]	training's auc: 0.772547	valid_1's auc: 0.762347
# [160]	training's auc: 0.774571	valid_1's auc: 0.764334
# [170]	training's auc: 0.77663	valid_1's auc: 0.765944
# [180]	training's auc: 0.778555	valid_1's auc: 0.76739
# [190]	training's auc: 0.780199	valid_1's auc: 0.768617
# [200]	training's auc: 0.781775	valid_1's auc: 0.769987
# [210]	training's auc: 0.783375	valid_1's auc: 0.771165
# [220]	training's auc: 0.784902	valid_1's auc: 0.772313
# [230]	training's auc: 0.786179	valid_1's auc: 0.773495
# [240]	training's auc: 0.787405	valid_1's auc: 0.774429
# [250]	training's auc: 0.788563	valid_1's auc: 0.775245
# [260]	training's auc: 0.789647	valid_1's auc: 0.776002
# [270]	training's auc: 0.790701	valid_1's auc: 0.776973
# [280]	training's auc: 0.791734	valid_1's auc: 0.777797
# [290]	training's auc: 0.792714	valid_1's auc: 0.778615
# [300]	training's auc: 0.793609	valid_1's auc: 0.779278
# [310]	training's auc: 0.794516	valid_1's auc: 0.779681
# [320]	training's auc: 0.795321	valid_1's auc: 0.780105
# [330]	training's auc: 0.796187	valid_1's auc: 0.780729
# [340]	training's auc: 0.796991	valid_1's auc: 0.781136
# [350]	training's auc: 0.797805	valid_1's auc: 0.78156
# [360]	training's auc: 0.798578	valid_1's auc: 0.782004
# [370]	training's auc: 0.799256	valid_1's auc: 0.782309
# [380]	training's auc: 0.799986	valid_1's auc: 0.782775
# [390]	training's auc: 0.800698	valid_1's auc: 0.782942
# [400]	training's auc: 0.801401	valid_1's auc: 0.783219
# [410]	training's auc: 0.802051	valid_1's auc: 0.783609
# [420]	training's auc: 0.80269	valid_1's auc: 0.783857
# [430]	training's auc: 0.8034	valid_1's auc: 0.784152
# [440]	training's auc: 0.803999	valid_1's auc: 0.784371
# [450]	training's auc: 0.804664	valid_1's auc: 0.784554
# [460]	training's auc: 0.8053	valid_1's auc: 0.78474
# [470]	training's auc: 0.805843	valid_1's auc: 0.78494
# [480]	training's auc: 0.806342	valid_1's auc: 0.785069
# [490]	training's auc: 0.806903	valid_1's auc: 0.785262
# [500]	training's auc: 0.807389	valid_1's auc: 0.785373
# [510]	training's auc: 0.807939	valid_1's auc: 0.785599
# [520]	training's auc: 0.808533	valid_1's auc: 0.785698
# [530]	training's auc: 0.809087	valid_1's auc: 0.785865
# [540]	training's auc: 0.809594	valid_1's auc: 0.785986
# [550]	training's auc: 0.810141	valid_1's auc: 0.786061
# [560]	training's auc: 0.810656	valid_1's auc: 0.786233
# [570]	training's auc: 0.811189	valid_1's auc: 0.786335
# [580]	training's auc: 0.811769	valid_1's auc: 0.786367
# [590]	training's auc: 0.812266	valid_1's auc: 0.786413
# [600]	training's auc: 0.812784	valid_1's auc: 0.786489
# [610]	training's auc: 0.813265	valid_1's auc: 0.786564
# [620]	training's auc: 0.813709	valid_1's auc: 0.786668
# [630]	training's auc: 0.814214	valid_1's auc: 0.786751
# [640]	training's auc: 0.814691	valid_1's auc: 0.786849
# [650]	training's auc: 0.815162	valid_1's auc: 0.786918
# [660]	training's auc: 0.815615	valid_1's auc: 0.787001
# [670]	training's auc: 0.816076	valid_1's auc: 0.787085
# [680]	training's auc: 0.816554	valid_1's auc: 0.787121
# [690]	training's auc: 0.817003	valid_1's auc: 0.787173
# Early stopping, best iteration is:
# [686]	training's auc: 0.816794	valid_1's auc: 0.787218
# TEST auc roc: 0.774 | auc pr: 0.0153 | ratio of the test set 0.0029 | iteration: 686

# %%
# Create model path
model_format = datetime.strftime(datetime.today(), "%Y%m%d_%H%M")
model_folder = f"{model_path}{model_format}_{model}_{model_type}_model/"

if not os.path.exists(model_folder):
    os.makedirs(model_folder)

importance_lgbm = lgbmodel.feature_importance(importance_type="gain")
df_importance_lgbm = pd.DataFrame(
    {'column': list(df_train[vars_to_model].columns),
     'importance_gain': importance_lgbm})
df_importance_lgbm.sort_values('importance_gain', ascending=False, axis=0, inplace=True)
df_importance_lgbm['importance_gain'] = df_importance_lgbm['importance_gain'] / \
                                        df_importance_lgbm['importance_gain'].sum()
# Export variable importance
df_importance_lgbm.to_csv(model_folder + model_format + "_important_variables.csv", sep=";", decimal=".", index=False)

print(df_importance_lgbm.head(30))

export_auc_graph(df_train=df_train,
                 df_dev=df_dev,
                 df_test=df_test,
                 model=lgbmodel,
                 vars_to_model=vars_to_model,
                 target_var=target_var,
                 file_path=model_folder + model_format + "_auc.png",
                 multiclass=False)
# Out:
#                                             column  importance_gain
# 476                                  EOP_N_TECH_10         0.063937
# 752    CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_336         0.054397
# 358                                 EOP_N_HARDWARE         0.049479
# 355                                     EOP_TENURE         0.042350
# 411              EVE_CAT_COMBINED_108_3_nansum_336         0.034680
# 794              EVE_CAT_COMBINED_108_3_nansum_252         0.027791
# 1032                                 EOP_N_TECH_30         0.024262
# 163                                   EOP_N_BRONCE         0.020643
# 410   CAM_OFERTA_COMBINADA_OTROS_BUNDLE_nansum_336         0.020085
# 74                CAM_DAYS_TO_END_OFFER_nanmax_336         0.019272
# 89               EVE_CAT_COMBINED_108_3_nansum_168         0.015901
# 597                                      EOP_N_HBO         0.014615
# 555              EVE_CAT_COMBINED_133_5_nansum_336         0.014082
# 43                                   EOP_N_TECH_25         0.013834
# 914               CAM_DAYS_TO_END_OFFER_nanmin_336         0.012609
# 1088              CAM_DAYS_TO_END_OFFER_nanmax_252         0.012485
# 371               EVE_CAT_COMBINED_108_3_nansum_84         0.010876
# 543                                       CLI_EDAD         0.010365
# 844         CAM_DAYS_SINCE_START_OFFER_nanmean_336         0.009207
# 950                  FAC_PCT_CHG_MONTO_TOTAL_56_28         0.009115
# 326                   FAC_CATEGORIA_ID_B_nansum_84         0.008892
# 1164         CAM_DAYS_SINCE_START_OFFER_nanmax_336         0.008669
# 1051                            AQY_RATIO_ARPU_1_3         0.008534
# 313                   FAC_CATEGORIA_ID_H_nansum_84         0.008450
# 251                               EOP_N_TECH_OTHER         0.008112
# 1107             CAM_MONTO_OFFER_SCALED_nanmin_336         0.007944
# 252                             AQY_ARPU_nanmean_1         0.007834
# 842                                      EOP_N_FOX         0.007712
# 1127             EVE_CAT_COMBINED_171_3_nansum_336         0.007651
# 990             EVE_CAT_COMBINED_OTHER_3_nansum_28         0.007236

# %%
# Export model performance
export_model_performance_lgbm(model=lgbmodel,
                              vars_to_include=vars_to_model,
                              target_var=target_var,
                              id_var=id_vars,
                              period_var=period_vars,
                              score_var=score_var,
                              df=df_train,
                              table_name="train",
                              model_folder=model_folder,
                              model_format=model_format,
                              export_df=False)
export_model_performance_lgbm(model=lgbmodel,
                              vars_to_include=vars_to_model,
                              target_var=target_var,
                              id_var=id_vars,
                              period_var=period_vars,
                              score_var=score_var,
                              df=df_dev,
                              table_name="dev",
                              model_folder=model_folder,
                              model_format=model_format,
                              export_df=False)

export_model_performance_lgbm(model=lgbmodel,
                              vars_to_include=vars_to_model,
                              target_var=target_var,
                              id_var=id_vars,
                              period_var=period_vars,
                              score_var=score_var,
                              df=df_test,
                              table_name="test",
                              model_folder=model_folder,
                              model_format=model_format,
                              export_df=True,
                              N=20)

df_explore = df_test.copy()
df_explore[score_var] = lgbmodel.predict(df_test[vars_to_model])

df_summary = variable_avg_by_ntile(df_explore,
                                   N=10,
                                   score_col=score_var,
                                   feature_importance=df_importance_lgbm)

df_summary.to_csv(model_folder + model_format + "_summary.csv", sep=";", decimal=",", index=False)

# Export volumes
df_volume = get_model_volumes(df_train=df_train,
                              df_dev=df_dev,
                              df_test=df_test,
                              period_var="DATE_CALC",
                              target_var=target_var)
df_volume.to_csv(model_folder + model_format + "_volumes.csv", sep=";", decimal=",", index=False)

# Save parameteres
save_json(model_parameters, model_folder + model_format + "_model_parameters.json")

df = []
vars_to_analyze = df_importance_lgbm[df_importance_lgbm["importance_gain"] > 0]["column"].values.tolist()

df_list = [df_train[period_vars + vars_to_analyze],
           df_dev[period_vars + vars_to_analyze],
           df_test[period_vars + vars_to_analyze]]
df = pd.concat(df_list)
df = df.groupby(period_vars).agg(np.nanmean).T.reset_index().rename(columns={"index": "column"})
df = pd.merge(df, df_importance_lgbm, on="column", how="inner")
df.to_csv(model_folder + model_format + "_mean_evolution.csv", sep=";", decimal=",")

# Calculate NaN evolution
df = []
vars_to_analyze = df_importance_lgbm[df_importance_lgbm["importance_gain"] > 0]["column"].values.tolist()

df_list = [df_train[period_vars + vars_to_analyze],
           df_dev[period_vars + vars_to_analyze],
           df_test[period_vars + vars_to_analyze]]
df = pd.concat(df_list)
df = df.groupby(period_vars).agg(lambda x: x.isnull().sum()/len(x)).T.reset_index().rename(columns={"index": "column"})
df = pd.merge(df, df_importance_lgbm, on="column", how="inner")
df.to_csv(model_folder + model_format + "_nan_evolution.csv", sep=";", decimal=",")

# Calculate NaNs by decile
df_explore = get_ntile(df_explore,
                       N=10,
                       score_col=score_var,
                       ntile_col="DECIL")

df_explore_grouped = df_explore[period_vars + vars_to_analyze + ["DECIL"]].groupby("DECIL").agg(lambda x: x.isnull().sum()/len(x)
                                                                                               ).T.reset_index(
                                                                                               ).rename(columns={"index": "column"})

df_explore_grouped = pd.merge(df_explore_grouped, df_importance_lgbm, on="column", how="inner")
df_explore_grouped.to_csv(model_folder + model_format + "_nan_summary.csv", sep=";", decimal=",")

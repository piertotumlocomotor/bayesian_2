# %% [markdown]
# ### prueba de parametros skopt

# %% [markdown]
# ### 0. Load Kedro context:
# - This is only necessary to run a notebook within a Kedro project, not needed in production code when running nodes/pipelines

# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")
from re import search
import random
from aa_engine_pkg.assets.utils import *
from aa_engine_pkg.assets.core.data.kedro.catalog_expansion.partitioned_sql import SQLPartitionedDataSet
from sklearn import model_selection
from functools import partial
from skopt import space
from skopt import gp_minimize
from aa_engine_pkg.assets.utils import model_pipeline

# %%
# -------------------------------- UPSELL MODEL --------------------------------
# Using temporal division
# Initialize logger
log = initialize_logger()
log.info(f"[TRAIN_MODEL] Creating model...")

# Loading parameters
model = "upsell"
model_type = "binary"
if model == "":
    model = parameters["models"]["model"]
if model_type == "":
    model = parameters["models"][model]["model_type"]
model_path = parameters["paths"]["model_path"]
n_threads = parameters["models"]["n_threads"]

random_time=False
downsample=False
# Out:
# 2021-01-13 19:13:50,154 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Creating model...

# %%
train_periods = parameters["models"][model][model_type]["train_periods"]
dev_periods = parameters["models"][model][model_type]["dev_periods"]
test_periods = parameters["models"][model][model_type]["test_periods"]
id_vars = parameters["models"][model][model_type]["id_vars"]
period_vars = parameters["models"][model][model_type]["period_vars"]
target_var = parameters["models"][model][model_type]["target_var"]
score_var = parameters["models"][model][model_type]["score_var"]
load_subsample = parameters["models"][model][model_type]["load_subsample"]
fill_na_with = parameters["models"][model][model_type]["fill_na_with"]

# %%
if type(fill_na_with) == str:
    fill_na_with = eval(fill_na_with)

# Join periods
model_periods = list(np.unique(train_periods + dev_periods))
if len(model_periods) < (len(train_periods) + len(dev_periods)):
    log.warning(f"Validation periods and train periods overlap")

# Set maximum number of threads
os.environ["NUMEXPR_MAX_THREADS"] = str(n_threads)

# %% [markdown]
# ### 1. Random periods and downsample

# %%
#Random periods
if random_time == True:
    random.seed(4)
    l=train_periods+dev_periods+test_periods
    ix=list(range(len(l)-1))
    sampled_list = random.sample(ix, int(0.8*len(ix)))
    train_list = [l[i] for i in sampled_list ] 
    test_list = [l[i] for i in ix if i not in sampled_list ] 
else:
    train_list=train_periods+dev_periods
    test_list=test_periods
    
print(f"----------- train periods -------------")
print(f"{train_list}")
print(f"----------- test periods -------------")
print(f"{test_list}")
# Out:
# ----------- train periods -------------
# ['20181203', '20181231', '20190128', '20190225', '20190325', '20190422', '20190520', '20190617', '20190715', '20190812', '20190909', '20191007', '20191104', '20191202', '20191230', '20200127', '20200224', '20200323', '20200420', '20200518']
# ----------- test periods -------------
# ['20200615', '20200713', '20200810', '20200907']

# %%
#Downsample
ratio_noevents_vs_events=4
if downsample==True:
    random.seed(4)
    df_all = load_and_merge_tables(model=model,
                                     model_type=model_type,
                                     periods=train_list+test_list,
                                     parameters=parameters,
                                     load_subsample=load_subsample,
                                     load_target=True)
    df_all.reset_index(drop=True,inplace=True)
    df_down_sample=[]
    for date in df_all.DATE_CALC.unique():
        if date not in test_list:
            idx_target=df_all.loc[(df_all.TARGET==1) & (df_all.DATE_CALC==date)].index
            n_target=df_all.loc[(df_all.TARGET==1) & (df_all.DATE_CALC==date)].shape[0]

            idx_no_target=df_all.loc[(df_all.TARGET==0) & (df_all.DATE_CALC==date)].index
            n_no_target=df_all.loc[(df_all.TARGET==0) & (df_all.DATE_CALC==date)].shape[0]
            
            n=np.where(n_target*ratio_noevents_vs_events<n_no_target,n_target*ratio_noevents_vs_events,n_no_target)

            random_indices = np.random.choice( idx_no_target, n , replace=False)
            down_sample_indices = np.concatenate([idx_target,random_indices])
            aux=df_all.loc[down_sample_indices].copy()
            
            print(f"ratio 1/0 {date}: { np.round(aux.TARGET.mean(),2) }")
            df_down_sample.append(aux)

        df_down=pd.concat(df_down_sample)
        df_train=df_down.loc[df_down.DATE_CALC.isin(train_list)].copy()
        
    df_test=df_all.loc[df_all.DATE_CALC.isin(test_list)].copy()
else:
    print("-----------No downsample ------------------")
    # Load datasets
    df_train = load_and_merge_tables(model=model,
                                     model_type=model_type,
                                     periods=train_list,
                                     parameters=parameters,
                                     load_subsample=load_subsample,
                                     load_target=True)
    print(f"ratio 1/0 {df_train.groupby('DATE_CALC').agg({'TARGET':'mean'})}")
    df_test = load_and_merge_tables(model=model,
                                    model_type=model_type,
                                    periods=test_list,
                                    parameters=parameters,
                                    load_subsample=False,
                                    load_target=True)

print(f"ratio 1/0 {df_test.groupby('DATE_CALC').agg({'TARGET':'mean'})}")
# Out:
# -----------No downsample ------------------
# 2021-01-13 20:50:30,898 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20181203
# 2021-01-13 20:50:31,138 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:31,568 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20181231
# 2021-01-13 20:50:31,795 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:32,383 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190128
# 2021-01-13 20:50:32,629 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:33,142 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190225
# 2021-01-13 20:50:33,374 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:33,669 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190325
# 2021-01-13 20:50:33,906 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:34,211 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190422
# 2021-01-13 20:50:34,451 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:34,761 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190520
# 2021-01-13 20:50:35,001 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:35,364 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190617
# 2021-01-13 20:50:35,603 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:36,041 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190715
# 2021-01-13 20:50:36,286 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:36,790 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190812
# 2021-01-13 20:50:37,034 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:37,623 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20190909
# 2021-01-13 20:50:37,869 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:38,157 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20191007
# 2021-01-13 20:50:38,409 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:38,776 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20191104
# 2021-01-13 20:50:39,020 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:39,331 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20191202
# 2021-01-13 20:50:39,580 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:40,026 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20191230
# 2021-01-13 20:50:40,284 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:40,574 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200127
# 2021-01-13 20:50:40,826 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:41,271 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200224
# 2021-01-13 20:50:41,524 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:41,969 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200323
# 2021-01-13 20:50:42,196 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:42,781 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200420
# 2021-01-13 20:50:43,027 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:43,619 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200518
# 2021-01-13 20:50:43,852 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# ratio 1/0              TARGET
# DATE_CALC
# 20181203   0.002881
# 20181231   0.003715
# 20190128   0.004229
# 20190225   0.004561
# 20190325   0.003553
# 20190422   0.003788
# 20190520   0.005089
# 20190617   0.003763
# 20190715   0.006598
# 20190812   0.004072
# 20190909   0.004618
# 20191007   0.004133
# 20191104   0.003341
# 20191202   0.002945
# 20191230   0.003198
# 20200127   0.003534
# 20200224   0.003482
# 20200323   0.003005
# 20200420   0.001938
# 20200518   0.005328
# 2021-01-13 20:50:52,328 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200615
# 2021-01-13 20:50:52,565 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:53,074 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200713
# 2021-01-13 20:50:53,310 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:53,833 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200810
# 2021-01-13 20:50:54,070 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# 2021-01-13 20:50:54,388 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200907
# 2021-01-13 20:50:54,628 - aa_engine_pkg.assets.utils.utilities - INFO - cargando upsell
# ratio 1/0              TARGET
# DATE_CALC
# 20200615   0.003761
# 20200713   0.003256
# 20200810   0.004760
# 20200907   0.003867

# %% [markdown]
# ### Remuevo clientes que ya no pueden hacer upgrades

# %%
# Train
log.info(f"[TRAIN] Target pre-filtros: {df_train.groupby(target_var).size()/df_train.shape[0]*100}")
train_mask_has_top_product = (df_train["PRC_CODIGO"] != 139)
df_train = df_train.loc[train_mask_has_top_product, :]
log.info(f"[TRAIN] Target post-filtros: {df_train.groupby(target_var).size()/df_train.shape[0]*100}")

#Test
log.info(f"[TEST] Target pre-filtros: {df_test.groupby(target_var).size()/df_test.shape[0]*100}")
test_mask_has_top_product = (df_test["PRC_CODIGO"] != 139)
df_test = df_test.loc[test_mask_has_top_product, :]
log.info(f"[TEST] Target post-filtros: {df_test.groupby(target_var).size()/df_test.shape[0]*100}")

df_test=df_test.drop(['PRC_CODIGO'], axis=1)
df_train=df_train.drop(['PRC_CODIGO'], axis=1)
# Out:
# 2021-01-13 20:50:56,412 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN] Target pre-filtros: TARGET
# 0    99.611882
# 1     0.388118
# dtype: float64
# 2021-01-13 20:50:57,964 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN] Target post-filtros: TARGET
# 0    99.611882
# 1     0.388118
# dtype: float64
# 2021-01-13 20:50:57,971 - aa_engine_pkg.assets.utils.utilities - INFO - [TEST] Target pre-filtros: TARGET
# 0    99.60849
# 1     0.39151
# dtype: float64
# 2021-01-13 20:50:58,176 - aa_engine_pkg.assets.utils.utilities - INFO - [TEST] Target post-filtros: TARGET
# 0    99.60849
# 1     0.39151
# dtype: float64

# %% [markdown]
# ### 2. Split

# %%
# Split train and dev sets
X_train, X_dev, y_train, y_dev = model_pipeline.create_train_test_datasets(df_train, df_train[target_var], test_size=0.2)
df_train = X_train
df_train[target_var] = y_train
df_dev = X_dev
df_dev[target_var] = y_dev
del X_train, y_train, X_dev, y_dev; gc.collect()

if model_type == "binary":
    for df, name in zip([df_train, df_dev, df_test], ["TRAIN", "DEV", "TEST"]):
        log.info(f"{name}:")
        log.info(pd.crosstab(df["DATE_CALC"], df["TARGET"]).reset_index().apply(lambda x: x[1] / (x[1] + x[0]),axis=1))
            
elif model_type == "multiclass":
    for df, name in zip([df_train, df_dev, df_test], ["TRAIN", "DEV", "TEST"]):
        for idx, cat in enumerate(df[target_var].unique()):
            log.info(f"{name}:")
            log.info(f"{cat}:")
            log.info(pd.crosstab(df["DATE_CALC"], df[target_var]).apply(lambda x: x[idx] / (x[0] + x[1] + x[2]), axis=1))
# Out:
# 2021-01-13 20:51:04,519 - aa_engine_pkg.assets.utils.utilities - INFO - TRAIN:
# 2021-01-13 20:51:04,606 - aa_engine_pkg.assets.utils.utilities - INFO - 0     0.003069
# 1     0.003845
# 2     0.004330
# 3     0.004536
# 4     0.003468
# 5     0.003849
# 6     0.005020
# 7     0.003560
# 8     0.006586
# 9     0.004143
# 10    0.004767
# 11    0.004017
# 12    0.003161
# 13    0.003030
# 14    0.003308
# 15    0.003496
# 16    0.003628
# 17    0.003193
# 18    0.002022
# 19    0.005156
# dtype: float64
# 2021-01-13 20:51:04,609 - aa_engine_pkg.assets.utils.utilities - INFO - DEV:
# 2021-01-13 20:51:04,642 - aa_engine_pkg.assets.utils.utilities - INFO - 0     0.002136
# 1     0.003189
# 2     0.003823
# 3     0.004662
# 4     0.003892
# 5     0.003544
# 6     0.005368
# 7     0.004576
# 8     0.006649
# 9     0.003784
# 10    0.004020
# 11    0.004592
# 12    0.004059
# 13    0.002610
# 14    0.002765
# 15    0.003689
# 16    0.002898
# 17    0.002256
# 18    0.001604
# 19    0.006025
# dtype: float64
# 2021-01-13 20:51:04,645 - aa_engine_pkg.assets.utils.utilities - INFO - TEST:
# 2021-01-13 20:51:04,678 - aa_engine_pkg.assets.utils.utilities - INFO - 0    0.003761
# 1    0.003256
# 2    0.004760
# 3    0.003867
# dtype: float64

# %%
# Exclude vars
vars_to_exclude = ['EOP_N_ORO','EOP_N_BRONCE' ,'EOP_N_PLATA']
num_vars = df_train.select_dtypes(include=[np.number]).columns.tolist()

# Select vars to use for training
vars_to_model = list(set(num_vars) - set(id_vars + period_vars + [target_var] + vars_to_exclude))

del df; gc.collect()

df_dev = add_selected_variables(df_dev, vars_to_model, fill_na_with)
df_test = add_selected_variables(df_test, vars_to_model, fill_na_with)
# Out:
# [] not found in df
# ['EVE_CAT_COMBINED_100133_1_nansum_84', 'EVE_CAT_COMBINED_123_1_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_28', 'MAN_ESTADOWO_ID_AG_nansum_14', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_336', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_84', 'MAN_ESTADOWO_ID_AG_nansum_84', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_28', 'EVE_CAT_COMBINED_100133_1_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_84', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_14', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_84', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_336', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_252', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_21', 'EVE_CAT_COMBINED_100133_1_nansum_28', 'EVE_CAT_COMBINED_123_1_nansum_336', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_21', 'MAN_ESTADOWO_ID_AG_nansum_28', 'EVE_CAT_COMBINED_100133_1_nansum_252', 'EVE_CAT_COMBINED_123_1_nansum_252', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_21', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_252', 'EVE_CAT_COMBINED_100133_1_nansum_168', 'MAN_ESTADOWO_ID_AG_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_21', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_28', 'EVE_CAT_COMBINED_123_1_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_336'] not found in df

# %%
# LGB datasets
if model_type == "multiclass":
    xlgb_train = lgbm.Dataset(df_train[vars_to_model], label=df_train[target_var].cat.codes)
    xlgb_dev = lgbm.Dataset(df_dev[vars_to_model], label=df_dev[target_var].cat.codes)
elif model_type == "binary":
    xlgb_train = lgbm.Dataset(df_train[vars_to_model], label=df_train[target_var])
    xlgb_dev = lgbm.Dataset(df_dev[vars_to_model], label=df_dev[target_var])
valid_sets = [xlgb_train, xlgb_dev]
log.info(f"[TRAIN_MODEL] Training model")
# Out:
# 2021-01-13 20:51:07,342 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model

# %% [markdown]
# ### 3. Using Bayesian Optimization
#
# keaggle example: [link1](https://www.kaggle.com/a31314431/bayesian-optimization-lightgbm)
#
#
# youtube: [link2](https://www.youtube.com/watch?v=5nYqK-HaoKY)

# %% [markdown]
# ### 3.1 check params [link](https://colab.research.google.com/github/lmassaron/kaggledays-2019-gbdt/blob/master/Kaggle%20Days%20Paris%20-%20%20GBDT%20workshop.ipynb#scrollTo=dJI3_YbYVzBb)

# %%
#List of search space dimensions
param_space=[
     #space.Categorical(["goss","gbdt"], name='boosting_type'),
     space.Categorical(["gbdt"], name='boosting_type'),
     space.Real(10**-2, 10**0, "log-uniform", name='learning_rate'),
     space.Integer(3,7,prior="uniform",name="feature_fraction"),
     space.Integer(3,7,prior="uniform",name="bagging_fraction"),
     space.Integer(3,15,name="num_leaves"),
     space.Integer(3,10,name="min_child_weight"),
 ]

# %% [markdown]
# #### self-defined eval metric
# #### Precision-Recall Curves and AUC
# Precision is a metric that quantifies the number of correct positive predictions made.
# It is calculated as the number of true positives divided by the total number of true positives and false positives.
# Recall is a metric that quantifies the number of correct positive predictions made out of all positive predictions that could have been made.
# Both the precision and the recall are focused on the positive class (the minority class) and are unconcerned with the true negatives (majority class).
# [check](https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-imbalanced-classification/#:~:text=The%20Precision%2DRecall%20AUC%20is,a%20model%20with%20perfect%20skill)

# %%
# self-defined eval metric
# f(preds: array, train_data: Dataset) -> name: string, eval_result: float, is_higher_better: bool
# binary error
# NOTE: when you do customized loss function, the default prediction value is margin
# This may make built-in evalution metric calculate wrong results
# For example, we are doing log likelihood loss, the prediction is score before logistic transformation
# Keep this in mind when you use the customization
def f_pr_auc(probas_pred, y_true):
    probas_pred=1. / (1. + np.exp(-probas_pred))
    labels=y_true.get_label()
    p, r, _ = skmetrics.precision_recall_curve(labels, probas_pred)
    score=skmetrics.auc(r,p)
    return "pr_auc", score, True

# %%
def var_to_minimize(param):
    
    model_params= {
    "boosting_type": param[0],
    "objective": "binary",
    "metric": ["auc"],
    "seed": 9520,
    "learning_rate": param[1],
    "feature_fraction": param[2]/10,
    "bagging_fraction": param[3]/10,
    "num_leaves": param[4],
    "min_child_weight": param[5],
    "num_threads": n_threads}
    
    log.info(f"[TRAIN_MODEL] Training model")
    print('\nNext set of params.....',model_params)
    
    eval_results = {}
    cb_evaluation = lgbm.record_evaluation(eval_results)
    # Train model
    lgbmodel = lgbm.train(model_params,
                          xlgb_train,
                          valid_sets=valid_sets,
                          #feval =f_pr_auc,
                          early_stopping_rounds=10,
                          verbose_eval=False,
                          num_boost_round=500,
                          callbacks=[cb_evaluation])
    
    preds=lgbmodel.predict(df_test[vars_to_model])
    metric=skmetrics.roc_auc_score(df_test[target_var], preds)
    
    p, r, _=skmetrics.precision_recall_curve(df_test[target_var], preds)
    pr_auc=skmetrics.auc(r,p)
    
   
    print(f"auc roc: {np.round(metric,4)} | auc pr: {np.round(pr_auc,4)} | ratio of the test set {np.round(df_test.TARGET.mean(),4)} | iteration: {lgbmodel.current_iteration()}")
    return -1*(metric)

# %%
res_gp = gp_minimize(var_to_minimize, 
                     param_space, n_calls=100,
                     random_state=0,n_random_starts=10)
# Out:
# 2021-01-13 20:52:03,662 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
# /u01/miniconda3/envs/uypo37/lib/python3.7/site-packages/skopt/optimizer/base.py:235: DeprecationWarning: n_random_starts will be removed in favour of n_initial_points. It overwrites n_initial_points.
#   DeprecationWarning)
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.4881255012149711, 'feature_fraction': 0.6, 'bagging_fraction': 0.6, 'num_leaves': 10, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.7337 | auc pr: 0.1084 | ratio of the test set 0.0039 | iteration: 1
# 2021-01-13 20:52:24,225 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.012984521643751776, 'feature_fraction': 0.4, 'bagging_fraction': 0.5, 'num_leaves': 13, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.8552 | auc pr: 0.1005 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 20:53:32,942 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.4700645792732058, 'feature_fraction': 0.4, 'bagging_fraction': 0.6, 'num_leaves': 7, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7974 | auc pr: 0.0598 | ratio of the test set 0.0039 | iteration: 48
# 2021-01-13 20:53:41,147 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.5497617455119916, 'feature_fraction': 0.5, 'bagging_fraction': 0.6, 'num_leaves': 9, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.732 | auc pr: 0.1054 | ratio of the test set 0.0039 | iteration: 1
# 2021-01-13 20:53:44,433 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.14589472312361856, 'feature_fraction': 0.5, 'bagging_fraction': 0.6, 'num_leaves': 4, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.8507 | auc pr: 0.0982 | ratio of the test set 0.0039 | iteration: 242
# 2021-01-13 20:54:13,048 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.2977394311301938, 'feature_fraction': 0.4, 'bagging_fraction': 0.4, 'num_leaves': 7, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.7939 | auc pr: 0.0423 | ratio of the test set 0.0039 | iteration: 46
# 2021-01-13 20:54:20,772 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05928952380648088, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'num_leaves': 10, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.8513 | auc pr: 0.0933 | ratio of the test set 0.0039 | iteration: 124
# 2021-01-13 20:54:46,928 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.8701981095758312, 'feature_fraction': 0.6, 'bagging_fraction': 0.4, 'num_leaves': 7, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.7079 | auc pr: 0.108 | ratio of the test set 0.0039 | iteration: 1
# 2021-01-13 20:54:50,289 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04467807553356735, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 15, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.8543 | auc pr: 0.0975 | ratio of the test set 0.0039 | iteration: 202
# 2021-01-13 20:55:16,516 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.9785863088320509, 'feature_fraction': 0.5, 'bagging_fraction': 0.5, 'num_leaves': 9, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.7335 | auc pr: 0.1078 | ratio of the test set 0.0039 | iteration: 1
# 2021-01-13 20:55:20,485 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'bagging_fraction': 0.4, 'num_leaves': 4, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8362 | auc pr: 0.0821 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 20:56:31,926 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05303843415534323, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.8485 | auc pr: 0.0836 | ratio of the test set 0.0039 | iteration: 372
# 2021-01-13 20:57:12,287 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.10557223007120442, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 10, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8508 | auc pr: 0.0822 | ratio of the test set 0.0039 | iteration: 102
# 2021-01-13 20:57:26,649 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 4, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8362 | auc pr: 0.0794 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 20:58:11,239 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.026584050909480704, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8565 | auc pr: 0.0999 | ratio of the test set 0.0039 | iteration: 413
# 2021-01-13 20:59:34,010 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02822913930855688, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 9, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.8546 | auc pr: 0.0935 | ratio of the test set 0.0039 | iteration: 429
# 2021-01-13 21:00:34,520 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.0631366819949667, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8474 | auc pr: 0.088 | ratio of the test set 0.0039 | iteration: 372
# 2021-01-13 21:01:06,695 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02467728533354832, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8574 | auc pr: 0.0986 | ratio of the test set 0.0039 | iteration: 352
# 2021-01-13 21:01:51,752 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.023525626823268475, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 5, 'min_child_weight': 9, 'num_threads': 28}
# auc roc: 0.8514 | auc pr: 0.0976 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:02:58,833 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.06815928390205146, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'num_leaves': 14, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.8551 | auc pr: 0.0911 | ratio of the test set 0.0039 | iteration: 171
# 2021-01-13 21:03:31,807 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.1116378003780368, 'feature_fraction': 0.7, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.8509 | auc pr: 0.0899 | ratio of the test set 0.0039 | iteration: 79
# 2021-01-13 21:03:51,471 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.21599943817449507, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8454 | auc pr: 0.0894 | ratio of the test set 0.0039 | iteration: 53
# 2021-01-13 21:04:03,813 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.024022311348816258, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 15, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.8572 | auc pr: 0.0992 | ratio of the test set 0.0039 | iteration: 339
# 2021-01-13 21:04:46,622 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.12109046242477894, 'feature_fraction': 0.4, 'bagging_fraction': 0.6, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8468 | auc pr: 0.0938 | ratio of the test set 0.0039 | iteration: 79
# 2021-01-13 21:05:01,159 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.040057718321482, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.852 | auc pr: 0.1007 | ratio of the test set 0.0039 | iteration: 197
# 2021-01-13 21:05:28,046 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.017258298492199974, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 4, 'num_threads': 28}
# auc roc: 0.8557 | auc pr: 0.0998 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:06:28,373 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.11641109707481102, 'feature_fraction': 0.5, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8536 | auc pr: 0.0911 | ratio of the test set 0.0039 | iteration: 73
# 2021-01-13 21:06:44,228 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.10272289169601596, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 5, 'num_threads': 28}
# auc roc: 0.8506 | auc pr: 0.0872 | ratio of the test set 0.0039 | iteration: 83
# 2021-01-13 21:06:57,699 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.015862561419911134, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.857 | auc pr: 0.1048 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:07:58,814 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.014610476741085239, 'feature_fraction': 0.4, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.8558 | auc pr: 0.0984 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:09:10,900 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.15431325838812057, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8462 | auc pr: 0.0795 | ratio of the test set 0.0039 | iteration: 127
# 2021-01-13 21:09:30,854 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05812602002420906, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 6, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8531 | auc pr: 0.0999 | ratio of the test set 0.0039 | iteration: 271
# 2021-01-13 21:10:00,337 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03489367598661428, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8554 | auc pr: 0.0981 | ratio of the test set 0.0039 | iteration: 262
# 2021-01-13 21:10:35,919 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 1.0, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7535 | auc pr: 0.0771 | ratio of the test set 0.0039 | iteration: 1
# 2021-01-13 21:10:41,224 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07610981221777405, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8587 | auc pr: 0.097 | ratio of the test set 0.0039 | iteration: 171
# 2021-01-13 21:11:05,169 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.30520143971820174, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8404 | auc pr: 0.0881 | ratio of the test set 0.0039 | iteration: 30
# 2021-01-13 21:11:13,473 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02250592207359092, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.853 | auc pr: 0.0986 | ratio of the test set 0.0039 | iteration: 341
# 2021-01-13 21:12:24,701 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.014042276192365793, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8548 | auc pr: 0.1033 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:13:25,213 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.17214396098031104, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8404 | auc pr: 0.0849 | ratio of the test set 0.0039 | iteration: 57
# 2021-01-13 21:13:36,530 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07983128433971093, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8528 | auc pr: 0.0985 | ratio of the test set 0.0039 | iteration: 139
# 2021-01-13 21:13:56,139 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 9, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7736 | auc pr: 0.0894 | ratio of the test set 0.0039 | iteration: 11
# 2021-01-13 21:14:01,611 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02791940080285092, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8548 | auc pr: 0.098 | ratio of the test set 0.0039 | iteration: 338
# 2021-01-13 21:14:43,177 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.0384722160385556, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 8, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.853 | auc pr: 0.1 | ratio of the test set 0.0039 | iteration: 319
# 2021-01-13 21:15:19,484 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.021668986795428606, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8427 | auc pr: 0.0781 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:16:01,122 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.3863782323581311, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8446 | auc pr: 0.0851 | ratio of the test set 0.0039 | iteration: 107
# 2021-01-13 21:16:13,549 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.09324229228342636, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8532 | auc pr: 0.0841 | ratio of the test set 0.0039 | iteration: 147
# 2021-01-13 21:16:33,754 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.094308869870482, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 7, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8502 | auc pr: 0.0879 | ratio of the test set 0.0039 | iteration: 156
# 2021-01-13 21:16:52,999 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.019272127030670445, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 13, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8569 | auc pr: 0.1019 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:17:52,389 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.036786166334996435, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 5, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8531 | auc pr: 0.1033 | ratio of the test set 0.0039 | iteration: 483
# 2021-01-13 21:19:05,963 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.09121102774716404, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 5, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.854 | auc pr: 0.0914 | ratio of the test set 0.0039 | iteration: 263
# 2021-01-13 21:19:47,369 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04726862137168723, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8543 | auc pr: 0.1008 | ratio of the test set 0.0039 | iteration: 235
# 2021-01-13 21:20:17,412 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.034403958363459386, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8556 | auc pr: 0.1004 | ratio of the test set 0.0039 | iteration: 261
# 2021-01-13 21:20:51,690 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.15325142855534243, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8497 | auc pr: 0.0841 | ratio of the test set 0.0039 | iteration: 168
# 2021-01-13 21:21:09,660 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.013178277884803526, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 8, 'num_threads': 28}
# auc roc: 0.8557 | auc pr: 0.0985 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:22:53,567 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.3442036819730317, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8478 | auc pr: 0.0856 | ratio of the test set 0.0039 | iteration: 160
# 2021-01-13 21:23:10,756 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.025079909820842107, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8566 | auc pr: 0.0963 | ratio of the test set 0.0039 | iteration: 352
# 2021-01-13 21:23:56,460 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.0717721795026786, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8524 | auc pr: 0.0923 | ratio of the test set 0.0039 | iteration: 95
# 2021-01-13 21:24:21,714 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05316286150416679, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8537 | auc pr: 0.1094 | ratio of the test set 0.0039 | iteration: 149
# 2021-01-13 21:24:43,704 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 14, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8534 | auc pr: 0.0979 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:25:46,172 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.027494281939993086, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'num_leaves': 7, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8522 | auc pr: 0.1012 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:27:06,856 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.15355228029335832, 'feature_fraction': 0.4, 'bagging_fraction': 0.4, 'num_leaves': 13, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8511 | auc pr: 0.0908 | ratio of the test set 0.0039 | iteration: 89
# 2021-01-13 21:27:23,727 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.031073717408139537, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 14, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8562 | auc pr: 0.1003 | ratio of the test set 0.0039 | iteration: 337
# 2021-01-13 21:28:06,928 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03644368869398604, 'feature_fraction': 0.3, 'bagging_fraction': 0.7, 'num_leaves': 10, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8525 | auc pr: 0.1057 | ratio of the test set 0.0039 | iteration: 291
# 2021-01-13 21:28:42,645 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01344918078418467, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.7297 | auc pr: 0.0752 | ratio of the test set 0.0039 | iteration: 28
# 2021-01-13 21:28:50,501 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02911249459954221, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 5, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8516 | auc pr: 0.0999 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:29:52,527 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01739638793069029, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8536 | auc pr: 0.0993 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:31:26,831 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.11213096278571226, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8487 | auc pr: 0.0805 | ratio of the test set 0.0039 | iteration: 236
# 2021-01-13 21:31:50,448 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02708055790158146, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8448 | auc pr: 0.0813 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:32:33,060 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.048186961594627396, 'feature_fraction': 0.5, 'bagging_fraction': 0.7, 'num_leaves': 7, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8549 | auc pr: 0.097 | ratio of the test set 0.0039 | iteration: 348
# 2021-01-13 21:33:22,617 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.025975838228939965, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8552 | auc pr: 0.0948 | ratio of the test set 0.0039 | iteration: 393
# 2021-01-13 21:34:40,356 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.04724691145526171, 'feature_fraction': 0.6, 'bagging_fraction': 0.7, 'num_leaves': 11, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8528 | auc pr: 0.1017 | ratio of the test set 0.0039 | iteration: 203
# 2021-01-13 21:35:18,027 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'bagging_fraction': 0.3, 'num_leaves': 7, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8464 | auc pr: 0.0917 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:36:44,972 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07282321857377942, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 5, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8519 | auc pr: 0.0977 | ratio of the test set 0.0039 | iteration: 251
# 2021-01-13 21:37:18,980 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.14487782691312723, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 8, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8527 | auc pr: 0.0874 | ratio of the test set 0.0039 | iteration: 74
# 2021-01-13 21:37:32,083 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 6, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8433 | auc pr: 0.0939 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:38:24,653 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.026162238081783813, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8572 | auc pr: 0.0986 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:39:25,518 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.166786243253721, 'feature_fraction': 0.3, 'bagging_fraction': 0.5, 'num_leaves': 11, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8479 | auc pr: 0.0938 | ratio of the test set 0.0039 | iteration: 50
# 2021-01-13 21:39:36,715 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8518 | auc pr: 0.1018 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:41:21,750 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.020025890526167794, 'feature_fraction': 0.7, 'bagging_fraction': 0.6, 'num_leaves': 9, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8522 | auc pr: 0.0956 | ratio of the test set 0.0039 | iteration: 429
# 2021-01-13 21:42:40,350 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.09479004423389437, 'feature_fraction': 0.7, 'bagging_fraction': 0.7, 'num_leaves': 3, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8463 | auc pr: 0.0922 | ratio of the test set 0.0039 | iteration: 293
# 2021-01-13 21:43:22,156 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.06557983465632461, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 12, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8538 | auc pr: 0.092 | ratio of the test set 0.0039 | iteration: 147
# 2021-01-13 21:43:43,973 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.12495773080951975, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 6, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8527 | auc pr: 0.083 | ratio of the test set 0.0039 | iteration: 120
# 2021-01-13 21:44:00,883 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.22529350621671318, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 3, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8445 | auc pr: 0.0951 | ratio of the test set 0.0039 | iteration: 165
# 2021-01-13 21:44:19,083 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02953735388794284, 'feature_fraction': 0.4, 'bagging_fraction': 0.7, 'num_leaves': 5, 'min_child_weight': 7, 'num_threads': 28}
# auc roc: 0.8529 | auc pr: 0.0961 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:45:15,386 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 11, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8504 | auc pr: 0.0977 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:46:15,937 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.03473002011904504, 'feature_fraction': 0.7, 'bagging_fraction': 0.6, 'num_leaves': 9, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8533 | auc pr: 0.1006 | ratio of the test set 0.0039 | iteration: 400
# 2021-01-13 21:47:26,677 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.021789175155520337, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 7, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8541 | auc pr: 0.0942 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:48:20,546 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.2113020550699375, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8467 | auc pr: 0.1008 | ratio of the test set 0.0039 | iteration: 62
# 2021-01-13 21:48:33,701 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07551597350380626, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.848 | auc pr: 0.0844 | ratio of the test set 0.0039 | iteration: 277
# 2021-01-13 21:49:01,212 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8533 | auc pr: 0.0988 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:50:05,100 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01, 'feature_fraction': 0.5, 'bagging_fraction': 0.3, 'num_leaves': 13, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8523 | auc pr: 0.0976 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:51:28,542 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.05758783412680835, 'feature_fraction': 0.6, 'bagging_fraction': 0.5, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8503 | auc pr: 0.0985 | ratio of the test set 0.0039 | iteration: 173
# 2021-01-13 21:52:03,426 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.1564449244023448, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 3, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8491 | auc pr: 0.0779 | ratio of the test set 0.0039 | iteration: 148
# 2021-01-13 21:52:20,922 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.07679756729177264, 'feature_fraction': 0.5, 'bagging_fraction': 0.6, 'num_leaves': 3, 'min_child_weight': 6, 'num_threads': 28}
# auc roc: 0.8472 | auc pr: 0.0896 | ratio of the test set 0.0039 | iteration: 317
# 2021-01-13 21:52:58,412 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.01844844806190629, 'feature_fraction': 0.3, 'bagging_fraction': 0.6, 'num_leaves': 15, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8554 | auc pr: 0.1038 | ratio of the test set 0.0039 | iteration: 415
# 2021-01-13 21:53:52,631 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.2159459712295118, 'feature_fraction': 0.7, 'bagging_fraction': 0.5, 'num_leaves': 4, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8513 | auc pr: 0.0915 | ratio of the test set 0.0039 | iteration: 168
# 2021-01-13 21:54:21,680 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.06182333378927391, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 8, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8542 | auc pr: 0.0982 | ratio of the test set 0.0039 | iteration: 235
# 2021-01-13 21:54:51,572 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.029569732399638973, 'feature_fraction': 0.3, 'bagging_fraction': 0.3, 'num_leaves': 3, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8461 | auc pr: 0.0818 | ratio of the test set 0.0039 | iteration: 500
# 2021-01-13 21:55:36,521 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.024652870706253046, 'feature_fraction': 0.7, 'bagging_fraction': 0.6, 'num_leaves': 11, 'min_child_weight': 3, 'num_threads': 28}
# auc roc: 0.8543 | auc pr: 0.106 | ratio of the test set 0.0039 | iteration: 487
# 2021-01-13 21:57:06,318 - aa_engine_pkg.assets.utils.utilities - INFO - [TRAIN_MODEL] Training model
#
# Next set of params..... {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['auc'], 'seed': 9520, 'learning_rate': 0.02189076654358042, 'feature_fraction': 0.3, 'bagging_fraction': 0.4, 'num_leaves': 15, 'min_child_weight': 10, 'num_threads': 28}
# auc roc: 0.8582 | auc pr: 0.1009 | ratio of the test set 0.0039 | iteration: 472

# %%
"Best score=%.4f" % res_gp.fun
# Out:
# 'Best score=-0.8587'

# %% [markdown]
# ### 3. Training model with the best params

# %%
model_parameters= {
    "boosting_type": res_gp.x[0],
    "objective": "binary",
    "metric": ["auc"],
    "seed": 9520,
    "learning_rate": res_gp.x[1],
    "feature_fraction": res_gp.x[2]/10,
    "bagging_fraction": res_gp.x[3]/10,
    "num_leaves": res_gp.x[4],
    "min_child_weight": res_gp.x[5],
    "num_threads": n_threads}
model_parameters
# Out:
# {'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'metric': ['auc'],
#  'seed': 9520,
#  'learning_rate': 0.07610981221777405,
#  'feature_fraction': 0.3,
#  'bagging_fraction': 0.3,
#  'num_leaves': 15,
#  'min_child_weight': 10,
#  'num_threads': 28}

# %%
#Default params
model_parameters= {
    "boosting_type": "gbdt",
    "objective": model_type,
    "seed": 9520,
    "learning_rate": 0.050,
    "metric": ["auc"],
    "feature_fraction": 0.7,
    "bagging_fraction": 0.4,
    "num_leaves": 15,
    "min_child_weight": 16,
    "num_threads": n_threads}
model_parameters

# %%
eval_results = {}
cb_evaluation = lgbm.record_evaluation(eval_results)
lgbmodel = lgbm.train(model_parameters,
                      xlgb_train,
                      valid_sets=valid_sets,
                      early_stopping_rounds=10,
                      verbose_eval=10,
                      num_boost_round=500,
                      callbacks=[cb_evaluation])
preds=lgbmodel.predict(df_test[vars_to_model])
metric=skmetrics.roc_auc_score(df_test[target_var], preds)

p, r, _=skmetrics.precision_recall_curve(df_test[target_var], preds)
pr_auc=skmetrics.auc(r,p)

print(f"TEST auc roc: {np.round(metric,4)} | auc pr: {np.round(pr_auc,4)} | ratio of the test set {np.round(df_test.TARGET.mean(),4)} | iteration: {lgbmodel.current_iteration()}")
# Out:
# Training until validation scores don't improve for 10 rounds
# [10]	training's auc: 0.825282	valid_1's auc: 0.806369
# [20]	training's auc: 0.846905	valid_1's auc: 0.824529
# [30]	training's auc: 0.859325	valid_1's auc: 0.834871
# [40]	training's auc: 0.866138	valid_1's auc: 0.838568
# [50]	training's auc: 0.872909	valid_1's auc: 0.841426
# [60]	training's auc: 0.879239	valid_1's auc: 0.844672
# [70]	training's auc: 0.884737	valid_1's auc: 0.846479
# [80]	training's auc: 0.889474	valid_1's auc: 0.848287
# [90]	training's auc: 0.893838	valid_1's auc: 0.84941
# [100]	training's auc: 0.897282	valid_1's auc: 0.849885
# [110]	training's auc: 0.90058	valid_1's auc: 0.850653
# [120]	training's auc: 0.903359	valid_1's auc: 0.851814
# [130]	training's auc: 0.906052	valid_1's auc: 0.852069
# [140]	training's auc: 0.908678	valid_1's auc: 0.852271
# [150]	training's auc: 0.910989	valid_1's auc: 0.853112
# [160]	training's auc: 0.913752	valid_1's auc: 0.853355
# [170]	training's auc: 0.915757	valid_1's auc: 0.853558
# [180]	training's auc: 0.918447	valid_1's auc: 0.853416
# Early stopping, best iteration is:
# [171]	training's auc: 0.916161	valid_1's auc: 0.853845
# TEST auc roc: 0.8587 | auc pr: 0.097 | ratio of the test set 0.0039 | iteration: 171

# %%
# Create model path
model_format = datetime.strftime(datetime.today(), "%Y%m%d_%H%M")
model_folder = f"{model_path}{model_format}_{model}_{model_type}_model/"

if not os.path.exists(model_folder):
    os.makedirs(model_folder)

importance_lgbm = lgbmodel.feature_importance(importance_type="gain")
df_importance_lgbm = pd.DataFrame(
    {'column': list(df_train[vars_to_model].columns),
     'importance_gain': importance_lgbm})
df_importance_lgbm.sort_values('importance_gain', ascending=False, axis=0, inplace=True)
df_importance_lgbm['importance_gain'] = df_importance_lgbm['importance_gain'] / \
                                        df_importance_lgbm['importance_gain'].sum()
# Export variable importance
df_importance_lgbm.to_csv(model_folder + model_format + "_important_variables.csv", sep=";", decimal=".", index=False)

print(df_importance_lgbm.head(30))

export_auc_graph(df_train=df_train,
                 df_dev=df_dev,
                 df_test=df_test,
                 model=lgbmodel,
                 vars_to_model=vars_to_model,
                 target_var=target_var,
                 file_path=model_folder + model_format + "_auc.png",
                 multiclass=False)
# Out:
#                                    column  importance_gain
# 753         SAC_N_CONT_CAT_0801_nansum_28         0.087541
# 476           AQY_PROP_DISCOUNT_nanmean_1         0.050213
# 257                   CLI_PROVINCIA_SALTO         0.044286
# 516           AQY_PROP_DISCOUNT_nanmean_3         0.030633
# 97    EVE_CAT_COMBINED_100142_3_nansum_28         0.026070
# 519   EVE_CAT_COMBINED_100142_5_nansum_84         0.023301
# 881   EVE_CAT_COMBINED_OTHER_3_nansum_336         0.022870
# 396                    AQY_ARPU_nanmean_1         0.022657
# 692  EVE_CAT_COMBINED_200142_5_nansum_336         0.020550
# 414   EVE_CAT_COMBINED_OTHER_3_nansum_252         0.018022
# 230   SAC_N_CONT_SUBCAT_1207042_nansum_84         0.015459
# 206                    AQY_ARPU_nanmean_6         0.015377
# 375                         EOP_N_PREMIUM         0.014369
# 327           AQY_PROP_DISCOUNT_nanmean_6         0.014013
# 729   EVE_CAT_COMBINED_100142_3_nansum_84         0.013664
# 896      CAM_DAYS_TO_END_OFFER_nanmax_336         0.012949
# 918                         EOP_N_TECH_10         0.012756
# 172                         EOP_N_TECH_25         0.012557
# 335     EVE_CAT_COMBINED_108_3_nansum_252         0.012305
# 160  EVF_BALANCE_BROUGHT_FORWARD_nanmin_6         0.011342
# 561                    AQY_RATIO_ARPU_1_6         0.008754
# 183      EVE_CAT_COMBINED_108_3_nansum_28         0.008108
# 270               CLI_PROVINCIA_CANELONES         0.008014
# 716         SAC_N_CONT_CAT_1207_nansum_28         0.007698
# 878                    AQY_ARPU_nanmean_3         0.007609
# 922     EVE_CAT_COMBINED_108_3_nansum_168         0.007564
# 615   SAC_N_CONT_SUBCAT_1207042_nansum_28         0.007398
# 232      EVE_CAT_COMBINED_108_3_nansum_21         0.007190
# 633   EVE_CAT_COMBINED_OTHER_3_nansum_168         0.006765
# 795  EVF_BALANCE_BROUGHT_FORWARD_nanmin_5         0.006110

# %%
# Export model performance
export_model_performance_lgbm(model=lgbmodel,
                              vars_to_include=vars_to_model,
                              target_var=target_var,
                              id_var=id_vars,
                              period_var=period_vars,
                              score_var=score_var,
                              df=df_train,
                              table_name="train",
                              model_folder=model_folder,
                              model_format=model_format,
                              export_df=False)
export_model_performance_lgbm(model=lgbmodel,
                              vars_to_include=vars_to_model,
                              target_var=target_var,
                              id_var=id_vars,
                              period_var=period_vars,
                              score_var=score_var,
                              df=df_dev,
                              table_name="dev",
                              model_folder=model_folder,
                              model_format=model_format,
                              export_df=False)

export_model_performance_lgbm(model=lgbmodel,
                              vars_to_include=vars_to_model,
                              target_var=target_var,
                              id_var=id_vars,
                              period_var=period_vars,
                              score_var=score_var,
                              df=df_test,
                              table_name="test",
                              model_folder=model_folder,
                              model_format=model_format,
                              export_df=True,
                              N=20)

df_explore = df_test.copy()
df_explore[score_var] = lgbmodel.predict(df_test[vars_to_model])

df_summary = variable_avg_by_ntile(df_explore,
                                   N=10,
                                   score_col=score_var,
                                   feature_importance=df_importance_lgbm)

df_summary.to_csv(model_folder + model_format + "_summary.csv", sep=";", decimal=",", index=False)

# Export volumes
df_volume = get_model_volumes(df_train=df_train,
                              df_dev=df_dev,
                              df_test=df_test,
                              period_var="DATE_CALC",
                              target_var=target_var)
df_volume.to_csv(model_folder + model_format + "_volumes.csv", sep=";", decimal=",", index=False)

# Save parameteres
save_json(model_parameters, model_folder + model_format + "_model_parameters.json")

df = []
vars_to_analyze = df_importance_lgbm[df_importance_lgbm["importance_gain"] > 0]["column"].values.tolist()

df_list = [df_train[period_vars + vars_to_analyze],
           df_dev[period_vars + vars_to_analyze],
           df_test[period_vars + vars_to_analyze]]
df = pd.concat(df_list)
df = df.groupby(period_vars).agg(np.nanmean).T.reset_index().rename(columns={"index": "column"})
df = pd.merge(df, df_importance_lgbm, on="column", how="inner")
df.to_csv(model_folder + model_format + "_mean_evolution.csv", sep=";", decimal=",")

# Calculate NaN evolution
df = []
vars_to_analyze = df_importance_lgbm[df_importance_lgbm["importance_gain"] > 0]["column"].values.tolist()

df_list = [df_train[period_vars + vars_to_analyze],
           df_dev[period_vars + vars_to_analyze],
           df_test[period_vars + vars_to_analyze]]
df = pd.concat(df_list)
df = df.groupby(period_vars).agg(lambda x: x.isnull().sum()/len(x)).T.reset_index().rename(columns={"index": "column"})
df = pd.merge(df, df_importance_lgbm, on="column", how="inner")
df.to_csv(model_folder + model_format + "_nan_evolution.csv", sep=";", decimal=",")

# Calculate NaNs by decile
df_explore = get_ntile(df_explore,
                       N=10,
                       score_col=score_var,
                       ntile_col="DECIL")

df_explore_grouped = df_explore[period_vars + vars_to_analyze + ["DECIL"]].groupby("DECIL").agg(lambda x: x.isnull().sum()/len(x)
                                                                                               ).T.reset_index(
                                                                                               ).rename(columns={"index": "column"})

df_explore_grouped = pd.merge(df_explore_grouped, df_importance_lgbm, on="column", how="inner")
df_explore_grouped.to_csv(model_folder + model_format + "_nan_summary.csv", sep=";", decimal=",")

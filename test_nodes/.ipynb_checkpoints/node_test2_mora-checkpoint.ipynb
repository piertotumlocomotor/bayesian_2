# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")

from aa_engine_pkg.assets.utils import *
from aa_engine_pkg.assets.core.data.kedro.catalog_expansion.partitioned_sql import SQLPartitionedDataSet

# %%
def create_cliente_activo(cliente_activo: SQLPartitionedDataSet,
                          date: str) -> pd.DataFrame:
    """Creates master table with features related to EoP state of customers for one period of data

    Parameters
    ----------
    cliente_activo:
        dataset defined in ´catalog.yml´ - list of active customers at EoP for the given period
    date:
        period to process
    
    Returns
    -------
        Mastertable with information of clientes at EoP
    """

    # Initialize logger
    log = initialize_logger()

    # Load active clientes for period
    log.info(f"Creating cliente_activo...")
    period_to_load = get_previous_month(date)
    df_clientes_activos = cliente_activo.filter_by(date=period_to_load)

    # Return
    return df_clientes_activos

# %%
past_periods = [14, 28, 84, 168]

string_vars = ["ESTADOWO", "SUBSTYPENAME"]

expand_vars = ["FLAG_CORPORATIVOS", "FLAG_COMPLETED", "TIME_TO_COMPLETE", "FECHA_CREACION", "CUSTOMER_ID", "ID"]

categories_dict = {"SERVICIO_ID": ["S", "IA", "SC"],
                   "DEALER_WO_ID": ["PERSONAL", "MIXER", "UNIVISION", "GLOBAL", "TIME"]}

vars_to_dummy = ["SERVICIO_ID", "DEALER_WO_ID", "ESTADOWO_ID", "SUBSTYPENAME_ID"]

# %%
def create_master_mantenimiento(mantenimiento: SQLPartitionedDataSet,
                                cliente_activo: pd.DataFrame,
                                parameters: Dict,
                                date: str) -> pd.DataFrame:
    """Creates master table with features related to interactions with call center for one period of data
    Parameters
    ----------
    cliente_activo: 
        dataset defined in ``catalog_raw.yml`` - list of active customers at EoP for the given period
    mantenimiento:
        dataset defined in ``catalog_raw.yml`` with raw data information related to work orders
    date: 
        period to process
    parameters: 
        set of project parameters defined in ``parameters.yml``
    Returns
    -------
    pd.DataFrame
        Master table with call center interactions features for one period
    """

    # Initialize logger
    log = initialize_logger()

    write_to_parquet = parameters["write_to_parquet"]
    table_name = "mantenimiento"
    overwrite = parameters["masters"][table_name]["overwrite"]

    # Check if table was already created
    files = get_mastertable_paths_by_period(parameters=parameters, period=date)
    match = [str(file) for file in files if table_name in file]

    if len(match) > 0 and overwrite is False:
        # If table is found, read parquet:
        log.info(f"Reading {match[0]} table")
        df_master_mantenimiento = pd.read_parquet(match[0], engine="pyarrow")

    else:
        log.info("Creating master table mantenimiento")

        # Read parameters
        lookback_days = parameters["masters"]["global"]["look_back_days"]
        start_date = pd.to_datetime(date) - timedelta(days=lookback_days)

        # Calculate period to load for active clients
        log.info("Loading EoP clients...")
        period_to_load = get_previous_month(date)
        df_clientes = cliente_activo[["CUSTOMER_ID"]]

        # Get mantenimiento table
        log.info("Loading Mantenimiento table...")
        df_m = mantenimiento.filter_by(date=[start_date.strftime("%Y%m%d"),
                                             date])

        # Merging
        log.info("Merging Mantenimiento with EoP table...")
        df_m = df_clientes.merge(df_m,
                                 on="CUSTOMER_ID",
                                 how="inner",
                                 validate="1:m")

        # Format string variables
        df_m["SERVICIO_ID"] = df_m["SERVICIO"].str.extract(r'([a-zA-Z]+)\d+')
        log.info("Formatting varibles...")
        for var in string_vars:
            new_name = var + "_ID"
            df_m[new_name] = df_m[var].str.split("-").str[0].str.strip()

        # Format string variables
        new_name = "DEALER_WO" + "_ID"
        df_m[new_name] = df_m["DEALER_WO"].str.split(" ").str[1]

        # Format date variable
        df_m["FECHA_CREACION"] = df_m["FECHA_CREACION"].dt.strftime("%Y%m%d")

        # Flags and time to completion of WO
        condition = (df_m["KEYWORD"] == "EC-CORPORATIVOS")
        df_m['FLAG_CORPORATIVOS'] = np.where(condition, 1, 0)
        df_m['FLAG_COMPLETED'] = np.where(df_m['COMPLETED_DATE_TIME'], 0, 1)
        df_m["TIME_TO_COMPLETE"] = (df_m['COMPLETED_DATE_TIME'] - pd.to_datetime(
            df_m["FECHA_CREACION"])) / np.timedelta64(1, "D")

        # Flatten by customer_id and date

        df_comp = df_m[expand_vars]
        df_flatten = df_comp.groupby(["CUSTOMER_ID", "FECHA_CREACION"]).agg({"FLAG_CORPORATIVOS": np.nansum,
                                                                             "TIME_TO_COMPLETE": np.nanmax,
                                                                             "ID": "nunique"}).reset_index()
        df_flatten.rename(columns={"FLAG_CORPORATIVOS": "N_CORPORATIVOS",
                                   "TIME_TO_COMPLETE": "DAYS_TO_COMPLETE",
                                   "ID": "N_WO"}
                          , inplace=True)

        log.info("Creating past variables...")
        df_past = add_relative_calculate_past(df=df_flatten,
                                              id_cols=["CUSTOMER_ID"],
                                              periods=past_periods,
                                              agg={"N_CORPORATIVOS": np.nansum,
                                                   "N_WO": np.nansum,
                                                   "DAYS_TO_COMPLETE": [np.nanmin, np.nanmax]},
                                              date_col="FECHA_CREACION",
                                              start_date=start_date,
                                              end_date=date,
                                              period_freq="D")
        # Impute categories
        impute_categories(df_m,
                          "SERVICIO_ID",
                          categories_dict["SERVICIO_ID"]
                          )

        impute_categories(df_m,
                          "DEALER_WO_ID",
                          categories_dict["DEALER_WO_ID"]
                          )

        log.info("Creating dummy variables...")
        df = []
        for var in vars_to_dummy:
            log.info(f'---- {var}')
            df.append(create_dummy_variables(df=df_m,
                                             vars_to_groupby=["CUSTOMER_ID", "FECHA_CREACION"],
                                             var_to_dummy=var,
                                             include_total=False,
                                             include_subtotal=False))

        mantenimiento_dummies = reduce(
            lambda left, right: pd.merge(left, right, on=["CUSTOMER_ID", "FECHA_CREACION"], how="outer"), df)

        # Create expanded variables
        log.info("Creating past variables...")
        df_num = add_relative_calculate_past(df=mantenimiento_dummies,
                                             id_cols=["CUSTOMER_ID"],
                                             periods=past_periods,
                                             agg=[np.nansum],
                                             date_col="FECHA_CREACION",
                                             start_date=start_date,
                                             end_date=date,
                                             period_freq="D")

        # Merging
        log.info("Merging the two past variables tables...")
        df_master_mantenimiento = df_past.merge(df_num,
                                                on="CUSTOMER_ID",
                                                how="inner",
                                                validate="1:1")

        # Add date variables
        df_master_mantenimiento["DATE_EXP"] = period_to_load
        df_master_mantenimiento["DATE_CALC"] = date
        id_cols = ["CUSTOMER_ID", "DATE_EXP", "DATE_CALC"]

        # Change variable names 
        table_preffix = parameters["masters"]["mantenimiento"]["table_preffix"]
        rename_table(df_master_mantenimiento,
                     preffix=table_preffix,
                     ids_to_exclude=id_cols)
        log.info(f"Exporting {df_master_mantenimiento.shape[0]} rows and {df_master_mantenimiento.shape[1]} columns")

        if write_to_parquet:
            log.info(f"\n------ Writing {table_name} for period {date} to parquet ------")
            file = f"{parameters['paths']['master_path']}master_{table_name}/master_{table_name}_{date}.parquet"
            df_master_mantenimiento.to_parquet(file, engine="pyarrow")

        log.info(f"Exporting {df_master_mantenimiento.shape[0]} rows and {df_master_mantenimiento.shape[1]} columns")

    return df_master_mantenimiento

# %%
cliente_activo=catalog.load("cliente_activo")
mantenimiento=catalog.load("mantenimiento")
# Out:
# 2020-12-30 19:33:55,069 - kedro.io.data_catalog - INFO - Loading data from `cliente_activo` (SQLPartitionedDataSet)...
# 2020-12-30 19:33:55,071 - kedro.io.data_catalog - INFO - Loading data from `mantenimiento` (SQLPartitionedDataSet)...

# %%
dates = calculate_dates_to_process_for_master(parameters, table_name="mantenimiento")
print(dates)
# Out:
# ['20181203', '20181231', '20190128', '20190225', '20190325', '20190422']

# %%
for date in dates:
    print(f"Processing date {date}")
    cliente_activo_df= create_cliente_activo(cliente_activo,date)
    create_master_mantenimiento(mantenimiento,cliente_activo_df,parameters,date)
# Out:
# Processing date 20181203
# 2020-12-30 19:34:01,449 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# /u01/miniconda3/envs/uypo37/lib/python3.7/site-packages/sqlalchemy/dialects/oracle/base.py:1381: SAWarning: Oracle version (19, 5, 0, 0, 0) is known to have a maximum identifier length of 128, rather than the historical default of 30. SQLAlchemy 1.4 will use 128 for this database; please set max_identifier_length=128 in create_engine() in order to test the application with this new length, or set to 30 in order to assure that 30 continues to be used.  In particular, pay close attention to the behavior of database migrations as dynamically generated names may change. See the section 'Max Identifier Lengths' in the SQLAlchemy Oracle dialect documentation for background.
#   % ((self.server_version_info,))
# 2020-12-30 19:34:04,678 - aa_engine_pkg.assets.utils.utilities - INFO - Creating master table mantenimiento
# 2020-12-30 19:34:04,679 - aa_engine_pkg.assets.utils.utilities - INFO - Loading EoP clients...
# 2020-12-30 19:34:04,682 - aa_engine_pkg.assets.utils.utilities - INFO - Loading Mantenimiento table...
# select CUSTOMER_ID, DATE_EXP, ID, FECHA_CREACION, ESTADOWO, COMPLETED_DATE_TIME, SHUSERNR, SUBSTYPENAME, PROVINCIA, KEYWORD, SERVICIO, DEALER_WO from stg_uy_mantenimiento where FECHA_CREACION >= to_date('20180618', 'yyyymmdd') and FECHA_CREACION < to_date('20181203', 'yyyymmdd')
# 2020-12-30 19:34:08,537 - aa_engine_pkg.assets.utils.utilities - INFO - Merging Mantenimiento with EoP table...
# 2020-12-30 19:34:08,913 - aa_engine_pkg.assets.utils.utilities - INFO - Formatting varibles...
# 2020-12-30 19:34:09,820 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:09,821 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-06-18 00:00:00 and 20181203
# 2020-12-30 19:34:09,841 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:09,856 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:09,872 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:09,895 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:10,124 - aa_engine_pkg.assets.utils.utilities - INFO - Creating dummy variables...
# 2020-12-30 19:34:10,125 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SERVICIO_ID
# 2020-12-30 19:34:10,173 - aa_engine_pkg.assets.utils.utilities - INFO - ---- DEALER_WO_ID
# 2020-12-30 19:34:10,210 - aa_engine_pkg.assets.utils.utilities - INFO - ---- ESTADOWO_ID
# 2020-12-30 19:34:10,245 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SUBSTYPENAME_ID
# 2020-12-30 19:34:10,319 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:10,321 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-06-18 00:00:00 and 20181203
# 2020-12-30 19:34:10,341 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:10,371 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:10,404 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:10,451 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:10,659 - aa_engine_pkg.assets.utils.utilities - INFO - Merging the two past variables tables...
# 2020-12-30 19:34:10,701 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 27504 rows and 55 columns
# 2020-12-30 19:34:10,702 - aa_engine_pkg.assets.utils.utilities - INFO -
# ------ Writing mantenimiento for period 20181203 to parquet ------
# 2020-12-30 19:34:10,832 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 27504 rows and 55 columns
# Processing date 20181231
# 2020-12-30 19:34:10,863 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# 2020-12-30 19:34:15,243 - aa_engine_pkg.assets.utils.utilities - INFO - Creating master table mantenimiento
# 2020-12-30 19:34:15,244 - aa_engine_pkg.assets.utils.utilities - INFO - Loading EoP clients...
# 2020-12-30 19:34:15,246 - aa_engine_pkg.assets.utils.utilities - INFO - Loading Mantenimiento table...
# select CUSTOMER_ID, DATE_EXP, ID, FECHA_CREACION, ESTADOWO, COMPLETED_DATE_TIME, SHUSERNR, SUBSTYPENAME, PROVINCIA, KEYWORD, SERVICIO, DEALER_WO from stg_uy_mantenimiento where FECHA_CREACION >= to_date('20180716', 'yyyymmdd') and FECHA_CREACION < to_date('20181231', 'yyyymmdd')
# 2020-12-30 19:34:17,627 - aa_engine_pkg.assets.utils.utilities - INFO - Merging Mantenimiento with EoP table...
# 2020-12-30 19:34:17,971 - aa_engine_pkg.assets.utils.utilities - INFO - Formatting varibles...
# 2020-12-30 19:34:18,739 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:18,741 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-07-16 00:00:00 and 20181231
# 2020-12-30 19:34:18,765 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:18,778 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:18,794 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:18,816 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:18,995 - aa_engine_pkg.assets.utils.utilities - INFO - Creating dummy variables...
# 2020-12-30 19:34:18,996 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SERVICIO_ID
# 2020-12-30 19:34:19,030 - aa_engine_pkg.assets.utils.utilities - INFO - ---- DEALER_WO_ID
# 2020-12-30 19:34:19,060 - aa_engine_pkg.assets.utils.utilities - INFO - ---- ESTADOWO_ID
# 2020-12-30 19:34:19,089 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SUBSTYPENAME_ID
# 2020-12-30 19:34:19,158 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:19,159 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-07-16 00:00:00 and 20181231
# 2020-12-30 19:34:19,177 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:19,211 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:19,242 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:19,286 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:19,466 - aa_engine_pkg.assets.utils.utilities - INFO - Merging the two past variables tables...
# 2020-12-30 19:34:19,500 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24742 rows and 55 columns
# 2020-12-30 19:34:19,500 - aa_engine_pkg.assets.utils.utilities - INFO -
# ------ Writing mantenimiento for period 20181231 to parquet ------
# 2020-12-30 19:34:19,599 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24742 rows and 55 columns
# Processing date 20190128
# 2020-12-30 19:34:19,625 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201812
# 2020-12-30 19:34:22,189 - aa_engine_pkg.assets.utils.utilities - INFO - Creating master table mantenimiento
# 2020-12-30 19:34:22,191 - aa_engine_pkg.assets.utils.utilities - INFO - Loading EoP clients...
# 2020-12-30 19:34:22,193 - aa_engine_pkg.assets.utils.utilities - INFO - Loading Mantenimiento table...
# select CUSTOMER_ID, DATE_EXP, ID, FECHA_CREACION, ESTADOWO, COMPLETED_DATE_TIME, SHUSERNR, SUBSTYPENAME, PROVINCIA, KEYWORD, SERVICIO, DEALER_WO from stg_uy_mantenimiento where FECHA_CREACION >= to_date('20180813', 'yyyymmdd') and FECHA_CREACION < to_date('20190128', 'yyyymmdd')
# 2020-12-30 19:34:24,470 - aa_engine_pkg.assets.utils.utilities - INFO - Merging Mantenimiento with EoP table...
# 2020-12-30 19:34:24,822 - aa_engine_pkg.assets.utils.utilities - INFO - Formatting varibles...
# 2020-12-30 19:34:25,588 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:25,589 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-08-13 00:00:00 and 20190128
# 2020-12-30 19:34:25,608 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:25,628 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:25,643 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:25,666 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:25,845 - aa_engine_pkg.assets.utils.utilities - INFO - Creating dummy variables...
# 2020-12-30 19:34:25,846 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SERVICIO_ID
# 2020-12-30 19:34:25,880 - aa_engine_pkg.assets.utils.utilities - INFO - ---- DEALER_WO_ID
# 2020-12-30 19:34:25,910 - aa_engine_pkg.assets.utils.utilities - INFO - ---- ESTADOWO_ID
# 2020-12-30 19:34:25,940 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SUBSTYPENAME_ID
# 2020-12-30 19:34:26,009 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:26,010 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-08-13 00:00:00 and 20190128
# 2020-12-30 19:34:26,028 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:26,056 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:26,087 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:26,131 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:26,306 - aa_engine_pkg.assets.utils.utilities - INFO - Merging the two past variables tables...
# 2020-12-30 19:34:26,338 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24669 rows and 55 columns
# 2020-12-30 19:34:26,339 - aa_engine_pkg.assets.utils.utilities - INFO -
# ------ Writing mantenimiento for period 20190128 to parquet ------
# 2020-12-30 19:34:26,440 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24669 rows and 55 columns
# Processing date 20190225
# 2020-12-30 19:34:26,465 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201901
# 2020-12-30 19:34:28,428 - aa_engine_pkg.assets.utils.utilities - INFO - Creating master table mantenimiento
# 2020-12-30 19:34:28,430 - aa_engine_pkg.assets.utils.utilities - INFO - Loading EoP clients...
# 2020-12-30 19:34:28,432 - aa_engine_pkg.assets.utils.utilities - INFO - Loading Mantenimiento table...
# select CUSTOMER_ID, DATE_EXP, ID, FECHA_CREACION, ESTADOWO, COMPLETED_DATE_TIME, SHUSERNR, SUBSTYPENAME, PROVINCIA, KEYWORD, SERVICIO, DEALER_WO from stg_uy_mantenimiento where FECHA_CREACION >= to_date('20180910', 'yyyymmdd') and FECHA_CREACION < to_date('20190225', 'yyyymmdd')
# 2020-12-30 19:34:30,236 - aa_engine_pkg.assets.utils.utilities - INFO - Merging Mantenimiento with EoP table...
# 2020-12-30 19:34:30,591 - aa_engine_pkg.assets.utils.utilities - INFO - Formatting varibles...
# 2020-12-30 19:34:31,366 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:31,368 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-09-10 00:00:00 and 20190225
# 2020-12-30 19:34:31,386 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:31,400 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:31,415 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:31,437 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:31,615 - aa_engine_pkg.assets.utils.utilities - INFO - Creating dummy variables...
# 2020-12-30 19:34:31,617 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SERVICIO_ID
# 2020-12-30 19:34:31,651 - aa_engine_pkg.assets.utils.utilities - INFO - ---- DEALER_WO_ID
# 2020-12-30 19:34:31,681 - aa_engine_pkg.assets.utils.utilities - INFO - ---- ESTADOWO_ID
# 2020-12-30 19:34:31,712 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SUBSTYPENAME_ID
# 2020-12-30 19:34:31,781 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:31,782 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-09-10 00:00:00 and 20190225
# 2020-12-30 19:34:31,800 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:31,831 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:31,865 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:31,913 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:32,096 - aa_engine_pkg.assets.utils.utilities - INFO - Merging the two past variables tables...
# 2020-12-30 19:34:32,133 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24376 rows and 59 columns
# 2020-12-30 19:34:32,134 - aa_engine_pkg.assets.utils.utilities - INFO -
# ------ Writing mantenimiento for period 20190225 to parquet ------
# 2020-12-30 19:34:32,240 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24376 rows and 59 columns
# Processing date 20190325
# 2020-12-30 19:34:32,267 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201902
# 2020-12-30 19:34:36,243 - aa_engine_pkg.assets.utils.utilities - INFO - Creating master table mantenimiento
# 2020-12-30 19:34:36,244 - aa_engine_pkg.assets.utils.utilities - INFO - Loading EoP clients...
# 2020-12-30 19:34:36,247 - aa_engine_pkg.assets.utils.utilities - INFO - Loading Mantenimiento table...
# select CUSTOMER_ID, DATE_EXP, ID, FECHA_CREACION, ESTADOWO, COMPLETED_DATE_TIME, SHUSERNR, SUBSTYPENAME, PROVINCIA, KEYWORD, SERVICIO, DEALER_WO from stg_uy_mantenimiento where FECHA_CREACION >= to_date('20181008', 'yyyymmdd') and FECHA_CREACION < to_date('20190325', 'yyyymmdd')
# 2020-12-30 19:34:38,529 - aa_engine_pkg.assets.utils.utilities - INFO - Merging Mantenimiento with EoP table...
# 2020-12-30 19:34:38,872 - aa_engine_pkg.assets.utils.utilities - INFO - Formatting varibles...
# 2020-12-30 19:34:39,633 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:39,634 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-10-08 00:00:00 and 20190325
# 2020-12-30 19:34:39,658 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:39,672 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:39,688 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:39,710 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:39,894 - aa_engine_pkg.assets.utils.utilities - INFO - Creating dummy variables...
# 2020-12-30 19:34:39,895 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SERVICIO_ID
# 2020-12-30 19:34:39,930 - aa_engine_pkg.assets.utils.utilities - INFO - ---- DEALER_WO_ID
# 2020-12-30 19:34:39,960 - aa_engine_pkg.assets.utils.utilities - INFO - ---- ESTADOWO_ID
# 2020-12-30 19:34:39,991 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SUBSTYPENAME_ID
# 2020-12-30 19:34:40,067 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:40,068 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-10-08 00:00:00 and 20190325
# 2020-12-30 19:34:40,090 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:40,125 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:40,160 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:40,210 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:40,400 - aa_engine_pkg.assets.utils.utilities - INFO - Merging the two past variables tables...
# 2020-12-30 19:34:40,434 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24368 rows and 59 columns
# 2020-12-30 19:34:40,435 - aa_engine_pkg.assets.utils.utilities - INFO -
# ------ Writing mantenimiento for period 20190325 to parquet ------
# 2020-12-30 19:34:40,537 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24368 rows and 59 columns
# Processing date 20190422
# 2020-12-30 19:34:40,563 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201903
# 2020-12-30 19:34:43,083 - aa_engine_pkg.assets.utils.utilities - INFO - Creating master table mantenimiento
# 2020-12-30 19:34:43,084 - aa_engine_pkg.assets.utils.utilities - INFO - Loading EoP clients...
# 2020-12-30 19:34:43,087 - aa_engine_pkg.assets.utils.utilities - INFO - Loading Mantenimiento table...
# select CUSTOMER_ID, DATE_EXP, ID, FECHA_CREACION, ESTADOWO, COMPLETED_DATE_TIME, SHUSERNR, SUBSTYPENAME, PROVINCIA, KEYWORD, SERVICIO, DEALER_WO from stg_uy_mantenimiento where FECHA_CREACION >= to_date('20181105', 'yyyymmdd') and FECHA_CREACION < to_date('20190422', 'yyyymmdd')
# 2020-12-30 19:34:46,664 - aa_engine_pkg.assets.utils.utilities - INFO - Merging Mantenimiento with EoP table...
# 2020-12-30 19:34:47,004 - aa_engine_pkg.assets.utils.utilities - INFO - Formatting varibles...
# 2020-12-30 19:34:47,761 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:47,762 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-11-05 00:00:00 and 20190422
# 2020-12-30 19:34:47,781 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:47,800 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:47,815 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:47,838 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:48,016 - aa_engine_pkg.assets.utils.utilities - INFO - Creating dummy variables...
# 2020-12-30 19:34:48,017 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SERVICIO_ID
# 2020-12-30 19:34:48,051 - aa_engine_pkg.assets.utils.utilities - INFO - ---- DEALER_WO_ID
# 2020-12-30 19:34:48,081 - aa_engine_pkg.assets.utils.utilities - INFO - ---- ESTADOWO_ID
# 2020-12-30 19:34:48,112 - aa_engine_pkg.assets.utils.utilities - INFO - ---- SUBSTYPENAME_ID
# 2020-12-30 19:34:48,180 - aa_engine_pkg.assets.utils.utilities - INFO - Creating past variables...
# 2020-12-30 19:34:48,181 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 2018-11-05 00:00:00 and 20190422
# 2020-12-30 19:34:48,199 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 19:34:48,232 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 19:34:48,268 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 19:34:48,321 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 19:34:48,517 - aa_engine_pkg.assets.utils.utilities - INFO - Merging the two past variables tables...
# 2020-12-30 19:34:48,552 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24360 rows and 63 columns
# 2020-12-30 19:34:48,553 - aa_engine_pkg.assets.utils.utilities - INFO -
# ------ Writing mantenimiento for period 20190422 to parquet ------
# 2020-12-30 19:34:48,656 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 24360 rows and 63 columns

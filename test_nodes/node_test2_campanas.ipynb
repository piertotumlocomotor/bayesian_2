# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")

from aa_engine_pkg.assets.utils import *
from aa_engine_pkg.assets.core.data.kedro.catalog_expansion.partitioned_sql import SQLPartitionedDataSet

# %%
def create_cliente_activo(cliente_activo: SQLPartitionedDataSet,
                          date: str) -> pd.DataFrame:
    """Creates master table with features related to EoP state of customers for one period of data

    Parameters
    ----------
    cliente_activo:
        dataset defined in ´catalog.yml´ - list of active customers at EoP for the given period
    date:
        period to process
    
    Returns
    -------
        Mastertable with information of clientes at EoP
    """

    # Initialize logger
    log = initialize_logger()

    # Load active clientes for period
    log.info(f"Creating cliente_activo...")
    period_to_load = get_previous_month(date)
    df_clientes_activos = cliente_activo.filter_by(date=period_to_load)

    # Return
    return df_clientes_activos

# %%
vars_to_dummy = ["OFERTA_COMBINADA"]

past_periods = [14, 21, 28, 84, 168, 252, 336]

# %%
def create_master_campanas(campanas: SQLPartitionedDataSet,
                           cliente_activo: pd.DataFrame,
                           parameters: Union[Dict, None],
                           date: str
                           ) -> pd.DataFrame:
    """Creates master table with offer features for one period of data
    Parameters
    ----------
    campanas:
        dataset defined in ``catalog_raw.yml`` with raw data information related to client's offers
    cliente_activo:
        dataset defined in ``catalog_raw.yml`` with raw data information related to active clients at EoP
    date:
        period to process
    parameters:
        set of project parameters defined in ``parameters.yml``
    Returns
    -------
    pd.DataFrame
        Master table with offer features for one period
    """

    # Read parameters
    log = initialize_logger()

    write_to_parquet = parameters["write_to_parquet"]
    table_name = "campanas"
    overwrite = parameters["masters"][table_name]["overwrite"]

    # Check if table was already created
    files = get_mastertable_paths_by_period(parameters=parameters, period=date)
    match = [str(file) for file in files if table_name in file]

    if len(match) > 0 and overwrite is False:
        # If table is found, read parquet:
        log.info(f"Reading {match[0]} table")
        df_final = pd.read_parquet(match[0], engine="pyarrow")

    else:
        # Read parameters
        log = initialize_logger()
        look_back_days = parameters["masters"]["campanas"]["look_back_days"]
        start_date = (pd.to_datetime(date) - timedelta(days=look_back_days)).strftime("%Y%m%d")

        # Calculate period to load for active clients
        period_to_load = get_previous_month(date)
        log.info(f"Loading campanas...")
        df_campanas = campanas.filter_by(date=[start_date, date]).drop_duplicates()

        df_clientes = cliente_activo

        df_campanas = pd.merge(df_clientes,
                               df_campanas,
                               on=["CUSTOMER_ID"],
                               how="inner")

        log.info("Creating variables...")
        # Calculate offer duration / days since start / until end
        df_campanas['OFFER_DURATION'] = (pd.to_datetime(df_campanas.END_DATE,
                                                        errors="coerce") - df_campanas.START_DATE) / np.timedelta64(1,
                                                                                                                    "D")
        df_campanas["DAYS_SINCE_START_OFFER"] = (pd.to_datetime(date) - df_campanas.START_DATE) / np.timedelta64(1, "D")
        df_campanas["DAYS_TO_END_OFFER"] = (pd.to_datetime(df_campanas.END_DATE, errors="coerce") - pd.to_datetime(
            date)) / np.timedelta64(1, "D")

        # Extract percentages of offers from their description
        df_campanas["PORC_OFFER"] = df_campanas["DESCRIPTION"].str.extract(r'(\d+)%')[0].astype(float)

        # Extract discount values of offers from their description
        df_campanas["VALUE_OFFER"] = df_campanas["DESCRIPTION"].str.extract(r'\$(\d+)')[0].astype(float)

        # Make a mask with position of values
        maskvalue = df_campanas["VALUE_OFFER"].notna()
        maskporc = df_campanas["PORC_OFFER"].notna()

        # Create a unique ranking scaled for Percentage and value
        maskall = dict(zip(["VALUE_OFFER", "PORC_OFFER"],
                           (maskvalue, maskporc)))
        for var, mask in maskall.items():
            df_campanas.loc[mask, "MONTO_OFFER_SCALED"] = scale_values(df=df_campanas.loc[mask, :],
                                                                       vars_to_groupby=["DATE_EXP"],
                                                                       var_to_scale=var,
                                                                       by_ranking=False)

            # Extract length of offer from their description
        tuple_len = df_campanas["DESCRIPTION"].str.extract(r'(?:(\d+)[ ]*M|(\d+)X)', re.IGNORECASE)[[0, 1]].fillna(
            0).astype(int)
        df_campanas["LENGTH_OFFER"] = tuple_len.sum(axis=1)

        # creo la variable tipo_oferta
        condlist = [df_campanas["DESCRIPTION"].str.upper().str.contains("DSCTO|RET|DESC", na=False),
                    df_campanas["DESCRIPTION"].str.upper().str.contains("RENTA", na=False),
                    df_campanas["DESCRIPTION"].str.upper().str.contains("UPGRADE", na=False),
                    df_campanas["DESCRIPTION"].str.upper().str.contains("NUEVO", na=False),
                    df_campanas["DESCRIPTION"].str.upper().str.contains("RECON")
                    ]
        choicelist = ["RETE",
                      "RENT",
                      "UPGR",
                      "NUEV",
                      "RECO"]
        df_campanas["TIPO_OFERTA"] = np.select(condlist, choicelist, default="OTROS")

        # creo variable tipo de producto de la oferta
        condlist = [df_campanas["DESCRIPTION"].str.upper().str.contains(
            "PREMIUM|FOX|HBO|EXXXOTICO|HOTPACK|ADULT|CLAXON|HUSTLER", na=False),
                    df_campanas["DESCRIPTION"].str.upper().str.contains("PLATA|ORO|BRONCE|SICO", na=False),
                    df_campanas["DESCRIPTION"].str.upper().str.contains("BUNDLE", na=False),
                    df_campanas["DESCRIPTION"].str.upper().str.contains("NET", na=False),
                    ]
        choicelist = ["PREMIUM",
                      "BASICO",
                      "BUNDLE",
                      "NET"]
        df_campanas["PRODUCTO_OFERTA"] = np.select(condlist, choicelist, default="OTROS")

        df_campanas["OFERTA_COMBINADA"] = df_campanas["TIPO_OFERTA"] + "_" + df_campanas["PRODUCTO_OFERTA"]
        df_campanas["FECHA"] = df_campanas["START_DATE"].dt.strftime("%Y%m%d")

        # creo las variables dummy
        df_list = []
        for var in vars_to_dummy:
            log.info(f'---- {var}')
            df_list.append(group_categorical_variables(df_campanas,
                                                       vars_to_groupby=["CUSTOMER_ID", "FECHA"],
                                                       var_to_count=var,
                                                       other_category=None))

        # Reduce list of list to create a data table
        df = reduce(lambda left, right: pd.merge(left, right, on=["CUSTOMER_ID", "FECHA"], how="outer"), df_list)

        ofer_cols = [c for c in df.columns if "OFERTA" in c]

        df["N_OFERTAS"] = df[ofer_cols].sum(axis=1)

        # Join with num vars and expand
        df_expanded_offers = add_relative_calculate_past(df=df_campanas[["CUSTOMER_ID",
                                                                         "FECHA",
                                                                         "DAYS_SINCE_START_OFFER",
                                                                         "DAYS_TO_END_OFFER",
                                                                         "LENGTH_OFFER",
                                                                         "MONTO_OFFER_SCALED"]],
                                                         id_cols=["CUSTOMER_ID"],
                                                         periods=past_periods,
                                                         agg=[np.nanmean, np.nanmin, np.nanmax],
                                                         date_col="FECHA",
                                                         start_date=start_date,
                                                         end_date=date,
                                                         period_freq="D")

        # Join with num vars and expand
        df_expanded_products = add_relative_calculate_past(df=df,
                                                           id_cols=["CUSTOMER_ID"],
                                                           periods=past_periods,
                                                           agg=[np.nansum],
                                                           date_col="FECHA",
                                                           start_date=start_date,
                                                           end_date=date,
                                                           period_freq="D")

        # Merge
        df_final = df_expanded_products.merge(df_expanded_offers, on="CUSTOMER_ID", validate="1:1")

        # Add date variables
        df_final["DATE_EXP"] = period_to_load
        df_final["DATE_CALC"] = date

        # Rename table
        rename_table(df=df_final,
                     preffix=parameters["masters"]["campanas"]["table_preffix"],
                     ids_to_exclude=["CUSTOMER_ID", "DATE_EXP", "DATE_CALC"]
                     )

        # Return
        log.info(f"Exporting {df_final.shape[0]} rows and {df_final.shape[1]} columns")

        if write_to_parquet:
            file = f"{parameters['paths']['master_path']}master_{table_name}/master_{table_name}_{date}.parquet"
            df_final.to_parquet(file, engine="pyarrow")

    return df_final

# %%
cliente_activo=catalog.load("cliente_activo")
campanas= catalog.load("campanas")
# Out:
# 2020-12-30 12:14:42,462 - kedro.io.data_catalog - INFO - Loading data from `cliente_activo` (SQLPartitionedDataSet)...
# 2020-12-30 12:14:42,464 - kedro.io.data_catalog - INFO - Loading data from `campanas` (SQLPartitionedDataSet)...

# %%
dates = calculate_dates_to_process_for_master(parameters, table_name="campanas")

# %%
for date in dates:
    print(f"Processing date {date}")
    cliente_activo_df= create_cliente_activo(cliente_activo,date)
    create_master_campanas(campanas,cliente_activo_df,parameters,date)
# Out:
# Processing date 20181203
# 2020-12-30 12:15:32,848 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# /u01/miniconda3/envs/uypo37/lib/python3.7/site-packages/sqlalchemy/dialects/oracle/base.py:1381: SAWarning: Oracle version (19, 5, 0, 0, 0) is known to have a maximum identifier length of 128, rather than the historical default of 30. SQLAlchemy 1.4 will use 128 for this database; please set max_identifier_length=128 in create_engine() in order to test the application with this new length, or set to 30 in order to assure that 30 continues to be used.  In particular, pay close attention to the behavior of database migrations as dynamically generated names may change. See the section 'Max Identifier Lengths' in the SQLAlchemy Oracle dialect documentation for background.
#   % ((self.server_version_info,))
# 2020-12-30 12:15:37,188 - aa_engine_pkg.assets.utils.utilities - INFO - Loading campanas...
# select * from stg_uy_campana where START_DATE >= to_date('20180101', 'yyyymmdd') and START_DATE < to_date('20181203', 'yyyymmdd')
# 2020-12-30 12:15:50,230 - aa_engine_pkg.assets.utils.utilities - INFO - Creating variables...
# 2020-12-30 12:15:51,667 - numexpr.utils - INFO - Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2020-12-30 12:15:51,668 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.
# 2020-12-30 12:15:58,704 - aa_engine_pkg.assets.utils.utilities - INFO - ---- OFERTA_COMBINADA
# 2020-12-30 12:15:59,340 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180101 and 20181203
# 2020-12-30 12:15:59,427 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:15:59,464 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:15:59,508 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:15:59,560 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:15:59,662 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:15:59,828 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:16:00,040 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:16:00,779 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180101 and 20181203
# 2020-12-30 12:16:00,843 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:16:00,882 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:16:00,926 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:16:00,976 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:16:01,060 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:16:01,182 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:16:01,331 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:16:01,976 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 72352 rows and 150 columns
# Processing date 20181231
# 2020-12-30 12:16:02,547 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# 2020-12-30 12:16:06,830 - aa_engine_pkg.assets.utils.utilities - INFO - Loading campanas...
# select * from stg_uy_campana where START_DATE >= to_date('20180129', 'yyyymmdd') and START_DATE < to_date('20181231', 'yyyymmdd')
# 2020-12-30 12:16:15,806 - aa_engine_pkg.assets.utils.utilities - INFO - Creating variables...
# 2020-12-30 12:16:24,637 - aa_engine_pkg.assets.utils.utilities - INFO - ---- OFERTA_COMBINADA
# 2020-12-30 12:16:25,263 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180129 and 20181231
# 2020-12-30 12:16:25,415 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:16:25,446 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:16:25,483 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:16:25,529 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:16:25,625 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:16:25,782 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:16:25,983 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:16:26,673 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180129 and 20181231
# 2020-12-30 12:16:26,742 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:16:26,777 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:16:26,817 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:16:26,862 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:16:26,940 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:16:27,060 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:16:27,207 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:16:27,857 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 73076 rows and 150 columns
# Processing date 20190128
# 2020-12-30 12:16:28,402 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201812
# 2020-12-30 12:16:31,064 - aa_engine_pkg.assets.utils.utilities - INFO - Loading campanas...
# select * from stg_uy_campana where START_DATE >= to_date('20180226', 'yyyymmdd') and START_DATE < to_date('20190128', 'yyyymmdd')
# 2020-12-30 12:16:42,823 - aa_engine_pkg.assets.utils.utilities - INFO - Creating variables...
# 2020-12-30 12:16:52,002 - aa_engine_pkg.assets.utils.utilities - INFO - ---- OFERTA_COMBINADA
# 2020-12-30 12:16:52,659 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180226 and 20190128
# 2020-12-30 12:16:52,816 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:16:52,848 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:16:52,893 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:16:52,944 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:16:53,047 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:16:53,209 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:16:53,414 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:16:54,145 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180226 and 20190128
# 2020-12-30 12:16:54,216 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:16:54,255 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:16:54,302 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:16:54,357 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:16:54,446 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:16:54,579 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:16:54,744 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:16:55,411 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 74284 rows and 157 columns
# Processing date 20190225
# 2020-12-30 12:16:55,985 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201901
# 2020-12-30 12:16:59,722 - aa_engine_pkg.assets.utils.utilities - INFO - Loading campanas...
# select * from stg_uy_campana where START_DATE >= to_date('20180326', 'yyyymmdd') and START_DATE < to_date('20190225', 'yyyymmdd')
# 2020-12-30 12:17:08,766 - aa_engine_pkg.assets.utils.utilities - INFO - Creating variables...
# 2020-12-30 12:17:18,224 - aa_engine_pkg.assets.utils.utilities - INFO - ---- OFERTA_COMBINADA
# 2020-12-30 12:17:18,907 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180326 and 20190225
# 2020-12-30 12:17:19,067 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:17:19,100 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:17:19,141 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:17:19,193 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:17:19,298 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:17:19,457 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:17:19,661 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:17:20,417 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180326 and 20190225
# 2020-12-30 12:17:20,491 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:17:20,533 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:17:20,579 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:17:20,635 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:17:20,729 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:17:20,862 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:17:21,027 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:17:21,713 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 74624 rows and 157 columns
# Processing date 20190325
# 2020-12-30 12:17:22,303 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201902
# 2020-12-30 12:17:24,166 - aa_engine_pkg.assets.utils.utilities - INFO - Loading campanas...
# select * from stg_uy_campana where START_DATE >= to_date('20180423', 'yyyymmdd') and START_DATE < to_date('20190325', 'yyyymmdd')
# 2020-12-30 12:17:33,833 - aa_engine_pkg.assets.utils.utilities - INFO - Creating variables...
# 2020-12-30 12:17:43,757 - aa_engine_pkg.assets.utils.utilities - INFO - ---- OFERTA_COMBINADA
# 2020-12-30 12:17:44,460 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180423 and 20190325
# 2020-12-30 12:17:44,628 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:17:44,663 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:17:44,705 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:17:44,762 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:17:44,874 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:17:45,037 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:17:45,246 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:17:46,004 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180423 and 20190325
# 2020-12-30 12:17:46,085 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:17:46,126 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:17:46,174 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:17:46,232 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:17:46,333 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:17:46,470 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:17:46,632 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:17:47,323 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 74774 rows and 157 columns
# Processing date 20190422
# 2020-12-30 12:17:47,938 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201903
# 2020-12-30 12:17:49,824 - aa_engine_pkg.assets.utils.utilities - INFO - Loading campanas...
# select * from stg_uy_campana where START_DATE >= to_date('20180521', 'yyyymmdd') and START_DATE < to_date('20190422', 'yyyymmdd')
# 2020-12-30 12:17:59,732 - aa_engine_pkg.assets.utils.utilities - INFO - Creating variables...
# 2020-12-30 12:18:09,946 - aa_engine_pkg.assets.utils.utilities - INFO - ---- OFERTA_COMBINADA
# 2020-12-30 12:18:10,673 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180521 and 20190422
# 2020-12-30 12:18:10,845 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:18:10,877 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:18:10,917 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:18:10,969 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:18:11,080 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:18:11,248 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:18:11,455 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:18:12,268 - aa_engine_pkg.assets.utils.utilities - INFO - Adding relative date between 20180521 and 20190422
# 2020-12-30 12:18:12,344 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 14
# 2020-12-30 12:18:12,383 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 21
# 2020-12-30 12:18:12,428 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 28
# 2020-12-30 12:18:12,483 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 84
# 2020-12-30 12:18:12,584 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 168
# 2020-12-30 12:18:12,726 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 252
# 2020-12-30 12:18:12,888 - aa_engine_pkg.assets.utils.utilities - INFO - Expanding table for period: 336
# 2020-12-30 12:18:13,571 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting 75067 rows and 157 columns

# %% [markdown]
# ### The shap_values object
# is a list with two arrays. The first array is the SHAP values for a negative outcome, and the second array is the list of SHAP values for the positive outcome. We typically think about predictions in terms of the prediction of a positive outcome, so we'll pull out SHAP values for positive outcomes (**pulling out shap_values[1]**)

# %%
import shap
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
current_dir = Path("/u01/share/cesar/aa_engine_co/notebooks/04_features")
proj_path = current_dir.parent.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")
from re import search
from aa_engine_pkg.assets.utils import *

from datetime import datetime
from scipy.ndimage import gaussian_filter1d
import os
from lime.lime_tabular import LimeTabularExplainer
import shap
import numpy as np
import pandas as pd
import re
import plotly.graph_objects as go
import math
import seaborn as sns
import waterfall_chart


from aa_engine_pkg.assets.utils import *
pd.set_option('display.max_columns', 100)

# Initialize logger
log = logging.getLogger(__name__)

# %%
# Loading parameters
model = "upsell"
model_type = "binary"
if model == "":
    model = parameters["models"]["model"]
if model_type == "":
    model = parameters["models"][model]["model_type"]
id_var = parameters["models"][model][model_type]["id_vars"]
period_var = parameters["models"][model][model_type]["period_vars"]
score_var = parameters["models"][model][model_type]["score_var"]

# %%
def load_explainability_input(model:str,
                              model_type:str,
                              parameters):

    # Load parameters
    model_path = parameters["paths"]["model_path"]
    n_threads = parameters["models"]["n_threads"]
    target_var = parameters["models"][model][model_type]["target_var"]
    score_var = parameters["models"][model][model_type]["score_var"]
    fill_na_with = parameters["models"][model][model_type]["fill_na_with"]
    model_format = parameters["models"][model][model_type]["model_to_load"]
    print(model_path + model_format + f"_{model}_{model_type}_model/")
    if type(fill_na_with) == str:
        fill_na_with = eval(fill_na_with)

    # Set model file
    model_folder = model_path + model_format + f"_{model}_{model_type}_model/"

    # Load model
    lgbmodel = lgbm.Booster(model_file=model_folder + model_format + ".txt")

    # Load data
    aux = pd.read_csv(model_folder + model_format + "_volumes.csv", sep=";", decimal=",")
    periods_to_load = aux.loc[aux["SET"]=="TEST",period_var[0]].astype(str).unique().tolist()
    df = load_and_merge_tables(model=model,
                               model_type=model_type,
                               periods=periods_to_load,
                               parameters=parameters,
                               load_subsample=False,
                               load_target=True)
    print(df.shape)

    df = add_selected_variables(df, lgbmodel.feature_name(), fill_na_with)
    df=df[lgbmodel.feature_name()].copy()
    
    df[score_var] = lgbmodel.predict(df)
    df.sort_values(score_var, inplace=True)

    # Return lime input
    return lgbmodel, df

# %%
def generate_output_dependence_plot(shap_values ,x_train, number_of_top_variables,sample_size,path=None):
    
    vars_=[var for var in df.columns if var not in ["SCORE"]]
    x_train = df.loc[:,vars_].sample(sample_size,random_state=42)
    top_inds = np.argsort(-np.sum(np.abs(np.array(shap_values)), 0))
    
    for i in np.arange(0, number_of_top_variables):
        variable_selected = x_train.columns[top_inds[i]]
        print('Iterating SHAP values for variable {}'.format(variable_selected))
        index_ = x_train[variable_selected] <= x_train[variable_selected].quantile(0.95)
        train=x_train.loc[index_]
        shap_=shap_values[np.where(index_)]
        shap.dependence_plot(variable_selected,shap_values[x_train.index],x_train,feature_names=train.columns,xmax="percentile(0.95)",interaction_index=None,show=False)
        plt.title("{} plot".format(variable_selected))
        plt.ylabel("Score contribution for the \n {} feature".format(variable_selected))
        aux_dt = pd.DataFrame({'variable_value':x_train[variable_selected].values,
                               'Shap':shap_values[x_train.index,np.where(np.array(x_train.columns) == variable_selected)][0]})
        aux_dt.sort_values(by='variable_value', inplace=True)
        ysmoothed = gaussian_filter1d(aux_dt['Shap'], sigma=5)
        plt.plot(aux_dt['variable_value'], ysmoothed, 'g-', linewidth=4)
        #aux_dt.to_csv(f'/u01/share/cesar/others/shap_values_curves/{variable_selected}.csv')

# %%
def shap_values_and_explaner(df,model_obj):
    
    # Calculate the explainer
    explainerModel = shap.TreeExplainer(model=model_obj, model_output="raw")
    explainerModel.model.original_model.params["objective"] = "binary"
    
    # Calculate the shap values
    shap_values = explainerModel.shap_values(df[model_obj.feature_name()])[1]
    # mean rate
    mean_rate = explainerModel.expected_value[1]
    
    return explainerModel,shap_values, mean_rate

# %%
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %%
def closest_node(node, nodes):
    nodes = np.asarray(nodes)
    dist_2 = np.nansum((nodes - node)**2, axis=1)
    return  np.where(dist_2==min(dist_2))

# %% [markdown]
# ### Load data for analysis

# %%
lgbmodel, df = load_explainability_input(model,model_type,parameters)
# Out:
# /data/co_po/models/20201120_1239_upsell_binary_model/
# 2020-12-11 17:47:47,259 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200406
# 2020-12-11 17:47:49,840 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200504
# 2020-12-11 17:47:53,244 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200601
# 2020-12-11 17:47:57,042 - aa_engine_pkg.assets.utils.utilities - INFO - Loading 20200629
# (586543, 1194)
# ['CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_84', 'CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_28', 'CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_21', 'CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_168', 'CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_336', 'CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_252', 'MAN_SUBSTYPENAME_ID_E_nansum_28', 'MAN_SUBSTYPENAME_ID_E_nansum_168', 'MAN_SUBSTYPENAME_ID_E_nansum_84', 'MAN_SUBSTYPENAME_ID_E_nansum_14', 'CAM_OFERTA_COMBINADA_NUEV_BASICO_nansum_14'] not found in df

# %%
117/3
# Out:
# 39.0

# %% [markdown]
# ### Calculate, the shap values, TreeExplainer and meam risk

# %%
explainerModel,shap_values, mean_rate = shap_values_and_explaner(df,lgbmodel)
# Out:
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray

# %% [markdown]
# ### Top 10 variables Shap values vs variable values

# %%
vars_=[var for var in df.columns if var not in ["SCORE"]]
top_inds = np.argsort(-np.sum(np.abs(np.array(shap_values)), 0))

# %%
i=7
variable_selected = df.columns[top_inds[i]]
print(f'variable: {variable_selected}')
# Out:
# variable: CAM_OFERTA_COMBINADA_OTROS_BUNDLE_nansum_336

# %%
aux_df = pd.DataFrame({f'{variable_selected}':df[variable_selected].values,
                       'shap_value':shap_values[:,np.where(np.array(df.columns) == variable_selected)[0][0]]})
index_ =aux_df[f'{variable_selected}'] <= aux_df[f'{variable_selected}'].quantile(0.95)
aux_df=aux_df.loc[index_].copy()
#aux_df[f'{variable_selected}'].fillna(-1,inplace=True)
smooth=aux_df.groupby([f'{variable_selected}']).agg({'shap_value':'median'}).reset_index()

# %%
ax = sns.stripplot(x=f"{variable_selected}", y="shap_value",color=(.25,.5,.75),data=aux_df,alpha=0.25)
#ax=sns.scatterplot(x=f"{variable_selected}", y="shap_value",color=(.25,.5,.75),data=aux_df,alpha=0.5)
plt.plot(smooth[f"{variable_selected}"], smooth["shap_value"], 'g-', linewidth=4)
plt.ylabel(f"Score contribution for the \n {variable_selected} feature")
plt.title(f"{variable_selected} plot")
path='/u01/share/cesar/others/shap_values_curves/'
filename = datetime.today().strftime("%Y%m%d") + f"_SHAP_plot_{variable_selected}.png"
plt.savefig(os.path.join(path, filename),bbox_inches ='tight')

# %%
print(f'Range of the score {df.SCORE.min()} {df.SCORE.max()}')
# Out:
# Range of the score 0.0001598041108472328 0.15529938230131318

# %% [markdown]
# ### Shap values for bucket of clientes

# %%
df["ventile"]=pd.qcut(-df.SCORE,20,labels=list(range(1,21)))
df["order"]= list(range(len(df.index)))

# %%
df.SCORE.hist(bins=100)
plt.axvline(df.SCORE.mean(), color = 'r', linestyle = 'dashed', linewidth = 1)
plt.title(f'Mean score value X={np.round(df.SCORE.mean(),6)}')
# Out:
# Text(0.5, 1.0, 'Mean score value X=0.002685')

# %%
#Best clients by ventil
best_clientes_by_ventil=df.sort_values('SCORE',ascending=False).groupby(["ventile"]).head(1)

# %%
best_clientes_by_ventil.head()
# Out:
#         EVF_MONTO_nanmin_1  SAC_N_CONT_CH_DIR_OUT_nansum_28  \
# 92231             0.710546                              0.0
# 16979             0.470836                              NaN
# 8153              0.405107                              0.0
# 128107            0.676071                              2.0
# 11566             0.850763                              NaN
#
#         FAC_N_REINTEGROS_sum_14  CAM_OFERTA_COMBINADA_NUEV_NET_nansum_14  \
# 92231                       NaN                                      NaN
# 16979                       NaN                                      NaN
# 8153                        3.0                                      NaN
# 128107                      3.0                                      NaN
# 11566                       7.0                                      NaN
#
#         ECH_DISPOSITION_DESC_ANSWERED_nansum_7  \
# 92231                                      1.0
# 16979                                      NaN
# 8153                                       NaN
# 128107                                     NaN
# 11566                                      NaN
#
#         SAC_N_CONT_SUBCAT_0102001_nansum_7  EOP_MOP_ANTICIPADO  \
# 92231                                  NaN                 0.0
# 16979                                  NaN                 0.0
# 8153                                   NaN                 0.0
# 128107                                 NaN                 0.0
# 11566                                  NaN                 0.0
#
#         CAM_DAYS_TO_END_OFFER_nanmax_252  FAC_MONTO_TOTAL_nanmin_56  \
# 92231                               33.0                   0.663101
# 16979                                NaN                   0.450676
# 8153                                80.0                   0.390271
# 128107                               NaN                   0.484142
# 11566                              -36.0                   0.243403
#
#         EVE_CAT_COMBINED_133_7_nansum_252  FAC_CATEGORIA_ID_O_nansum_28  \
# 92231                                 0.0                           2.0
# 16979                                 0.0                           1.0
# 8153                                  0.0                           0.0
# 128107                                0.0                           1.0
# 11566                                 1.0                           0.0
#
#         EOP_N_TECH_25  FAC_PCT_CHG_MONTO_TOTAL_84_56  \
# 92231             0.0                       1.000000
# 16979             0.0                       1.250796
# 8153              2.0                       0.822805
# 128107            1.0                       0.945684
# 11566             1.0                       0.979456
#
#         SAC_N_CONT_CAT_1202_nansum_84  \
# 92231                             3.0
# 16979                             0.0
# 8153                              0.0
# 128107                            2.0
# 11566                             2.0
#
#         CAM_OFERTA_COMBINADA_OTROS_OTROS_nansum_336  \
# 92231                                           0.0
# 16979                                           NaN
# 8153                                            1.0
# 128107                                          0.0
# 11566                                           0.0
#
#         ECH_DISPOSITION_DESC_ANSWERED_nansum_14  \
# 92231                                       3.0
# 16979                                       NaN
# 8153                                        NaN
# 128107                                      NaN
# 11566                                       NaN
#
#         SAC_N_CONT_CAT_0111_nansum_28  \
# 92231                             0.0
# 16979                             NaN
# 8153                              0.0
# 128107                            0.0
# 11566                             NaN
#
#         ECH_DISPOSITION_DESC_CONNECTED_nansum_84  \
# 92231                                        0.0
# 16979                                        NaN
# 8153                                         NaN
# 128107                                       0.0
# 11566                                        0.0
#
#         EVE_CAT_COMBINED_108_OTHER_nansum_336  \
# 92231                                     0.0
# 16979                                     0.0
# 8153                                      0.0
# 128107                                    0.0
# 11566                                     0.0
#
#         EVE_CAT_COMBINED_105245_1_nansum_168  FAC_CATEGORIA_ID_A_nansum_7  \
# 92231                                    0.0                          NaN
# 16979                                    0.0                          NaN
# 8153                                     1.0                          NaN
# 128107                                   NaN                          0.0
# 11566                                    0.0                          0.0
#
#         SAC_N_CONT_CH_OTHER_nansum_168  \
# 92231                              0.0
# 16979                              0.0
# 8153                               0.0
# 128107                             0.0
# 11566                              0.0
#
#         EVE_CAT_COMBINED_200142_OTHER_nansum_168  \
# 92231                                        0.0
# 16979                                        0.0
# 8153                                         0.0
# 128107                                       NaN
# 11566                                        0.0
#
#         EVE_CAT_COMBINED_133_5_nansum_21  FAC_CATEGORIA_ID_P_nansum_56  \
# 92231                                NaN                           0.0
# 16979                                NaN                           2.0
# 8153                                 NaN                           4.0
# 128107                               NaN                           0.0
# 11566                                NaN                           0.0
#
#         EVE_CAT_COMBINED_OTHER_1_nansum_252  \
# 92231                                   2.0
# 16979                                   0.0
# 8153                                    3.0
# 128107                                  0.0
# 11566                                   0.0
#
#         EVE_CAT_COMBINED_133_1_nansum_336  \
# 92231                                 0.0
# 16979                                 0.0
# 8153                                  0.0
# 128107                                0.0
# 11566                                 0.0
#
#         CAM_OFERTA_COMBINADA_RETE_NET_nansum_252  \
# 92231                                        0.0
# 16979                                        NaN
# 8153                                         0.0
# 128107                                       NaN
# 11566                                        0.0
#
#         SAC_N_CONT_CAT_0804_nansum_168  \
# 92231                              0.0
# 16979                              0.0
# 8153                               0.0
# 128107                             0.0
# 11566                              0.0
#
#         CAM_OFERTA_COMBINADA_RETE_PREMIUM_nansum_21  \
# 92231                                           NaN
# 16979                                           NaN
# 8153                                            NaN
# 128107                                          NaN
# 11566                                           NaN
#
#         EVE_CAT_COMBINED_OTHER_7_nansum_28  FAC_MONTO_nanmin_84  \
# 92231                                  0.0             0.447510
# 16979                                  NaN             0.576129
# 8153                                   NaN             0.470485
# 128107                                 NaN             0.562859
# 11566                                  NaN             0.451814
#
#         EVE_CAT_COMBINED_105245_1_nansum_14  \
# 92231                                   NaN
# 16979                                   NaN
# 8153                                    NaN
# 128107                                  NaN
# 11566                                   NaN
#
#         EVE_CAT_COMBINED_105245_OTHER_nansum_336  \
# 92231                                        0.0
# 16979                                        0.0
# 8153                                         0.0
# 128107                                       0.0
# 11566                                        0.0
#
#         EVE_CAT_COMBINED_105245_7_nansum_28  MAN_SERVICIO_ID_SC_nansum_28  \
# 92231                                   0.0                           NaN
# 16979                                   NaN                           NaN
# 8153                                    NaN                           NaN
# 128107                                  NaN                           0.0
# 11566                                   NaN                           NaN
#
#         EVE_CAT_COMBINED_100142_OTHER_nansum_28  \
# 92231                                       0.0
# 16979                                       NaN
# 8153                                        NaN
# 128107                                      NaN
# 11566                                       NaN
#
#         SAC_N_CONT_SUBCAT_0102002_nansum_7  CAM_DAYS_TO_END_OFFER_nanmean_84  \
# 92231                                  NaN                              33.0
# 16979                                  NaN                               NaN
# 8153                                   NaN                               NaN
# 128107                                 NaN                               NaN
# 11566                                  NaN                               NaN
#
#         EVE_CAT_COMBINED_100142_7_nansum_168  \
# 92231                                    0.0
# 16979                                    0.0
# 8153                                     0.0
# 128107                                   NaN
# 11566                                    0.0
#
#         MOR_MORA_151_180_scaled_nanmax_168  ECH_DURATION_mean_nanmean_28  \
# 92231                                  NaN                   1099.566650
# 16979                                  0.0                           NaN
# 8153                                   0.0                           NaN
# 128107                                 0.0                   1917.733276
# 11566                                  0.0                           NaN
#
#         EVE_CAT_COMBINED_105245_3_nansum_14  FAC_N_PRODUCTOS_sum_14  \
# 92231                                   NaN                     NaN
# 16979                                   NaN                     NaN
# 8153                                    NaN                     3.0
# 128107                                  NaN                     4.0
# 11566                                   NaN                     3.0
#
#         MAN_ESTADOWO_ID_N_nansum_28  SAC_N_CONT_SUBCAT_0102001_nansum_28  \
# 92231                           NaN                                  0.0
# 16979                           NaN                                  NaN
# 8153                            NaN                                  0.0
# 128107                          0.0                                  0.0
# 11566                           NaN                                  NaN
#
#         CAM_OFERTA_COMBINADA_NUEV_NET_nansum_21  \
# 92231                                       NaN
# 16979                                       NaN
# 8153                                        NaN
# 128107                                      NaN
# 11566                                       NaN
#
#         EVE_CAT_COMBINED_200142_7_nansum_21  EVE_CAT_COMBINED_171_1_nansum_14  \
# 92231                                   NaN                               NaN
# 16979                                   NaN                               NaN
# 8153                                    NaN                               NaN
# 128107                                  NaN                               NaN
# 11566                                   NaN                               NaN
#
#         SAC_N_CONT_SUBCAT_1207042_nansum_168  ...  \
# 92231                                    2.0  ...
# 16979                                    0.0  ...
# 8153                                     1.0  ...
# 128107                                   0.0  ...
# 11566                                    2.0  ...
#
#         SAC_N_CONT_SUBCAT_0109002_nansum_28  \
# 92231                                   0.0
# 16979                                   NaN
# 8153                                    0.0
# 128107                                  0.0
# 11566                                   NaN
#
#         EVE_CAT_COMBINED_5229_OTHER_nansum_84  CAM_LENGTH_OFFER_nanmin_14  \
# 92231                                     0.0                         NaN
# 16979                                     0.0                         NaN
# 8153                                      0.0                         NaN
# 128107                                    NaN                         NaN
# 11566                                     NaN                         NaN
#
#         EVE_CAT_COMBINED_123_7_nansum_336  CAM_DAYS_TO_END_OFFER_nanmin_21  \
# 92231                                 0.0                              NaN
# 16979                                 0.0                              NaN
# 8153                                  0.0                              NaN
# 128107                                0.0                              NaN
# 11566                                 0.0                              NaN
#
#         SAC_N_CONT_CAT_0801_nansum_28  CAM_N_OFERTAS_nansum_336  \
# 92231                             0.0                       7.0
# 16979                             NaN                       NaN
# 8153                              0.0                       5.0
# 128107                            0.0                       1.0
# 11566                             NaN                       2.0
#
#         EVE_CAT_COMBINED_105245_OTHER_nansum_28  MAN_ESTADOWO_ID_N_nansum_84  \
# 92231                                       0.0                          NaN
# 16979                                       NaN                          NaN
# 8153                                        NaN                          NaN
# 128107                                      NaN                          0.0
# 11566                                       NaN                          NaN
#
#         EVE_CAT_COMBINED_5229_5_nansum_28  EVF_MONTO_nanmin_3  \
# 92231                                 0.0            0.508127
# 16979                                 NaN            0.465291
# 8153                                  NaN            0.185219
# 128107                                NaN            0.496710
# 11566                                 NaN            0.460005
#
#         MAN_SERVICIO_ID_OTHER_nansum_14  SAC_N_CONT_CAT_0110_nansum_28  \
# 92231                               NaN                            0.0
# 16979                               NaN                            NaN
# 8153                                NaN                            0.0
# 128107                              NaN                            1.0
# 11566                               NaN                            NaN
#
#         SAC_N_CONT_CAT_1103_nansum_84  \
# 92231                             0.0
# 16979                             0.0
# 8153                              0.0
# 128107                            0.0
# 11566                             0.0
#
#         CAM_OFERTA_COMBINADA_OTROS_OTROS_nansum_84  \
# 92231                                          0.0
# 16979                                          NaN
# 8153                                           NaN
# 128107                                         NaN
# 11566                                          NaN
#
#         EVE_CAT_COMBINED_123_7_nansum_14  SAC_N_CONT_SUBCAT_0301003_nansum_28  \
# 92231                                NaN                                  0.0
# 16979                                NaN                                  NaN
# 8153                                 NaN                                  0.0
# 128107                               NaN                                  0.0
# 11566                                NaN                                  NaN
#
#         EVE_CAT_COMBINED_171_7_nansum_28  \
# 92231                                0.0
# 16979                                NaN
# 8153                                 NaN
# 128107                               NaN
# 11566                                NaN
#
#         EVE_CAT_COMBINED_171_OTHER_nansum_252  \
# 92231                                     0.0
# 16979                                     0.0
# 8153                                      0.0
# 128107                                    0.0
# 11566                                     0.0
#
#         SAC_N_CONT_SUBCAT_0109001_nansum_168  FAC_MONTO_nanmin_56  \
# 92231                                    0.0             0.447510
# 16979                                    0.0             0.576129
# 8153                                     0.0             0.531594
# 128107                                   1.0             0.563768
# 11566                                    0.0             0.486504
#
#         MAN_DEALER_WO_ID_OTHER_nansum_14  SAC_N_CONT_SUBCAT_1002006_nansum_28  \
# 92231                                NaN                                  0.0
# 16979                                NaN                                  NaN
# 8153                                 NaN                                  0.0
# 128107                               NaN                                  0.0
# 11566                                NaN                                  NaN
#
#         ECH_DISPOSITION_DESC_INTERFLOWED_nansum_168  \
# 92231                                           5.0
# 16979                                           NaN
# 8153                                            1.0
# 128107                                          1.0
# 11566                                           0.0
#
#         SAC_N_CONT_CAT_0102_nansum_28  \
# 92231                             0.0
# 16979                             NaN
# 8153                              0.0
# 128107                            0.0
# 11566                             NaN
#
#         ECH_DISPOSITION_DESC_FORCED_DISCONNECT_nansum_7  \
# 92231                                               0.0
# 16979                                               NaN
# 8153                                                NaN
# 128107                                              NaN
# 11566                                               NaN
#
#         ECH_DURATION_mean_nanmean_21  EVF_BALANCE_BROUGHT_FORWARD_nanmin_4  \
# 92231                    1173.050049                              0.512257
# 16979                            NaN                              0.469615
# 8153                             NaN                              0.187315
# 128107                   1644.000000                              0.500768
# 11566                            NaN                              0.367830
#
#         FAC_MONTO_nanmin_7  EVE_CAT_COMBINED_5229_1_nansum_28  \
# 92231                  NaN                                1.0
# 16979                  NaN                                NaN
# 8153                   NaN                                NaN
# 128107            0.563868                                NaN
# 11566             0.486504                                NaN
#
#         EVF_BALANCE_BROUGHT_FORWARD_nanmean_3  \
# 92231                                0.545278
# 16979                                0.596494
# 8153                                 0.260354
# 128107                               0.506817
# 11566                                0.557700
#
#         CAM_DAYS_TO_END_OFFER_nanmin_252  \
# 92231                                2.0
# 16979                                NaN
# 8153                               -60.0
# 128107                               NaN
# 11566                             -186.0
#
#         EVE_CAT_COMBINED_133_OTHER_nansum_336  \
# 92231                                     0.0
# 16979                                     0.0
# 8153                                      0.0
# 128107                                    0.0
# 11566                                     0.0
#
#         EVE_CAT_COMBINED_OTHER_7_nansum_168  \
# 92231                                   3.0
# 16979                                   0.0
# 8153                                    0.0
# 128107                                  NaN
# 11566                                   3.0
#
#         CAM_OFERTA_COMBINADA_OTROS_PREMIUM_nansum_14  \
# 92231                                            NaN
# 16979                                            NaN
# 8153                                             NaN
# 128107                                           NaN
# 11566                                            NaN
#
#         CAM_OFERTA_COMBINADA_OTROS_NET_nansum_252  \
# 92231                                         0.0
# 16979                                         NaN
# 8153                                          0.0
# 128107                                        NaN
# 11566                                         0.0
#
#         MOR_MORA_31_60_scaled_nanmax_84  \
# 92231                               NaN
# 16979                               0.0
# 8153                                0.0
# 128107                              0.0
# 11566                               0.0
#
#         CAM_OFERTA_COMBINADA_OTROS_NET_nansum_84  \
# 92231                                        0.0
# 16979                                        NaN
# 8153                                         NaN
# 128107                                       NaN
# 11566                                        NaN
#
#         FAC_CATEGORIA_ID_A_nansum_14  CAM_LENGTH_OFFER_nanmax_21  \
# 92231                            NaN                         NaN
# 16979                            NaN                         NaN
# 8153                             0.0                         NaN
# 128107                           0.0                         NaN
# 11566                            0.0                         NaN
#
#         CAM_OFERTA_COMBINADA_OTROS_BASICO_nansum_252  \
# 92231                                            0.0
# 16979                                            NaN
# 8153                                             0.0
# 128107                                           NaN
# 11566                                            0.0
#
#         CAM_OFERTA_COMBINADA_RETE_BUNDLE_nansum_14  \
# 92231                                          NaN
# 16979                                          NaN
# 8153                                           NaN
# 128107                                         NaN
# 11566                                          NaN
#
#         MAN_ESTADOWO_ID_RA_nansum_168  SAC_N_CONT_CAT_1108_nansum_7  \
# 92231                             NaN                           NaN
# 16979                             NaN                           NaN
# 8153                              NaN                           NaN
# 128107                            0.0                           NaN
# 11566                             NaN                           NaN
#
#         MAN_SERVICIO_ID_SC_nansum_14  MOR_MORA_1_30_scaled_nanmax_168  \
# 92231                            NaN                              NaN
# 16979                            NaN                         0.525205
# 8153                             NaN                         0.425556
# 128107                           NaN                         0.804864
# 11566                            NaN                         0.582465
#
#         SAC_N_CONT_CAT_0104_nansum_84     SCORE  ventile   order
# 92231                             0.0  0.155299        1  586542
# 16979                             0.0  0.007059        2  557214
# 8153                              0.0  0.005194        3  527887
# 128107                            0.0  0.004282        4  498559
# 11566                             0.0  0.003711        5  469233
#
# [5 rows x 1198 columns]

# %%
model_format = parameters["models"][model][model_type]["model_to_load"]
path_file_importance=f'/data/co_po/models/{model_format}_{model}_binary_model/{model_format}_important_variables.csv'

# %%
shap_vals_df = pd.DataFrame(data=shap_values,columns=lgbmodel.feature_name())
df_feature = pd.read_csv(path_file_importance, sep=";", decimal=",")

# %%
level=20

# %%
plt.rcParams.update({'figure.figsize':(7.5,7.5), 'figure.dpi':100})
best_clientes_by_ventil=best_clientes_by_ventil.loc[best_clientes_by_ventil.ventile<=2]
factor=100
for client, ventile, shap_ix in zip(best_clientes_by_ventil.index,best_clientes_by_ventil.ventile,best_clientes_by_ventil.order):
    
    # Sigmoid transformation
    data=shap_vals_df.iloc[shap_ix]
    shap_total=data.sum()
    sigmoid_intercept = sigmoid(mean_rate)
    score = sigmoid(mean_rate + shap_total) #score = sum of all shap values+base_line 
    score_diff = score - sigmoid_intercept

    
    vars_=df_feature.iloc[0:level].column.to_list()
    shap_val_clientes=data.apply(lambda x: x / data.sum() * score_diff)
    shap_val_clientes_vars_out=shap_val_clientes.loc[[x for x in list(shap_val_clientes.index) if x not in vars_ ]]
    shap_val_clientes_vars_in=shap_val_clientes.loc[vars_]

    variables=list(shap_val_clientes_vars_in.index)
    variables.insert(0,'base level')
    variables.append('rest')
    shap=list(shap_val_clientes_vars_in.values)
    shap.insert(0,sigmoid_intercept)
    shap.append(shap_val_clientes_vars_out.sum())
    shap=[x*factor for x in shap]

    waterfall_chart.plot(variables,shap,net_label=f'score * {factor}',formatting="{:,.2f}",Title=f'Client with the best score in the ventile {ventile}', rotation_value=90);

# %%
shap

# %%
# Out:
# 598.613349667653

# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context
import numpy as np

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")

# %%
clientes_connect=catalog.load("clientes")
# Out:
# 2020-12-14 17:09:40,824 - kedro.io.data_catalog - INFO - Loading data from `clientes` (SQLPartitionedDataSet)...

# %%
clientes=clientes_connect.filter_by_query("select * from stg_uy_clientes")

# %%
clientes.head()
# Out:
#    CUSTOMER_ID TITLEUSERKEY    GENERO        FECHA_CREATE CUSTOMER_CLASS  \
# 0         8031        Cmpa.  Compania 2001-09-20 13:42:32   2 - PostPago
# 1         8677          Sr.     Senor 2001-09-25 20:42:25   2 - PostPago
# 2         8677          Sr.     Senor 2001-09-25 20:42:25   2 - PostPago
# 3         8855          Sr.     Senor 2001-09-26 14:06:27   2 - PostPago
# 4         9055          Sr.     Senor 2001-09-26 16:40:28   2 - PostPago
#
#   FECHANACIMIENTO        CUSTOMER_TYPE  CUSTOMER_STATUS SEGMENTATION  \
# 0      1932-03-25  D - Normal Edificio  Normal customer      Grupo_2
# 1      1966-06-16      N - Normal Casa  Normal customer      Grupo_4
# 2      1966-06-16      N - Normal Casa  Normal customer      Grupo_4
# 3      1947-01-19      N - Normal Casa  Normal customer      Grupo_4
# 4      1950-01-28  D - Normal Edificio  Normal customer      Grupo_2
#
#           DOMICILO_INS_FACT                     LOCALIDAD     CP   PROVINCIA  \
# 0  DOMICILIO DE INSTALACION                  CIUDAD VIEJA  11000  MONTEVIDEO
# 1  DOMICILIO DE FACTURACION                          None  20100   MALDONADO
# 2  DOMICILIO DE INSTALACION                PUNTA DEL ESTE  20100   MALDONADO
# 3  DOMICILIO DE INSTALACION  PIEDRAS BLANCAS/VILLA GARCIA  12200  MONTEVIDEO
# 4  DOMICILIO DE INSTALACION             CENTRO/BARRIO SUR  11100  MONTEVIDEO
#
#       PAIS DATE_EXP
# 0  URUGUAY   202002
# 1  URUGUAY   202002
# 2  URUGUAY   202002
# 3  URUGUAY   202002
# 4  URUGUAY   202002

# %%
clientes.groupby(["DATE_EXP"]).agg({'CUSTOMER_ID':'nunique'})
# Out:
#           CUSTOMER_ID
# DATE_EXP
# 202001          58145
# 202002          60762

# %%
clientes.groupby(["DATE_EXP",'PROVINCIA','CUSTOMER_CLASS']).agg({'CUSTOMER_ID':'nunique'})
# Out:
#                                               CUSTOMER_ID
# DATE_EXP PROVINCIA      CUSTOMER_CLASS
# 202001   ARTIGAS        2 - PostPago                  850
#          CANELONES      2 - PostPago                14767
#                         9 - Premium Postpago            4
#          CERRO LARGO    2 - PostPago                 1263
#          COLONIA        2 - PostPago                 4686
#                         9 - Premium Postpago            1
#          DURAZNO        2 - PostPago                  829
#          FLORES         2 - PostPago                  459
#          FLORIDA        2 - PostPago                 1302
#          LAVALLEJA      2 - PostPago                  737
#                         9 - Premium Postpago            1
#          MALDONADO      2 - PostPago                 5014
#                         9 - Premium Postpago            7
#          MONTEVIDEO     2 - PostPago                15415
#                         9 - Premium Postpago           31
#          PAYSANDU       2 - PostPago                 1715
#                         9 - Premium Postpago            1
#          RIO NEGRO      2 - PostPago                 1699
#          RIVERA         2 - PostPago                  953
#          ROCHA          2 - PostPago                 1402
#          SALTO          2 - PostPago                 1829
#          SAN JOSE       2 - PostPago                 2631
#          SORIANO        2 - PostPago                 1645
#          TACUAREMBO     2 - PostPago                 1678
#          TREINTA Y TRES 2 - PostPago                  649
#                         9 - Premium Postpago            1
# 202002   ARTIGAS        2 - PostPago                  873
#          CANELONES      2 - PostPago                15291
#                         9 - Premium Postpago            7
#          CERRO LARGO    2 - PostPago                 1333
#          COLONIA        2 - PostPago                 4903
#                         9 - Premium Postpago            3
#          DURAZNO        2 - PostPago                  870
#          FLORES         2 - PostPago                  469
#          FLORIDA        2 - PostPago                 1437
#          LAVALLEJA      2 - PostPago                  808
#          MALDONADO      2 - PostPago                 5280
#                         9 - Premium Postpago            5
#          MONTEVIDEO     2 - PostPago                16076
#                         9 - Premium Postpago           29
#          PAYSANDU       2 - PostPago                 1747
#                         9 - Premium Postpago            1
#          RIO NEGRO      2 - PostPago                 1842
#          RIVERA         2 - PostPago                 1014
#          ROCHA          2 - PostPago                 1443
#          SALTO          2 - PostPago                 1908
#          SAN JOSE       2 - PostPago                 2870
#                         9 - Premium Postpago            1
#          SORIANO        2 - PostPago                 1667
#          TACUAREMBO     2 - PostPago                 1713
#          TREINTA Y TRES 2 - PostPago                  702
#                         9 - Premium Postpago            1

# %%
clientes.groupby(["DATE_EXP",'CUSTOMER_TYPE']).agg({'CUSTOMER_ID':'nunique'})
# Out:
#                               CUSTOMER_ID
# DATE_EXP CUSTOMER_TYPE
# 202001   D - Normal Edificio         9792
#          N - Normal Casa            48353
# 202002   D - Normal Edificio         9813
#          N - Normal Casa            50949

# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")
from aa_engine_pkg.assets.utils import *
from aa_engine_pkg.assets.core.data.kedro.catalog_expansion.partitioned_sql import SQLPartitionedDataSet

# %%
upgrades_basicos=catalog.load('upgrades_basicos')
eop=catalog.load("eop")#catalog.load("eop")
cliente_activo=catalog.load("cliente_activo")
agendas_basicos=catalog.load("agendas_basicos")
# Out:
# 2021-03-22 15:19:05,687 - kedro.io.data_catalog - INFO - Loading data from `upgrades_basicos` (SQLPartitionedDataSet)...
# 2021-03-22 15:19:05,689 - kedro.io.data_catalog - INFO - Loading data from `eop` (SQLPartitionedDataSet)...
# 2021-03-22 15:19:05,690 - kedro.io.data_catalog - INFO - Loading data from `cliente_activo` (SQLPartitionedDataSet)...
# 2021-03-22 15:19:05,691 - kedro.io.data_catalog - INFO - Loading data from `agendas_basicos` (SQLPartitionedDataSet)...

# %%
def create_cliente_activo(cliente_activo: SQLPartitionedDataSet,
                          date: str) -> pd.DataFrame:
    """Creates master table with features related to EoP state of customers for one period of data

    Parameters
    ----------
    cliente_activo:
        dataset defined in ´catalog.yml´ - list of active customers at EoP for the given period
    date:
        period to process
    
    Returns
    -------
        Mastertable with information of clientes at EoP
    """

    # Initialize logger
    log = initialize_logger()

    # Load active clientes for period
    log.info(f"Creating cliente_activo...")
    period_to_load = get_previous_month(date)
    df_clientes_activos = cliente_activo.filter_by(date=period_to_load)

    # Return
    return df_clientes_activos

# %%
def create_target_upsell(upgrades_basicos: SQLPartitionedDataSet,
                         eop: SQLPartitionedDataSet,
                         agendas_basicos: SQLPartitionedDataSet,
                         cliente_activo: pd.DataFrame,
                         parameters: Dict,
                         date: str) -> pd.DataFrame:
    """Function that takes care of generating the target feature for the up-sell model
    Up-selling includes:
        - Switching to a higher level of service on the same tecnology (e.g., from Silver SD to Gold SD)

    Target definition:
        - Existing customer switches service.
        - Stays with new product for at least 84 days
        - Doesn't have an agenda in the lat 28 days

    Target methodology:
        0. Definition of product ranking (update as needed)
        1. Loading of customer base (e.g., all post-paid customers in Uruguay)
        2. Loading of upgrade events (108) for period of interest (calculation_window)
        3. Loading of events (107,108,133,142) to detect customers that switch products for period of
        interest (activation_window)
        4. Loading of event (100108) for period (date - 28 days, date)
        5. For customers that have an event (108) in the calculation_window, compare previous service to new one to determine if it
    is an upgrade using the product ranking.
        6. For said customers in (5), check if another event happens in the activation_window after the 108 event. If it does not happen, then the
    customers are target for the model.

    Parameters
    ----------
    upgrades_basicos: 
        dataset defined in ``catalog_raw.yml`` with raw data information related to upgrades of programming service products
    eop:
        dataset defined in ``catalog_raw.yml`` with raw data information related to the client's EoP state
    date:
        period to process
    parameters:
        set of project parameters defined in ``parameters.yml``
    
    Returns
    -------
    pd.DataFrame
        Master table with up-sell target feature for one period (date+1; date+calculation_window)
    """
# Initialize logger
    log = initialize_logger()
    
    table_name = "target_upsell"
    write_to_parquet = parameters["write_to_parquet"]
    overwrite = parameters["targets"][table_name]["overwrite"]
    end_date = str(parameters["end_date"])
    log.info(f"Start the process of create upsell target for {date}")
    
    # Check if target can be created (date + max window < previous sunday)
    target_parameters = parameters["targets"][table_name]
    max_window = max([target_parameters[x] for x in target_parameters.keys() if x.endswith("window")])
    upper_bound = (pd.to_datetime(date) + timedelta(days=max_window)).strftime("%Y%m%d")
    previous_sunday = dt.today() - timedelta(days=dt.today().weekday() + 1)
    
    if pd.to_datetime(upper_bound, format="%Y%m%d") > previous_sunday:
        log.info(f"Cannot create upsell target for {date}: Not enough future information")
        return None

    # Compare with what is already processed
    path = f"{parameters['paths']['target_path']}{table_name}/"
    os.makedirs(path, exist_ok=True)
    processed_dates = os.listdir(path)
    match = [file for file in processed_dates if str(date) in file]
    if len(match) > 0 and overwrite is False:
        # If table is found, read parquet:
        log.info(f"Reading {match[0]} table")
        df_final = pd.read_parquet(path + match[0], engine="pyarrow")

    else:
        product_rank = parameters["targets"]["target_upsell"]["upsell_products_rank"]
        products_allowed_to_move=parameters["targets"]["target_upsell"]["products_allowed_to_move"]
        product_tecnology=parameters["targets"]["target_upsell"]["product_and_tecnology"]
        product_tecnology = {value : key for (key, value) in product_tecnology.items()}

        start_date = date
        end_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["calculation_window"])
                    ).strftime("%Y%m%d")
        cancel_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["activation_window"])
                       ).strftime("%Y%m%d")

        end_date_upgrades = (pd.to_datetime(date) + timedelta(days=2*parameters["targets"]["target_upsell"]["calculation_window"])).strftime("%Y%m%d")

        start_date_agendas = (pd.to_datetime(start_date)-timedelta(days=28)).strftime("%Y%m%d")

        # Get EoP active clients from previous period to exclude new clients
        period_to_load = get_previous_month(start_date)
        df_clientes = eop.filter_by(condition=f"PRC_TIPO_ID = 3 AND PRC_CODIGO  IN {tuple(products_allowed_to_move)}",
                                     #base of customers that can made an upgrade
                                     date=period_to_load)
        
        # Get the user tecnology
        df_clientes["tecno_eop"]=df_clientes["PRC_CODIGO"].map(product_tecnology)
        df_clientes["tecno_eop"]=[y.split(" ")[2] for x,y in enumerate(df_clientes["tecno_eop"])]

        # Get data for target creation
        moves=tuple([ value[0] for (key,value) in product_rank.items()])
        df_upgrades = upgrades_basicos.filter_by(condition=f"EVENTO_ID = 108 AND PRODUCTO_ID IN {moves}",
                                                 date=[start_date, end_date_upgrades],
                                                 target=True)
        #Tecnology of the basic product after the movement.
        df_upgrades["tecno_up"]=[y.split(" ")[2] for x,y in enumerate(df_upgrades.PRODUCTO_ID.map(product_tecnology))]

        #CANCELATIONS
        df_cancelations = upgrades_basicos.filter_by(date=[start_date,
                                                           cancel_date],
                                                     target=True)

        # Keep only first move by CUSTOMER, PRODUCT
        df_cancelations.sort_values(["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"], ascending=[False, False, True], inplace=True)
        df_cancelations.drop_duplicates(subset=["CUSTOMER_ID", "PRODUCTO_ID"], keep="last", inplace=True)

        #AGENDA
        df_agenda = agendas_basicos.filter_by(date=[start_date_agendas, end_date])
        df_agenda.rename(columns={"FECHA":"FECHA_AGENDA"},inplace=True)

        df_clientes_upgrades = pd.merge(
            df_clientes[["CUSTOMER_ID", "PRC_CODIGO","tecno_eop"]],
            df_upgrades[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA","tecno_up"]],
            on=["CUSTOMER_ID"],
            how="inner",
            validate="1:m")

        df_clientes_upgrades.sort_values(["CUSTOMER_ID", "PRC_CODIGO", "FECHA"], ascending=[False, False, True],
                                                 inplace=True)
        df_clientes_upgrades.drop_duplicates(subset=["CUSTOMER_ID", "PRC_CODIGO"], keep="last", inplace=True)

        del df_upgrades;
        gc.collect()
        
        #RANKING products
        df_product_rank = pd.DataFrame(product_rank.items(), columns=["PRODUCTO_RANK_INI", "PRC_CODIGO"])
        df_product_rank = df_product_rank.explode("PRC_CODIGO")

        # Rank initial product (PRC_CODIGO) from EOP table
        df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades,
                                               df_product_rank,
                                               on="PRC_CODIGO",
                                               how="left",
                                               validate="m:1")

        del df_clientes_upgrades
        gc.collect()

        # Rank last product (PRODUCTO_ID) from plan_evento table
        df_product_rank.rename(columns={"PRC_CODIGO": "PRODUCTO_ID",
                                        "PRODUCTO_RANK_INI": "PRODUCTO_RANK_END"}, inplace=True)
        df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades_ranked,
                                               df_product_rank,
                                               on="PRODUCTO_ID",
                                               how="left",
                                               validate="m:1")

        #Solving the situation of MIX, this tecnology is SD
        df_clientes_upgrades_ranked["tecno_eop"]=np.where(df_clientes_upgrades_ranked.tecno_eop.isin(["MIX"]),"SD",df_clientes_upgrades_ranked.tecno_eop)
        df_clientes_upgrades_ranked["tecno_up"]=np.where(df_clientes_upgrades_ranked.tecno_up.isin(["MIX"]),"SD",df_clientes_upgrades_ranked.tecno_up)

        # Calculate target based on initial and end product plus tecnology
        df_clientes_upgrades_ranked["TARGET"] = np.where((df_clientes_upgrades_ranked["PRODUCTO_RANK_END"] > \
                                                         df_clientes_upgrades_ranked["PRODUCTO_RANK_INI"]) & ((df_clientes_upgrades_ranked["tecno_eop"] == \
                                                                                                               df_clientes_upgrades_ranked["tecno_up"])), 1, 0)


        # Merge with target df to check for activation period
        df_target = pd.merge(df_clientes_upgrades_ranked,
                             df_cancelations[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"]],
                             on=["CUSTOMER_ID", "PRODUCTO_ID"],
                             how="left",
                             validate="1:m")

        del df_clientes_upgrades_ranked, df_cancelations;
        gc.collect()

        # Compute time difference between events
        df_target["DATE_DIFF"] = (df_target["FECHA_y"] - df_target["FECHA_x"]) / np.timedelta64(1, "D")
        log.info(f" Number of events 108 ending as upgrades before product changes rule {df_target.TARGET.sum()}")

        df_target["TARGET"] = np.where((df_target["DATE_DIFF"] > 0) & \
                                       (df_target["DATE_DIFF"] <= parameters["targets"]["target_upsell"][
                                           "activation_window"]),
                                       0,
                                       df_target["TARGET"])
        df_target = drop_extra_rename_remaining(df_target)
        log.info(f" Number of events 108 ending as upgrades after tecnology changes rule {df_target.TARGET.sum()}")
        
        # quitar upgrades agendados el mes anterior
        df_final = pd.merge(df_target,
                        df_agenda,
                        left_on=['CUSTOMER_ID'],
                        right_on=['CUSTOMER_ID'],
                        how='left')
        # quitar agendas mes anterior
        upgrades_agendados_antes = df_final[(df_final.FECHA_AGENDA)<(pd.to_datetime(start_date)).strftime("%Y%m%d")]
        df_final = df_final.drop(upgrades_agendados_antes.index)
        log.info(f" Number of events 108 ending as upgrades after 100108 rule {df_final.TARGET.sum()}")
        
        # quitar upgrades mes futuro no agendados este mes
        upgrades_futuros = df_final[df_final.FECHA>(pd.to_datetime(start_date)+timedelta(days=28)).strftime("%Y%m%d")]
        df_final = df_final.drop(upgrades_futuros[upgrades_futuros.FECHA_AGENDA.isna()].index)

        df_final.sort_values(["CUSTOMER_ID", "TARGET"], ascending=False,inplace=True)
        df_final.drop_duplicates(subset=["CUSTOMER_ID"], keep="first", inplace=True)
        
        # Merge back to EOP
        df_final = pd.merge(cliente_activo[["CUSTOMER_ID"]],
                            df_final[["CUSTOMER_ID", "TARGET", "FECHA", "PRC_CODIGO"]],
                            on="CUSTOMER_ID",
                            how="left",
                            validate="1:1")
        
        target=df_final.loc[df_final.CUSTOMER_ID.isin(cliente_activo.CUSTOMER_ID.unique())]

        del df_target, df_final;
        gc.collect()

        target["TARGET"].fillna(0, inplace=True)
        target["TARGET"] =  target["TARGET"].astype(np.int32)
        target["DATE_EXP"] = period_to_load
        target["DATE_CALC"] = date
        target.rename({"FECHA": "FECHA_TARGET"}, inplace=True)
        log.info(f"should be equals| {len(target.CUSTOMER_ID.unique())}=={target.shape[0]}")
        if write_to_parquet:
            file = f"{parameters['paths']['target_path']}{table_name}/{table_name}_{date}.parquet"
            #file = f"/u01/share/cesar/others_uy/target_corregido/{table_name}_{date}.parquet"
            target.to_parquet(file, engine="pyarrow")

        # Return
        log.info(
            f"""Exporting target for period {start_date} and rate {
            np.round(100 * target[target['TARGET'] == 1]['CUSTOMER_ID'].nunique() / target['CUSTOMER_ID'].nunique(), 2)
            }%""")

    return target

# %%
periods=parameters['models']['upsell']['binary']['train_periods']+parameters['models']['upsell']['binary']['test_periods']+parameters['models']['upsell']['binary']['dev_periods']

# %%
for date in periods:
    cliente_activo_df=create_cliente_activo(cliente_activo,date)
    create_target_upsell(upgrades_basicos,
                         eop,
                         agendas_basicos,
                         cliente_activo_df,
                         parameters,
                         date)
# Out:
# 2021-03-22 19:54:19,943 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# 2021-03-22 19:54:23,255 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20181203
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201811 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190128235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190331235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20181105', 'yyyymmdd') and FECHA < to_date('20181231', 'yyyymmdd')
# 2021-03-22 19:54:26,977 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 296
# 2021-03-22 19:54:26,983 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 265
# 2021-03-22 19:54:26,993 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 256
# 2021-03-22 19:54:27,350 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116634==116634
# 2021-03-22 19:54:27,442 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181203 and rate 0.11%
# 2021-03-22 19:54:27,451 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# 2021-03-22 19:54:30,031 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20181231
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201811 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190225235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190428235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20181203', 'yyyymmdd') and FECHA < to_date('20190128', 'yyyymmdd')
# 2021-03-22 19:54:33,870 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 333
# 2021-03-22 19:54:33,876 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 314
# 2021-03-22 19:54:33,886 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 287
# 2021-03-22 19:54:34,214 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116634==116634
# 2021-03-22 19:54:34,312 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181231 and rate 0.13%
# 2021-03-22 19:54:34,320 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201812
# 2021-03-22 19:54:39,214 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190128
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201812 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190325235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190526235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20181231', 'yyyymmdd') and FECHA < to_date('20190225', 'yyyymmdd')
# 2021-03-22 19:54:42,279 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 365
# 2021-03-22 19:54:42,285 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 341
# 2021-03-22 19:54:42,296 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 298
# 2021-03-22 19:54:42,638 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116984==116984
# 2021-03-22 19:54:42,732 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190128 and rate 0.13%
# 2021-03-22 19:54:42,740 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201901
# 2021-03-22 19:54:47,269 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190225
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201901 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190422235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190623235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190128', 'yyyymmdd') and FECHA < to_date('20190325', 'yyyymmdd')
# 2021-03-22 19:54:51,557 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 341
# 2021-03-22 19:54:51,563 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 317
# 2021-03-22 19:54:51,573 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 287
# 2021-03-22 19:54:51,905 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116342==116342
# 2021-03-22 19:54:51,997 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190225 and rate 0.14%
# 2021-03-22 19:54:52,005 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201902
# 2021-03-22 19:54:54,715 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190325
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201902 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190520235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190721235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190225', 'yyyymmdd') and FECHA < to_date('20190422', 'yyyymmdd')
# 2021-03-22 19:54:58,583 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 300
# 2021-03-22 19:54:58,589 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 271
# 2021-03-22 19:54:58,599 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 247
# 2021-03-22 19:54:58,931 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 115807==115807
# 2021-03-22 19:54:59,025 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190325 and rate 0.11%
# 2021-03-22 19:54:59,032 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201903
# 2021-03-22 19:55:03,004 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190422
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201903 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190617235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190818235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190325', 'yyyymmdd') and FECHA < to_date('20190520', 'yyyymmdd')
# 2021-03-22 19:55:07,069 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 364
# 2021-03-22 19:55:07,075 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 335
# 2021-03-22 19:55:07,086 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 310
# 2021-03-22 19:55:07,421 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 115524==115524
# 2021-03-22 19:55:07,511 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190422 and rate 0.11%
# 2021-03-22 19:55:07,519 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201904
# 2021-03-22 19:55:10,004 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190520
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201904 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190715235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190915235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190422', 'yyyymmdd') and FECHA < to_date('20190617', 'yyyymmdd')
# 2021-03-22 19:55:14,737 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 370
# 2021-03-22 19:55:14,743 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 334
# 2021-03-22 19:55:14,753 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 316
# 2021-03-22 19:55:15,084 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 115453==115453
# 2021-03-22 19:55:15,180 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190520 and rate 0.16%
# 2021-03-22 19:55:15,187 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201905
# 2021-03-22 19:55:19,970 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190617
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201905 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190812235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191013235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190520', 'yyyymmdd') and FECHA < to_date('20190715', 'yyyymmdd')
# 2021-03-22 19:55:24,435 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 414
# 2021-03-22 19:55:24,442 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 389
# 2021-03-22 19:55:24,453 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 376
# 2021-03-22 19:55:24,823 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116233==116233
# 2021-03-22 19:55:24,920 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190617 and rate 0.11%
# 2021-03-22 19:55:24,927 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201906
# 2021-03-22 19:55:29,763 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190715
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201906 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190909235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191110235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190617', 'yyyymmdd') and FECHA < to_date('20190812', 'yyyymmdd')
# 2021-03-22 19:55:34,354 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 428
# 2021-03-22 19:55:34,360 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 408
# 2021-03-22 19:55:34,371 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 398
# 2021-03-22 19:55:34,720 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 117318==117318
# 2021-03-22 19:55:34,815 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190715 and rate 0.2%
# 2021-03-22 19:55:34,823 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201907
# 2021-03-22 19:55:39,620 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190812
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201907 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191007235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191208235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190715', 'yyyymmdd') and FECHA < to_date('20190909', 'yyyymmdd')
# 2021-03-22 19:55:44,282 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 344
# 2021-03-22 19:55:44,288 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 328
# 2021-03-22 19:55:44,298 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 322
# 2021-03-22 19:55:44,654 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 117242==117242
# 2021-03-22 19:55:44,751 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190812 and rate 0.13%
# 2021-03-22 19:55:44,759 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201908
# 2021-03-22 19:55:49,804 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190909
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201908 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191104235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200105235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190812', 'yyyymmdd') and FECHA < to_date('20191007', 'yyyymmdd')
# 2021-03-22 19:55:54,170 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 366
# 2021-03-22 19:55:54,176 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 337
# 2021-03-22 19:55:54,187 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 333
# 2021-03-22 19:55:54,555 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 117172==117172
# 2021-03-22 19:55:54,651 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190909 and rate 0.14%
# 2021-03-22 19:55:54,658 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201909
# 2021-03-22 19:55:59,572 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191007
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201909 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191202235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200202235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190909', 'yyyymmdd') and FECHA < to_date('20191104', 'yyyymmdd')
# 2021-03-22 19:56:09,545 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 310
# 2021-03-22 19:56:09,551 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 289
# 2021-03-22 19:56:09,562 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 281
# 2021-03-22 19:56:09,933 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116912==116912
# 2021-03-22 19:56:10,029 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191007 and rate 0.12%
# 2021-03-22 19:56:10,038 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201910
# 2021-03-22 19:56:14,297 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191104
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201910 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191230235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200301235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191007', 'yyyymmdd') and FECHA < to_date('20191202', 'yyyymmdd')
# 2021-03-22 19:56:18,223 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 263
# 2021-03-22 19:56:18,230 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 242
# 2021-03-22 19:56:18,241 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 241
# 2021-03-22 19:56:18,629 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116800==116800
# 2021-03-22 19:56:18,727 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191104 and rate 0.11%
# 2021-03-22 19:56:18,735 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# 2021-03-22 19:56:23,607 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191202
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201911 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200127235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200329235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191104', 'yyyymmdd') and FECHA < to_date('20191230', 'yyyymmdd')
# 2021-03-22 19:56:27,807 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 277
# 2021-03-22 19:56:27,814 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 247
# 2021-03-22 19:56:27,824 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 247
# 2021-03-22 19:56:28,162 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 117068==117068
# 2021-03-22 19:56:28,254 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191202 and rate 0.11%
# 2021-03-22 19:56:28,261 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# 2021-03-22 19:56:32,789 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191230
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201911 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200224235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200426235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191202', 'yyyymmdd') and FECHA < to_date('20200127', 'yyyymmdd')
# 2021-03-22 19:56:36,902 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 283
# 2021-03-22 19:56:36,908 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 258
# 2021-03-22 19:56:36,918 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 238
# 2021-03-22 19:56:37,252 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 117068==117068
# 2021-03-22 19:56:37,342 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191230 and rate 0.1%
# 2021-03-22 19:56:37,349 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201912
# 2021-03-22 19:56:42,947 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200127
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201912 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200323235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200524235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191230', 'yyyymmdd') and FECHA < to_date('20200224', 'yyyymmdd')
# 2021-03-22 19:56:47,170 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 297
# 2021-03-22 19:56:47,176 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 280
# 2021-03-22 19:56:47,186 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 264
# 2021-03-22 19:56:47,529 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 117163==117163
# 2021-03-22 19:56:47,621 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200127 and rate 0.11%
# 2021-03-22 19:56:47,629 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202005
# 2021-03-22 19:56:52,052 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200615
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202005 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200810235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201011235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200518', 'yyyymmdd') and FECHA < to_date('20200713', 'yyyymmdd')
# 2021-03-22 19:56:56,179 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 313
# 2021-03-22 19:56:56,185 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 285
# 2021-03-22 19:56:56,196 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 276
# 2021-03-22 19:56:56,537 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 115755==115755
# 2021-03-22 19:56:56,629 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200615 and rate 0.13%
# 2021-03-22 19:56:56,638 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202006
# 2021-03-22 19:57:01,120 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200713
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202006 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200907235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201108235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200615', 'yyyymmdd') and FECHA < to_date('20200810', 'yyyymmdd')
# 2021-03-22 19:57:05,269 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 341
# 2021-03-22 19:57:05,274 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 311
# 2021-03-22 19:57:05,285 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 303
# 2021-03-22 19:57:05,621 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 115886==115886
# 2021-03-22 19:57:05,711 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200713 and rate 0.11%
# 2021-03-22 19:57:05,719 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202007
# 2021-03-22 19:57:10,223 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200810
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202007 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201005235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201206235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200713', 'yyyymmdd') and FECHA < to_date('20200907', 'yyyymmdd')
# 2021-03-22 19:57:14,288 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 398
# 2021-03-22 19:57:14,293 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 362
# 2021-03-22 19:57:14,304 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 356
# 2021-03-22 19:57:14,643 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116188==116188
# 2021-03-22 19:57:14,736 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200810 and rate 0.17%
# 2021-03-22 19:57:14,744 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202008
# 2021-03-22 19:57:19,325 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200907
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202008 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201102235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20210103235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200810', 'yyyymmdd') and FECHA < to_date('20201005', 'yyyymmdd')
# 2021-03-22 19:57:23,062 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 288
# 2021-03-22 19:57:23,068 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 267
# 2021-03-22 19:57:23,078 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 261
# 2021-03-22 19:57:23,412 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116749==116749
# 2021-03-22 19:57:23,505 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200907 and rate 0.13%
# 2021-03-22 19:57:23,513 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202001
# 2021-03-22 19:57:26,747 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200224
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202001 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200420235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200621235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200127', 'yyyymmdd') and FECHA < to_date('20200323', 'yyyymmdd')
# 2021-03-22 19:57:29,996 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 284
# 2021-03-22 19:57:30,002 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 261
# 2021-03-22 19:57:30,012 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 249
# 2021-03-22 19:57:30,365 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116774==116774
# 2021-03-22 19:57:30,455 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200224 and rate 0.12%
# 2021-03-22 19:57:30,462 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202002
# 2021-03-22 19:57:33,935 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200323
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202002 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200518235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200719235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200224', 'yyyymmdd') and FECHA < to_date('20200420', 'yyyymmdd')
# 2021-03-22 19:57:37,366 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 218
# 2021-03-22 19:57:37,372 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 195
# 2021-03-22 19:57:37,383 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 179
# 2021-03-22 19:57:37,725 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116537==116537
# 2021-03-22 19:57:37,820 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200323 and rate 0.1%
# 2021-03-22 19:57:37,828 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202003
# 2021-03-22 19:57:42,718 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200420
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202003 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200615235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200816235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200323', 'yyyymmdd') and FECHA < to_date('20200518', 'yyyymmdd')
# 2021-03-22 19:57:45,979 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 304
# 2021-03-22 19:57:45,985 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 276
# 2021-03-22 19:57:45,995 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 263
# 2021-03-22 19:57:46,318 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 116439==116439
# 2021-03-22 19:57:46,407 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200420 and rate 0.06%
# 2021-03-22 19:57:46,414 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202004
# 2021-03-22 19:57:51,390 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200518
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202004 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200713235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200913235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200420', 'yyyymmdd') and FECHA < to_date('20200615', 'yyyymmdd')
# 2021-03-22 19:57:55,197 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 391
# 2021-03-22 19:57:55,203 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 363
# 2021-03-22 19:57:55,214 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 355
# 2021-03-22 19:57:55,544 - aa_engine_pkg.assets.utils.utilities - INFO - should be equals| 115856==115856
# 2021-03-22 19:57:55,633 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200518 and rate 0.18%

# %% [markdown]
# ### check targets

# %%
df=list()
for date in test_periods:
    aux=pd.read_parquet(f"/u01/share/cesar/others_uy/target_corregido/target_upsell_{date}.parquet")
    df.append(aux)
new_target=pd.concat(df)

# %%
new_target.head()
# Out:
#    CUSTOMER_ID  TARGET FECHA  PRC_CODIGO DATE_EXP DATE_CALC
# 0      2038798       0   NaT         NaN   202005  20200615
# 1      2040174       0   NaT         NaN   202005  20200615
# 2      2066350       0   NaT         NaN   202005  20200615
# 3      2100151       0   NaT         NaN   202005  20200615
# 4      2106243       0   NaT         NaN   202005  20200615

# %%
#old target+master
model = "upsell"
model_type = "binary"
data=list()
for date in test_periods:
    file_master = f"{parameters['paths']['master_path']}master_total/master_total_{date}.parquet"
    df = pd.read_parquet(file_master)

    file_target = f"{parameters['paths']['target_path']}target_{model}/target_{model}_{date}.parquet"
    df_target = pd.read_parquet(file_target)

    data.append(df.merge(df_target[["CUSTOMER_ID","TARGET"]],on="CUSTOMER_ID",how="left"))
data=pd.concat(data)

# %%
data.head()
# Out:
#    CUSTOMER_ID  AQY_ARPU_nanmean_1  AQY_FLAG_DISCOUNT_nansum_1  \
# 0     53238376            0.524253                         0.0
# 1     53240440            0.554480                         0.0
# 2     53241310            0.188885                         1.0
# 3     53327082            0.890481                         0.0
# 4     53327959            0.149078                         1.0
#
#    AQY_PROP_DISCOUNT_nanmean_1  AQY_ARPU_nanmean_3  \
# 0                     0.327524            0.506094
# 1                     0.309646            0.534600
# 2                     0.835124            0.162252
# 3                     0.090533            0.593946
# 4                     0.754694            0.204858
#
#    AQY_FLAG_DISCOUNT_nansum_3  AQY_PROP_DISCOUNT_nanmean_3  \
# 0                         0.0                     0.341268
# 1                         0.0                     0.325359
# 2                         3.0                     0.867505
# 3                         2.0                     0.532049
# 4                         3.0                     0.674095
#
#    AQY_ARPU_nanmean_6  AQY_FLAG_DISCOUNT_nansum_6  \
# 0            0.486441                         0.0
# 1            0.514009                         0.0
# 2            0.149154                         5.0
# 3            0.510334                         4.0
# 4            0.218532                         5.0
#
#    AQY_PROP_DISCOUNT_nanmean_6  ...  EVF_BALANCE_BROUGHT_FORWARD_nanmax_5  \
# 0                     0.356955  ...                              0.454660
# 1                     0.342429  ...                              0.834607
# 2                     0.888875  ...                              0.408479
# 3                     0.670011  ...                              1.000000
# 4                     0.672981  ...                              0.494082
#
#    EVF_BALANCE_BROUGHT_FORWARD_nanmin_5  EVF_MONTO_nanmean_6  \
# 0                              0.445830             0.450925
# 1                              0.458274             0.536389
# 2                              0.311271             0.342087
# 3                              0.351329             0.640741
# 4                              0.360626             0.359101
#
#    EVF_MONTO_nanmax_6  EVF_MONTO_nanmin_6  \
# 0            0.468702            0.444516
# 1            0.835313            0.453753
# 2            0.404609            0.323101
# 3            1.000000            0.349069
# 4            0.366789            0.349304
#
#    EVF_BALANCE_BROUGHT_FORWARD_nanmean_6  \
# 0                               0.449618
# 1                               0.609697
# 2                               0.342377
# 3                               0.573314
# 4                               0.391581
#
#    EVF_BALANCE_BROUGHT_FORWARD_nanmax_6  EVF_BALANCE_BROUGHT_FORWARD_nanmin_6  \
# 0                              0.454660                              0.445830
# 1                              0.834607                              0.458274
# 2                              0.408479                              0.311271
# 3                              1.000000                              0.351329
# 4                              0.494082                              0.360626
#
#    DATE_CALC  TARGET
# 0   20200615     NaN
# 1   20200615     NaN
# 2   20200615     NaN
# 3   20200615     NaN
# 4   20200615     0.0
#
# [5 rows x 927 columns]

# %%
data=data.merge(new_target,on=["CUSTOMER_ID","DATE_CALC"], how="left")

# %%
data.head()
# Out:
#    CUSTOMER_ID  AQY_ARPU_nanmean_1  AQY_FLAG_DISCOUNT_nansum_1  \
# 0     53238376            0.524253                         0.0
# 1     53240440            0.554480                         0.0
# 2     53241310            0.188885                         1.0
# 3     53327082            0.890481                         0.0
# 4     53327959            0.149078                         1.0
#
#    AQY_PROP_DISCOUNT_nanmean_1  AQY_ARPU_nanmean_3  \
# 0                     0.327524            0.506094
# 1                     0.309646            0.534600
# 2                     0.835124            0.162252
# 3                     0.090533            0.593946
# 4                     0.754694            0.204858
#
#    AQY_FLAG_DISCOUNT_nansum_3  AQY_PROP_DISCOUNT_nanmean_3  \
# 0                         0.0                     0.341268
# 1                         0.0                     0.325359
# 2                         3.0                     0.867505
# 3                         2.0                     0.532049
# 4                         3.0                     0.674095
#
#    AQY_ARPU_nanmean_6  AQY_FLAG_DISCOUNT_nansum_6  \
# 0            0.486441                         0.0
# 1            0.514009                         0.0
# 2            0.149154                         5.0
# 3            0.510334                         4.0
# 4            0.218532                         5.0
#
#    AQY_PROP_DISCOUNT_nanmean_6  ...  EVF_MONTO_nanmin_6  \
# 0                     0.356955  ...            0.444516
# 1                     0.342429  ...            0.453753
# 2                     0.888875  ...            0.323101
# 3                     0.670011  ...            0.349069
# 4                     0.672981  ...            0.349304
#
#    EVF_BALANCE_BROUGHT_FORWARD_nanmean_6  \
# 0                               0.449618
# 1                               0.609697
# 2                               0.342377
# 3                               0.573314
# 4                               0.391581
#
#    EVF_BALANCE_BROUGHT_FORWARD_nanmax_6  EVF_BALANCE_BROUGHT_FORWARD_nanmin_6  \
# 0                              0.454660                              0.445830
# 1                              0.834607                              0.458274
# 2                              0.408479                              0.311271
# 3                              1.000000                              0.351329
# 4                              0.494082                              0.360626
#
#    DATE_CALC  TARGET_x  TARGET_y  FECHA  PRC_CODIGO  DATE_EXP
# 0   20200615       NaN       0.0    NaT         NaN    202005
# 1   20200615       NaN       0.0    NaT         NaN    202005
# 2   20200615       NaN       0.0    NaT         NaN    202005
# 3   20200615       NaN       0.0    NaT         NaN    202005
# 4   20200615       0.0       0.0    NaT         NaN    202005
#
# [5 rows x 931 columns]

# %%
data.TARGET_x.fillna(0,inplace=True)
data.TARGET_y.fillna(0,inplace=True)

# %%
sum((data.TARGET_x==1) &(data.TARGET_y==0))
# Out:
# 63

# %%
#Scoring
model_path = parameters["paths"]["model_path"]
model_format = parameters["models"][model][model_type]["model_to_load"]
model_folder = model_path + model_format + f"_{model}_{model_type}_model/"
lgbmodel = lgbm.Booster(model_file=model_folder + model_format + ".txt")
fill_na_with = np.nan
score_var = "SCORE"
vars_to_model = lgbmodel.feature_name()  # get features used in model training
scoring_data=list()
for date in test_periods:
    df_score = data.loc[data.DATE_CALC==date]
    df_score = add_selected_variables(df_score, vars_to_model, fill_na_with)
    df_score.loc[:, score_var] = lgbmodel.predict(df_score[vars_to_model])
    df_score.loc[:, score_var] = df_score[score_var] * 100
    df_score.loc[:,"decil"]=pd.qcut(df_score[score_var], 10, labels=sorted(np.arange(1, 10 + 1), reverse=True), precision=5,duplicates="drop")
    scoring_data.append(df_score)
scoring_data=pd.concat(scoring_data)
# Out:
# ['EVE_CAT_COMBINED_100133_1_nansum_21', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_21', 'MAN_ESTADOWO_ID_AG_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_252', 'EVE_CAT_COMBINED_123_1_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_336', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_84', 'EVE_CAT_COMBINED_100133_1_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_28', 'EVE_CAT_COMBINED_123_1_nansum_14', 'MAN_ESTADOWO_ID_AG_nansum_84', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_21', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_14', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_21', 'EVE_CAT_COMBINED_100133_1_nansum_28', 'MAN_ESTADOWO_ID_AG_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_84', 'MAN_ESTADOWO_ID_AG_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_168', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_84', 'EVE_CAT_COMBINED_123_1_nansum_28', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_336', 'EVE_CAT_COMBINED_100133_1_nansum_84', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_252', 'EVE_CAT_COMBINED_100133_1_nansum_14'] not found in df
# ['EVE_CAT_COMBINED_100133_1_nansum_21', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_21', 'MAN_ESTADOWO_ID_AG_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_252', 'EVE_CAT_COMBINED_123_1_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_336', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_84', 'EVE_CAT_COMBINED_100133_1_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_28', 'EVE_CAT_COMBINED_123_1_nansum_14', 'MAN_ESTADOWO_ID_AG_nansum_84', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_21', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_14', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_21', 'EVE_CAT_COMBINED_100133_1_nansum_28', 'MAN_ESTADOWO_ID_AG_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_84', 'MAN_ESTADOWO_ID_AG_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_168', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_84', 'EVE_CAT_COMBINED_123_1_nansum_28', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_336', 'EVE_CAT_COMBINED_100133_1_nansum_84', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_252', 'EVE_CAT_COMBINED_100133_1_nansum_14'] not found in df
# ['EVE_CAT_COMBINED_100133_1_nansum_21', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_21', 'MAN_ESTADOWO_ID_AG_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_252', 'EVE_CAT_COMBINED_123_1_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_336', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_84', 'EVE_CAT_COMBINED_100133_1_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_28', 'EVE_CAT_COMBINED_123_1_nansum_14', 'MAN_ESTADOWO_ID_AG_nansum_84', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_21', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_14', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_21', 'EVE_CAT_COMBINED_100133_1_nansum_28', 'MAN_ESTADOWO_ID_AG_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_84', 'MAN_ESTADOWO_ID_AG_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_168', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_84', 'EVE_CAT_COMBINED_123_1_nansum_28', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_336', 'EVE_CAT_COMBINED_100133_1_nansum_84', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_252', 'EVE_CAT_COMBINED_100133_1_nansum_14'] not found in df
# ['EVE_CAT_COMBINED_100133_1_nansum_21', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_21', 'MAN_ESTADOWO_ID_AG_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_252', 'EVE_CAT_COMBINED_123_1_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_336', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_84', 'EVE_CAT_COMBINED_100133_1_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_28', 'EVE_CAT_COMBINED_123_1_nansum_14', 'MAN_ESTADOWO_ID_AG_nansum_84', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_21', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_14', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_252', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_21', 'EVE_CAT_COMBINED_100133_1_nansum_28', 'MAN_ESTADOWO_ID_AG_nansum_168', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_336', 'EVE_CAT_COMBINED_123_1_nansum_84', 'MAN_ESTADOWO_ID_AG_nansum_28', 'CAM_OFERTA_COMBINADA_UPGR_BASICO_nansum_168', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_84', 'EVE_CAT_COMBINED_123_1_nansum_28', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_14', 'EVE_CAT_COMBINED_123_1_nansum_336', 'EVE_CAT_COMBINED_100133_1_nansum_84', 'CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_168', 'EVE_CAT_COMBINED_100133_1_nansum_252', 'EVE_CAT_COMBINED_100133_1_nansum_14'] not found in df

# %%
scoring_data.head()
# Out:
#    CUSTOMER_ID  AQY_ARPU_nanmean_1  AQY_FLAG_DISCOUNT_nansum_1  \
# 0     53238376            0.524253                         0.0
# 1     53240440            0.554480                         0.0
# 2     53241310            0.188885                         1.0
# 3     53327082            0.890481                         0.0
# 4     53327959            0.149078                         1.0
#
#    AQY_PROP_DISCOUNT_nanmean_1  AQY_ARPU_nanmean_3  \
# 0                     0.327524            0.506094
# 1                     0.309646            0.534600
# 2                     0.835124            0.162252
# 3                     0.090533            0.593946
# 4                     0.754694            0.204858
#
#    AQY_FLAG_DISCOUNT_nansum_3  AQY_PROP_DISCOUNT_nanmean_3  \
# 0                         0.0                     0.341268
# 1                         0.0                     0.325359
# 2                         3.0                     0.867505
# 3                         2.0                     0.532049
# 4                         3.0                     0.674095
#
#    AQY_ARPU_nanmean_6  AQY_FLAG_DISCOUNT_nansum_6  \
# 0            0.486441                         0.0
# 1            0.514009                         0.0
# 2            0.149154                         5.0
# 3            0.510334                         4.0
# 4            0.218532                         5.0
#
#    AQY_PROP_DISCOUNT_nanmean_6  ...  \
# 0                     0.356955  ...
# 1                     0.342429  ...
# 2                     0.888875  ...
# 3                     0.670011  ...
# 4                     0.672981  ...
#
#    CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_84  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    EVE_CAT_COMBINED_123_1_nansum_28  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_14  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    EVE_CAT_COMBINED_123_1_nansum_336  EVE_CAT_COMBINED_100133_1_nansum_84  \
# 0                                NaN                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
#
#    CAM_OFERTA_COMBINADA_RENT_OTROS_nansum_168  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    EVE_CAT_COMBINED_100133_1_nansum_252  EVE_CAT_COMBINED_100133_1_nansum_14  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
#
#       SCORE  decil
# 0  0.225786      3
# 1  0.071455      8
# 2  0.134119      5
# 3  0.172675      4
# 4  0.040074     10
#
# [5 rows x 965 columns]

# %%
scoring_data["diff_target"]=np.where((scoring_data.TARGET_x==1) & (scoring_data.TARGET_y==0),1,0)

# %%
scoring_data.groupby(['decil']).agg({'CUSTOMER_ID':'count','TARGET_x':'sum','diff_target':'sum'})
# Out:
#        CUSTOMER_ID  TARGET_x  diff_target
# decil
# 10           46624       3.0            0
# 9            46620       4.0            0
# 8            46621       7.0            0
# 7            46620      11.0            1
# 6            46622       9.0            2
# 5            46620      13.0            2
# 4            46620      24.0            1
# 3            46621      39.0            1
# 2            46621     123.0            8
# 1            46623     422.0           48

# %%
# Initialize logger
log = initialize_logger()

table_name = "target_upsell"
write_to_parquet = parameters["write_to_parquet"]
overwrite = parameters["targets"][table_name]["overwrite"]
end_date = str(parameters["end_date"])
log.info(f"Start the process of create upsell target for {date}")

# Check if target can be created (date + max window < previous sunday)
target_parameters = parameters["targets"][table_name]
max_window = max([target_parameters[x] for x in target_parameters.keys() if x.endswith("window")])
upper_bound = (pd.to_datetime(date) + timedelta(days=max_window)).strftime("%Y%m%d")
previous_sunday = dt.today() - timedelta(days=dt.today().weekday() + 1)
# Out:
# 2021-03-22 14:09:46,221 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200101

# %%
if pd.to_datetime(upper_bound, format="%Y%m%d") > previous_sunday:
        log.info(f"Cannot create upsell target for {date}: Not enough future information")

# %%
# Compare with what is already processed
path = f"{parameters['paths']['target_path']}{table_name}/"
os.makedirs(path, exist_ok=True)
processed_dates = os.listdir(path)
match = [file for file in processed_dates if str(date) in file]
if len(match) > 0 and overwrite is False:
    # If table is found, read parquet:
    log.info(f"Reading {match[0]} table")
    df_final = pd.read_parquet(path + match[0], engine="pyarrow")

# %%
product_rank = parameters["targets"]["target_upsell"]["upsell_products_rank"]
products_allowed_to_move=parameters["targets"]["target_upsell"]["products_allowed_to_move"]
product_tecnology=parameters["targets"]["target_upsell"]["product_and_tecnology"]
product_tecnology = {value : key for (key, value) in product_tecnology.items()}

start_date = date
end_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["calculation_window"])
            ).strftime("%Y%m%d")
cancel_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["activation_window"])
               ).strftime("%Y%m%d")

end_date_upgrades = (pd.to_datetime(date) + timedelta(days=2*parameters["targets"]["target_upsell"]["calculation_window"])).strftime("%Y%m%d")

start_date_agendas = (pd.to_datetime(start_date)-timedelta(days=28)).strftime("%Y%m%d")

# %%
# Get EoP active clients from previous period to exclude new clients
period_to_load = get_previous_month(start_date)
df_clientes = eop.filter_by(condition=f"PRC_TIPO_ID = 3 AND PRC_CODIGO  IN {tuple(products_allowed_to_move)}",
                             #base of customers that can made an upgrade
                             date=period_to_load)
# Out:
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201912 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)

# %%
# Get the user tecnology
df_clientes["tecno_eop"]=df_clientes["PRC_CODIGO"].map(product_tecnology)
df_clientes["tecno_eop"]=[y.split(" ")[2] for x,y in enumerate(df_clientes["tecno_eop"])]

# Get data for target creation
moves=tuple([ value[0] for (key,value) in product_rank.items()])
df_upgrades = upgrades_basicos.filter_by(condition=f"EVENTO_ID = 108 AND PRODUCTO_ID IN {moves}",
                                         date=[start_date, end_date_upgrades],
                                         target=True)
#Tecnology of the basic product after the movement.
df_upgrades["tecno_up"]=[y.split(" ")[2] for x,y in enumerate(df_upgrades.PRODUCTO_ID.map(product_tecnology))]

#CANCELATIONS
df_cancelations = upgrades_basicos.filter_by(date=[start_date,
                                                   cancel_date],
                                             target=True)

# Keep only first move by CUSTOMER, PRODUCT
df_cancelations.sort_values(["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"], ascending=[False, False, True], inplace=True)
df_cancelations.drop_duplicates(subset=["CUSTOMER_ID", "PRODUCTO_ID"], keep="last", inplace=True)

#AGENDA
df_agenda = agendas_basicos.filter_by(date=[start_date_agendas, end_date])
df_agenda.rename(columns={"FECHA":"FECHA_AGENDA"},inplace=True)

df_clientes_upgrades = pd.merge(
    df_clientes[["CUSTOMER_ID", "PRC_CODIGO","tecno_eop"]],
    df_upgrades[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA","tecno_up"]],
    on=["CUSTOMER_ID"],
    how="inner",
    validate="1:m")

df_clientes_upgrades.sort_values(["CUSTOMER_ID", "PRC_CODIGO", "FECHA"], ascending=[False, False, True],
                                         inplace=True)
df_clientes_upgrades.drop_duplicates(subset=["CUSTOMER_ID", "PRC_CODIGO"], keep="last", inplace=True)
    
del df_upgrades;
gc.collect()
# Out:
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200101235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200226235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200101235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200428235900', 'yyyymmddhh24miss')
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191204', 'yyyymmdd') and FECHA < to_date('20200129', 'yyyymmdd')
# 1999

# %%
df_product_rank = pd.DataFrame(product_rank.items(), columns=["PRODUCTO_RANK_INI", "PRC_CODIGO"])
df_product_rank = df_product_rank.explode("PRC_CODIGO")

# Rank initial product (PRC_CODIGO) from EOP table
df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades,
                                       df_product_rank,
                                       on="PRC_CODIGO",
                                       how="left",
                                       validate="m:1")

del df_clientes_upgrades
gc.collect()

# Rank last product (PRODUCTO_ID) from plan_evento table
df_product_rank.rename(columns={"PRC_CODIGO": "PRODUCTO_ID",
                                "PRODUCTO_RANK_INI": "PRODUCTO_RANK_END"}, inplace=True)
df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades_ranked,
                                       df_product_rank,
                                       on="PRODUCTO_ID",
                                       how="left",
                                       validate="m:1")

#Solving the situation of MIX, this tecnology is SD
df_clientes_upgrades_ranked["tecno_eop"]=np.where(df_clientes_upgrades_ranked.tecno_eop.isin(["MIX"]),"SD",df_clientes_upgrades_ranked.tecno_eop)
df_clientes_upgrades_ranked["tecno_up"]=np.where(df_clientes_upgrades_ranked.tecno_up.isin(["MIX"]),"SD",df_clientes_upgrades_ranked.tecno_up)

# Calculate target based on initial and end product plus tecnology
df_clientes_upgrades_ranked["TARGET"] = np.where((df_clientes_upgrades_ranked["PRODUCTO_RANK_END"] > \
                                                 df_clientes_upgrades_ranked["PRODUCTO_RANK_INI"]) & ((df_clientes_upgrades_ranked["tecno_eop"] == \
                                                                                                       df_clientes_upgrades_ranked["tecno_up"])), 1, 0)


# Merge with target df to check for activation period
df_target = pd.merge(df_clientes_upgrades_ranked,
                     df_cancelations[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"]],
                     on=["CUSTOMER_ID", "PRODUCTO_ID"],
                     how="left",
                     validate="1:m")

del df_clientes_upgrades_ranked, df_cancelations;
gc.collect()

# Compute time difference between events
df_target["DATE_DIFF"] = (df_target["FECHA_y"] - df_target["FECHA_x"]) / np.timedelta64(1, "D")
log.info(f" Number of events 108 ending as upgrades before product changes rule {df_target.TARGET.sum()}")

df_target["TARGET"] = np.where((df_target["DATE_DIFF"] > 0) & \
                               (df_target["DATE_DIFF"] <= parameters["targets"]["target_upsell"][
                                   "activation_window"]),
                               0,
                               df_target["TARGET"])
df_target = drop_extra_rename_remaining(df_target)
log.info(f" Number of events 108 ending as upgrades after tecnology changes rule {df_target.TARGET.sum()}")
# Out:
# 2021-03-22 14:09:54,151 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 289
# 2021-03-22 14:09:54,157 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after tecnology changes rule 270

# %%
# quitar upgrades agendados el mes anterior
df_final = pd.merge(df_target,
                df_agenda,
                left_on=['CUSTOMER_ID'],
                right_on=['CUSTOMER_ID'],
                how='left')
# quitar agendas mes anterior
upgrades_agendados_antes = df_final[(df_final.FECHA_AGENDA)<(pd.to_datetime(start_date)).strftime("%Y%m%d")]
df_final = df_final.drop(upgrades_agendados_antes.index)
log.info(f" Number of events 108 ending as upgrades after 100108 rule {df_final.TARGET.sum()}")
# Out:
# 2021-03-22 14:09:56,521 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after 100108 rule 263

# %%
# quitar upgrades mes futuro no agendados este mes
upgrades_futuros = df_final[df_final.FECHA>(pd.to_datetime(start_date)+timedelta(days=28)).strftime("%Y%m%d")]
df_final = df_final.drop(upgrades_futuros[upgrades_futuros.FECHA_AGENDA.isna()].index)

df_final.sort_values(["CUSTOMER_ID", "TARGET"], ascending=False,inplace=True)
df_final.drop_duplicates(subset=["CUSTOMER_ID"], keep="first", inplace=True)

# %%
df_final.head()
# Out:
#     CUSTOMER_ID PRC_CODIGO tecno_eop PRODUCTO_ID_x               FECHA  \
# 1      55182592        169        HD           139 2020-01-15 11:12:33
# 4      54559026        135        SD           132 2020-01-27 13:30:50
# 9      54516639        135        SD           132 2020-01-06 16:12:28
# 12     54506936        135        SD           132 2020-01-25 15:06:23
# 16     54432172        169        HD           139 2020-01-03 08:36:28
#
#    tecno_up  PRODUCTO_RANK_INI  PRODUCTO_RANK_END  TARGET  DATE_DIFF  \
# 1        HD                  5                  7       1        0.0
# 4        SD                  1                  6       1        0.0
# 9        SD                  1                  6       1        0.0
# 12       SD                  1                  6       1        0.0
# 16       HD                  5                  7       1        0.0
#
#     PRODUCTO_ID_y PRODUCTO FECHA_AGENDA
# 1             NaN      NaN          NaT
# 4             NaN      NaN          NaT
# 9             NaN      NaN          NaT
# 12            NaN      NaN          NaT
# 16            NaN      NaN          NaT

# %%
# Merge back to EOP
df_final = pd.merge(cliente_activo_df[["CUSTOMER_ID"]],
                    df_final[["CUSTOMER_ID", "TARGET", "FECHA", "PRC_CODIGO"]],
                    on="CUSTOMER_ID",
                    how="left",
                    validate="1:1")

# %%
df_final["TARGET"].fillna(0, inplace=True)

# %%
target=df_final.loc[df_final.CUSTOMER_ID.isin(cliente_activo_df.CUSTOMER_ID.unique())]

#del df_target, df_final;
#gc.collect()

target["TARGET"].fillna(0, inplace=True)
target["TARGET"] =  target["TARGET"].astype(np.int32)
target["DATE_EXP"] = period_to_load
target["DATE_CALC"] = date
target.rename({"FECHA": "FECHA_TARGET"}, inplace=True)

# %%
target.TARGET.value_counts()
# Out:
# 0    117042
# 1       121
# Name: TARGET, dtype: int64

# %%
def create_target_upsell(upgrades_basicos: SQLPartitionedDataSet,
                         eop: SQLPartitionedDataSet,
                         agendas_basicos: SQLPartitionedDataSet,
                         cliente_activo: pd.DataFrame,
                         parameters: Dict,
                         date: str) -> pd.DataFrame:
    """Function that takes care of generating the target feature for the up-sell model
    Up-selling includes:
        - Switching to a higher level of service on the same tecnology (e.g., from Silver SD to Gold SD)

    Target definition:
        - Existing customer switches service.
        - Stays with new product for at least 84 days

    Target methodology:
        0. Definition of product ranking (update as needed)
        1. Loading of customer base (e.g., all post-paid customers in Colombia)
        2. Loading of upgrade events (108) for period of interest (calculation_window)
        3. Loading of events (107,108,133,142) to detect customers that switch products for period of
        interest (activation_window)
        4. For customers that have an event (108) in the calculation_window, compare previous service to new one to determine if it
    is an upgrade using the product ranking.
        5. For said customers in (4), check if another event happens in the activation_window after the 108 event. If it does not happen, then the
    customers are target for the model.

    Parameters
    ----------
    upgrades_basicos: 
        dataset defined in ``catalog_raw.yml`` with raw data information related to upgrades of programming service products
    eop:
        dataset defined in ``catalog_raw.yml`` with raw data information related to the client's EoP state
    date:
        period to process
    parameters:
        set of project parameters defined in ``parameters.yml``
    
    Returns
    -------
    pd.DataFrame
        Master table with up-sell target feature for one period (date+1; date+calculation_window)
    """

    # Initialize logger
    log = initialize_logger()
    
    table_name = "target_upsell"
    write_to_parquet = parameters["write_to_parquet"]
    overwrite = parameters["targets"][table_name]["overwrite"]
    end_date = str(parameters["end_date"])
    log.info(f"Start the process of create upsell target for {date}")
    
    # Check if target can be created (date + max window < previous sunday)
    target_parameters = parameters["targets"][table_name]
    max_window = max([target_parameters[x] for x in target_parameters.keys() if x.endswith("window")])
    upper_bound = (pd.to_datetime(date) + timedelta(days=max_window)).strftime("%Y%m%d")
    previous_sunday = dt.today() - timedelta(days=dt.today().weekday() + 1)
    
    if pd.to_datetime(upper_bound, format="%Y%m%d") > previous_sunday:
        log.info(f"Cannot create upsell target for {date}: Not enough future information")
        return None

    # Compare with what is already processed
    path = f"{parameters['paths']['target_path']}{table_name}/"
    os.makedirs(path, exist_ok=True)
    processed_dates = os.listdir(path)
    match = [file for file in processed_dates if str(date) in file]
    if len(match) > 0 and overwrite is False:
        # If table is found, read parquet:
        log.info(f"Reading {match[0]} table")
        df_final = pd.read_parquet(path + match[0], engine="pyarrow")

    else:
        product_rank = parameters["targets"]["target_upsell"]["upsell_products_rank"]
        products_allowed_to_move=parameters["targets"]["target_upsell"]["products_allowed_to_move"]
        product_tecnology=parameters["targets"]["target_upsell"]["product_and_tecnology"]
        product_tecnology = {value : key for (key, value) in product_tecnology.items()}

        start_date = date
        end_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["calculation_window"])).strftime("%Y%m%d")
        cancel_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["activation_window"])).strftime("%Y%m%d")

        # Get EoP active clients from previous period to exclude new clients
        period_to_load = get_previous_month(start_date)
        df_clientes = eop.filter_by(condition=f"PRC_TIPO_ID = 3 AND PRC_CODIGO  IN {tuple(products_allowed_to_move)}",
                                     #base of customers that can made an upgrade
                                     date=period_to_load)

        # Get the user tecnology
        df_clientes["tecno_eop"]=df_clientes["PRC_CODIGO"].map(product_tecnology)
        df_clientes["tecno_eop"]=[y.split(" ")[2] for x,y in enumerate(df_clientes["tecno_eop"])]

        # Get data for target creation
        moves=tuple([ value[0] for (key,value) in product_rank.items()])
        df_upgrades = upgrades_basicos.filter_by(condition=f"EVENTO_ID = 108 AND PRODUCTO_ID IN {moves}",
                                                 date=[start_date, end_date],
                                                 target=True)
        #Tecnology of the basic product.
        df_upgrades["tecno_up"]=[y.split(" ")[2] for x,y in enumerate(df_upgrades.PRODUCTO_ID.map(product_tecnology))]

        df_cancelations = upgrades_basicos.filter_by(date=[start_date,
                                                           cancel_date],
                                                     target=True)

        df_clientes_upgrades = pd.merge(
            df_clientes[["CUSTOMER_ID", "PRC_CODIGO","tecno_eop"]],
            df_upgrades[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA","tecno_up"]],
            on=["CUSTOMER_ID"],
            how="inner",
            validate="1:m")
        del df_upgrades;
        gc.collect()

        df_clientes_upgrades.sort_values(["CUSTOMER_ID", "PRC_CODIGO", "FECHA"], ascending=[False, False, True],
                                         inplace=True)
        df_clientes_upgrades.drop_duplicates(subset=["CUSTOMER_ID", "PRC_CODIGO"], keep="last", inplace=True)

        df_product_rank = pd.DataFrame(product_rank.items(), columns=["PRODUCTO_RANK_INI", "PRC_CODIGO"])
        df_product_rank = df_product_rank.explode("PRC_CODIGO")


            # Rank initial product (PRC_CODIGO) from EOP table
        df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades,
                                               df_product_rank,
                                               on="PRC_CODIGO",
                                               how="left",
                                               validate="m:1")

        del df_clientes_upgrades
        gc.collect()

        # Rank last product (PRODUCTO_ID) from plan_evento table
        df_product_rank.rename(columns={"PRC_CODIGO": "PRODUCTO_ID",
                                        "PRODUCTO_RANK_INI": "PRODUCTO_RANK_END"}, inplace=True)
        df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades_ranked,
                                               df_product_rank,
                                               on="PRODUCTO_ID",
                                               how="left",
                                               validate="m:1")

        #Solving the situation of MIX, this tecnology is SD
        df_clientes_upgrades_ranked["tecno_eop"]=np.where(df_clientes_upgrades_ranked.tecno_eop.isin(["MIX"]),"SD",df_clientes_upgrades_ranked.tecno_eop)
        df_clientes_upgrades_ranked["tecno_up"]=np.where(df_clientes_upgrades_ranked.tecno_up.isin(["MIX"]),"SD",df_clientes_upgrades_ranked.tecno_up)
        
        # Calculate target based on initial and end product plus tecnology
        df_clientes_upgrades_ranked["TARGET"] = np.where((df_clientes_upgrades_ranked["PRODUCTO_RANK_END"] > \
                                                         df_clientes_upgrades_ranked["PRODUCTO_RANK_INI"]) & ((df_clientes_upgrades_ranked["tecno_eop"] == \
                                                                                                               df_clientes_upgrades_ranked["tecno_up"])), 1, 0)

        # Keep only first move by CUSTOMER, PRODUCT
        df_cancelations.sort_values(["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"], ascending=[False, False, True], inplace=True)
        df_cancelations.drop_duplicates(subset=["CUSTOMER_ID", "PRODUCTO_ID"], keep="last", inplace=True)

        # Merge with target df to check for activation period
        df_target = pd.merge(df_clientes_upgrades_ranked,
                             df_cancelations[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"]],
                             on=["CUSTOMER_ID", "PRODUCTO_ID"],
                             how="left",
                             validate="1:m")

        del df_clientes_upgrades_ranked, df_cancelations;
        gc.collect()

        # Compute time difference between events
        df_target["DATE_DIFF"] = (df_target["FECHA_y"] - df_target["FECHA_x"]) / np.timedelta64(1, "D")
        log.info(f" Number of events 108 ending as upgrades before product changes rule {df_target.TARGET.sum()}")

        df_target["TARGET"] = np.where((df_target["DATE_DIFF"] > 0) & \
                                       (df_target["DATE_DIFF"] <= parameters["targets"]["target_upsell"][
                                           "activation_window"]),
                                       0,
                                       df_target["TARGET"])
        df_target = drop_extra_rename_remaining(df_target)
        log.info(f" Number of events 108 ending as upgrades after product changes rule {df_target.TARGET.sum()}")

        # Merge back to EOP
        df_final = pd.merge(df_clientes[["CUSTOMER_ID", "PRC_CODIGO"]],
                            df_target[["CUSTOMER_ID", "TARGET", "FECHA", "PRODUCTO_ID"]],
                            on="CUSTOMER_ID",
                            how="left",
                            validate="1:1")
        
        target=df_final.loc[df_final.CUSTOMER_ID.isin(cliente_activo.CUSTOMER_ID.unique())]
        
        del df_target, df_final;
        gc.collect()

        target["TARGET"].fillna(0, inplace=True)
        target["TARGET"] =  target["TARGET"].astype(np.int32)
        target["DATE_EXP"] = period_to_load
        target["DATE_CALC"] = date
        target.rename({"FECHA": "FECHA_TARGET"}, inplace=True)
        
        if write_to_parquet:
            file = f"{parameters['paths']['target_path']}{table_name}/{table_name}_{date}.parquet"
            target.to_parquet(file, engine="pyarrow")

        # Return
        log.info(
            f"""Exporting target for period {start_date} and rate {
            np.round(100 * target[target['TARGET'] == 1]['CUSTOMER_ID'].nunique() / target['CUSTOMER_ID'].nunique(), 2)
            }%""")

    return target

# %%
dates=calculate_dates_to_process_for_target(parameters,'target_upsell_noagenda')
print(dates)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-226-d741832bcc08> in <module>
# ----> 1 dates=calculate_dates_to_process_for_target(parameters,'target_upsell_noagenda')
#       2 print(dates)
#
# /u01/share/cesar/aa_engine_uy/src/aa_engine_pkg/assets/utils/utilities.py in calculate_dates_to_process_for_target(parameters, table_name)
#     223     end_date = str(parameters["end_date"])
#     224     rolling_window = parameters["rolling_window_target"]
# --> 225     target_parameters = parameters["targets"][table_name]
#     226
#     227     max_window = [target_parameters[x] for x in target_parameters.keys() if x.endswith("window")]
#
# KeyError: 'target_upsell_noagenda'

# %%
for date in dates:
    print(date)
    cliente_activo_df= create_cliente_activo(cliente_activo,date)
    create_target_upsell(upgrades_basicos, eop, cliente_activo_df,parameters,date)
# Out:
# 20181203
# 2021-01-13 19:09:58,421 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# /u01/miniconda3/envs/uypo37/lib/python3.7/site-packages/sqlalchemy/dialects/oracle/base.py:1381: SAWarning: Oracle version (19, 5, 0, 0, 0) is known to have a maximum identifier length of 128, rather than the historical default of 30. SQLAlchemy 1.4 will use 128 for this database; please set max_identifier_length=128 in create_engine() in order to test the application with this new length, or set to 30 in order to assure that 30 continues to be used.  In particular, pay close attention to the behavior of database migrations as dynamically generated names may change. See the section 'Max Identifier Lengths' in the SQLAlchemy Oracle dialect documentation for background.
#   % ((self.server_version_info,))
# 2021-01-13 19:10:03,173 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20181203
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201811 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20181231235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190331235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:07,406 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 139
# 2021-01-13 19:10:07,412 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 114
# 2021-01-13 19:10:07,592 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181203 and rate 0.29%
# 20181231
# 2021-01-13 19:10:07,601 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# 2021-01-13 19:10:11,846 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20181231
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201811 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190128235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190428235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:15,647 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 160
# 2021-01-13 19:10:15,652 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 147
# 2021-01-13 19:10:15,830 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181231 and rate 0.37%
# 20190128
# 2021-01-13 19:10:15,837 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201812
# 2021-01-13 19:10:18,526 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190128
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201812 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190225235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190526235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:21,407 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 185
# 2021-01-13 19:10:21,413 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 166
# 2021-01-13 19:10:21,600 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190128 and rate 0.42%
# 20190225
# 2021-01-13 19:10:21,608 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201901
# 2021-01-13 19:10:24,333 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190225
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201901 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190325235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190623235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:27,195 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 194
# 2021-01-13 19:10:27,201 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 177
# 2021-01-13 19:10:27,392 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190225 and rate 0.46%
# 20190325
# 2021-01-13 19:10:27,400 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201902
# 2021-01-13 19:10:30,115 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190325
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201902 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190422235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190721235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:33,236 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 154
# 2021-01-13 19:10:33,242 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 137
# 2021-01-13 19:10:33,424 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190325 and rate 0.36%
# 20190422
# 2021-01-13 19:10:33,431 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201903
# 2021-01-13 19:10:37,252 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190422
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201903 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190520235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190818235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:40,240 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 166
# 2021-01-13 19:10:40,246 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 145
# 2021-01-13 19:10:40,429 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190422 and rate 0.38%
# 20190520
# 2021-01-13 19:10:40,436 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201904
# 2021-01-13 19:10:43,188 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190520
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201904 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190617235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190915235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:46,694 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 221
# 2021-01-13 19:10:46,700 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 195
# 2021-01-13 19:10:46,883 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190520 and rate 0.51%
# 20190617
# 2021-01-13 19:10:46,891 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201905
# 2021-01-13 19:10:49,723 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190617
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201905 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190715235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191013235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:52,505 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 158
# 2021-01-13 19:10:52,511 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 144
# 2021-01-13 19:10:52,698 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190617 and rate 0.38%
# 20190715
# 2021-01-13 19:10:52,706 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201906
# 2021-01-13 19:10:55,510 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190715
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201906 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190812235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191110235900', 'yyyymmddhh24miss')
# 2021-01-13 19:10:58,884 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 272
# 2021-01-13 19:10:58,890 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 253
# 2021-01-13 19:10:59,060 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190715 and rate 0.66%
# 20190812
# 2021-01-13 19:10:59,067 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201907
# 2021-01-13 19:11:03,106 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190812
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201907 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190909235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191208235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:06,311 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 167
# 2021-01-13 19:11:06,317 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 157
# 2021-01-13 19:11:06,501 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190812 and rate 0.41%
# 20190909
# 2021-01-13 19:11:06,508 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201908
# 2021-01-13 19:11:11,083 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190909
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201908 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191007235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200105235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:14,377 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 193
# 2021-01-13 19:11:14,383 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 179
# 2021-01-13 19:11:14,572 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190909 and rate 0.46%
# 20191007
# 2021-01-13 19:11:14,579 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201909
# 2021-01-13 19:11:17,038 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191007
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201909 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191104235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200202235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:20,165 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 178
# 2021-01-13 19:11:20,171 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 161
# 2021-01-13 19:11:20,361 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191007 and rate 0.41%
# 20191104
# 2021-01-13 19:11:20,368 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201910
# 2021-01-13 19:11:23,370 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191104
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201910 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191202235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200301235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:26,795 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 141
# 2021-01-13 19:11:26,803 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 131
# 2021-01-13 19:11:27,059 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191104 and rate 0.33%
# 20191202
# 2021-01-13 19:11:27,069 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# 2021-01-13 19:11:29,806 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191202
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201911 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191230235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200329235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:32,917 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 132
# 2021-01-13 19:11:32,923 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 116
# 2021-01-13 19:11:33,095 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191202 and rate 0.29%
# 20191230
# 2021-01-13 19:11:33,102 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# 2021-01-13 19:11:35,558 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191230
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201911 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200127235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200426235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:39,066 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 147
# 2021-01-13 19:11:39,073 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 126
# 2021-01-13 19:11:39,250 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191230 and rate 0.32%
# 20200127
# 2021-01-13 19:11:39,257 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201912
# 2021-01-13 19:11:41,545 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200127
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201912 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200224235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200524235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:44,278 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 153
# 2021-01-13 19:11:44,285 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 140
# 2021-01-13 19:11:44,484 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200127 and rate 0.35%
# 20200224
# 2021-01-13 19:11:44,492 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202001
# 2021-01-13 19:11:47,291 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200224
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202001 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200323235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200621235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:49,851 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 158
# 2021-01-13 19:11:49,858 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 138
# 2021-01-13 19:11:50,044 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200224 and rate 0.35%
# 20200323
# 2021-01-13 19:11:50,052 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202002
# 2021-01-13 19:11:52,096 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200323
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202002 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200420235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200719235900', 'yyyymmddhh24miss')
# 2021-01-13 19:11:55,166 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 134
# 2021-01-13 19:11:55,172 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 120
# 2021-01-13 19:11:55,366 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200323 and rate 0.3%
# 20200420
# 2021-01-13 19:11:55,373 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202003
# 2021-01-13 19:12:00,335 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200420
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202003 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200518235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200816235900', 'yyyymmddhh24miss')
# 2021-01-13 19:12:04,621 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 93
# 2021-01-13 19:12:04,627 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 78
# 2021-01-13 19:12:04,806 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200420 and rate 0.19%
# 20200518
# 2021-01-13 19:12:04,813 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202004
# 2021-01-13 19:12:08,976 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200518
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202004 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200615235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200913235900', 'yyyymmddhh24miss')
# 2021-01-13 19:12:12,727 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 239
# 2021-01-13 19:12:12,732 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 215
# 2021-01-13 19:12:12,910 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200518 and rate 0.53%
# 20200615
# 2021-01-13 19:12:12,917 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202005
# 2021-01-13 19:12:17,384 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200615
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202005 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200713235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201011235900', 'yyyymmddhh24miss')
# 2021-01-13 19:12:21,372 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 172
# 2021-01-13 19:12:21,378 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 154
# 2021-01-13 19:12:21,568 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200615 and rate 0.38%
# 20200713
# 2021-01-13 19:12:21,575 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202006
# 2021-01-13 19:12:26,941 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200713
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202006 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200810235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201108235900', 'yyyymmddhh24miss')
# 2021-01-13 19:12:30,523 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 149
# 2021-01-13 19:12:30,529 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 135
# 2021-01-13 19:12:30,717 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200713 and rate 0.33%
# 20200810
# 2021-01-13 19:12:30,725 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202007
# 2021-01-13 19:12:34,832 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200810
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202007 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200907235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201206235900', 'yyyymmddhh24miss')
# 2021-01-13 19:12:38,537 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 232
# 2021-01-13 19:12:38,543 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 201
# 2021-01-13 19:12:38,732 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200810 and rate 0.48%
# 20200907
# 2021-01-13 19:12:38,739 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202008
# 2021-01-13 19:12:43,386 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200907
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202008 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169, 132)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201005235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20210103235900', 'yyyymmddhh24miss')
# 2021-01-13 19:12:47,197 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades before product changes rule 182
# 2021-01-13 19:12:47,203 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after product changes rule 165
# 2021-01-13 19:12:47,382 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200907 and rate 0.39%

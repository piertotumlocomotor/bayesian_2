# %% [markdown]
# ### Generacion de target para modelos de upsell.
# #### Consideracines:
# 1. Se considera como target los eventos 108 que impliquen un incremento en el revenue del producto basico.
# 2. Que el nuevo producto se mantenga por aproximadamente 3 meses.
# 3. Ya que algunos eventos 108 son posteriores a eventos 100108 (agendas) consideraremos como target los siguentes casos:
# - Agendas en el periodo de interes.
# - Los upgrades en el perido de interes que no tuvieron una agenda previa.
#
# Esquema.
#
#
#               start_date_agendas   start_date          end_date       end_date_upgrade  cancel_date
#         --------------|-----------------|-----------------|-----------------|-----------------|------------------

# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")
from aa_engine_pkg.assets.utils import *
from aa_engine_pkg.assets.core.data.kedro.catalog_expansion.partitioned_sql import SQLPartitionedDataSet

# %%
upgrades_basicos=catalog.load('upgrades_basicos')
eop=catalog.load("eop")
cliente_activo=catalog.load("cliente_activo")
agendas_basicos=catalog.load("agendas_basicos")
# Out:
# 2021-03-25 20:55:15,958 - kedro.io.data_catalog - INFO - Loading data from `upgrades_basicos` (SQLPartitionedDataSet)...
# 2021-03-25 20:55:15,960 - kedro.io.data_catalog - INFO - Loading data from `eop` (SQLPartitionedDataSet)...
# 2021-03-25 20:55:15,961 - kedro.io.data_catalog - INFO - Loading data from `cliente_activo` (SQLPartitionedDataSet)...
# 2021-03-25 20:55:15,962 - kedro.io.data_catalog - INFO - Loading data from `agendas_basicos` (SQLPartitionedDataSet)...

# %%
def create_cliente_activo(cliente_activo: SQLPartitionedDataSet,
                          date: str) -> pd.DataFrame:
    """Creates master table with features related to EoP state of customers for one period of data

    Parameters
    ----------
    cliente_activo:
        dataset defined in ´catalog.yml´ - list of active customers at EoP for the given period
    date:
        period to process
    
    Returns
    -------
        Mastertable with information of clientes at EoP
    """

    # Initialize logger
    log = initialize_logger()

    # Load active clientes for period
    log.info(f"Creating cliente_activo...")
    period_to_load = get_previous_month(date)
    df_clientes_activos = cliente_activo.filter_by(date=period_to_load)

    # Return
    return df_clientes_activos

# %%
def create_target_upsell(upgrades_basicos: SQLPartitionedDataSet,
                         eop: SQLPartitionedDataSet,
                         agendas_basicos: SQLPartitionedDataSet,
                         cliente_activo: pd.DataFrame,
                         parameters: Dict,
                        date: str) -> None:

    
    """
    The following function will define the target variable for the upsell model of Basic products, considering:
    #### Products from PLAN VIGENTE including :
        - DIRECTV ACCES MIX
        - DIRECTV BRONCE SD
        - DIRECTV BRONCE HD ONLY
        - DIRECTV PLATA SD
        - DIRECTV PLATA HD ONLY
        - DIRECTV ORO MIX
        - DIRECTV ORO HD ONLY
    #### Target definition:
        - Existing customer upgrades product.
        - Stays active for 3 or more months (end of discount price period)
    ---
    ## Target methodology
        1. Definition of possible product upgrades
        2. Loading customer base (EOP)
        3. Loading upgrade events (108) for the period of interest (calculation window)
        4. Loading potential cancellation events (142,133) for the cancellation window (3 months)
        5. Loading agendas.
    Parameters
    ----------
    upgrades_basicos:
        dataset defined in ``catalog_raw.yml`` with raw data information related to upgrades of Basic products
    eop:
        dataset defined in ``catalog_raw.yml`` with raw data information related to the client's EOP state
    cliente_activo:
        pandas dataframe with active customers for period
    date:
        period to process
    parameters:
        set of project parameters defined in ``parameters.yml``
    Returns
    -------
    pd.DataFrame
        pandas dataframe with xsell target for period
    """
    
    # Initialize logger
    log = initialize_logger()
    
    table_name = "target_upsell"
    write_to_parquet = parameters["write_to_parquet"]
    overwrite = parameters["targets"][table_name]["overwrite"]
    end_date = str(parameters["end_date"])
    log.info(f"Start the process of create upsell target for {date}")
    
    # Check if target can be created (date + max window < previous sunday)
    target_parameters = parameters["targets"][table_name]
    max_window = max([target_parameters[x] for x in target_parameters.keys() if x.endswith("window")])
    upper_bound = (pd.to_datetime(date) + timedelta(days=max_window)).strftime("%Y%m%d")
    previous_sunday = dt.today() - timedelta(days=dt.today().weekday() + 1)
    
    if pd.to_datetime(upper_bound, format="%Y%m%d") > previous_sunday:
        log.info(f"Cannot create upsell target for {date}: Not enough future information")
        return None

    # Compare with what is already processed
    path = f"{parameters['paths']['target_path']}{table_name}/"
    os.makedirs(path, exist_ok=True)
    processed_dates = os.listdir(path)
    match = [file for file in processed_dates if str(date) in file]
    if len(match) > 0 and overwrite is False:
        # If table is found, read parquet:
        log.info(f"Reading {match[0]} table")
        df_final = pd.read_parquet(path + match[0], engine="pyarrow")

    else:
        
        product_rank = parameters["targets"]["target_upsell"]["upsell_products_rank"]
        product_tecnology=parameters["targets"]["target_upsell"]["product_and_tecnology"]
        product_tecnology = {value : key for (key, value) in product_tecnology.items()}

        start_date = date
        end_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["calculation_window"])
                    ).strftime("%Y%m%d")
        cancel_date = (pd.to_datetime(date) + timedelta(days=parameters["targets"]["target_upsell"]["activation_window"])
                       ).strftime("%Y%m%d")

        end_date_upgrades = (pd.to_datetime(date) + timedelta(days=2*parameters["targets"]["target_upsell"]["calculation_window"])).strftime("%Y%m%d")

        start_date_agendas = (pd.to_datetime(start_date)-timedelta(days=28)).strftime("%Y%m%d")
        
        # Get EoP active clients from previous period to exclude new clients
        products_allowed_to_move=tuple([key for (key, value) in product_tecnology.items() if value.find('ORO')==-1]) 
        period_to_load = get_previous_month(start_date)
        df_clientes = eop.filter_by(condition=f"PRC_TIPO_ID = 3 AND PRC_CODIGO  IN {products_allowed_to_move}",
                                     #base of customers that can made an upgrade
                                     date=period_to_load)
        log.info(f"EOP shape {df_clientes.shape[0]}")
        # Get the user tecnology
        df_clientes["tecno_eop"]=df_clientes["PRC_CODIGO"].map(product_tecnology)
        df_clientes["tecno_eop"]=[y.split(" ")[2] for x,y in enumerate(df_clientes["tecno_eop"])]
        df_clientes["tecno_eop"]=np.where(df_clientes.tecno_eop=="MIX","SD",df_clientes.tecno_eop)

        # Get Upgrades for target creation
        products_allowed_to_move=tuple([key for (key, value) in product_tecnology.items()]) 
        df_upgrades = upgrades_basicos.filter_by(condition=f"EVENTO_ID = 108 AND PRODUCTO_ID IN {products_allowed_to_move}",
                                                 date=[start_date, end_date_upgrades],
                                                 target=True)
        #Tecnology of the basic product.
        df_upgrades["tecno_up"]=[y.split(" ")[2] for x,y in enumerate(df_upgrades.PRODUCTO_ID.map(product_tecnology))]
        df_upgrades["tecno_up"]=np.where(df_upgrades.tecno_up=="MIX","SD",df_upgrades.tecno_up)
        
        #Get Agendas
        df_agenda = agendas_basicos.filter_by(date=[start_date_agendas, end_date])
        df_agenda.rename(columns={"FECHA":"FECHA_AGENDA"},inplace=True)
        
        #Get Cancelations
        df_cancelations = upgrades_basicos.filter_by(date=[start_date,cancel_date], target=True)
        # Keep only first cancellation by CUSTOMER, PRODUCT
        df_cancelations.sort_values(["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"], ascending=[False, False, True],
                                        inplace=True)
        df_cancelations.drop_duplicates(subset=["CUSTOMER_ID", "PRODUCTO_ID"], keep="last", inplace=True)

        df_clientes_upgrades = pd.merge(
                    df_clientes[["CUSTOMER_ID", "PRC_CODIGO","tecno_eop"]],
                    df_upgrades[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA","tecno_up"]],
                    on=["CUSTOMER_ID"],
                    how="inner",
                    validate="1:m")

        df_clientes_upgrades.sort_values(["CUSTOMER_ID", "PRC_CODIGO", "FECHA"], ascending=[False, False, True],inplace=True)
        df_clientes_upgrades.drop_duplicates(subset=["CUSTOMER_ID", "PRC_CODIGO"], keep="last", inplace=True)
        
        del df_upgrades;
        gc.collect()
        
        # Rank initial product (PRC_CODIGO) from EOP table
        df_product_rank = pd.DataFrame(product_rank.items(), columns=["PRODUCTO_RANK_INI", "PRC_CODIGO"]).explode("PRC_CODIGO")
        df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades,
                                           df_product_rank,
                                           on="PRC_CODIGO",
                                           how="left",
                                           validate="m:1")

        # Rank last product (PRODUCTO_ID) from plan_evento table
        df_product_rank.rename(columns={"PRC_CODIGO": "PRODUCTO_ID","PRODUCTO_RANK_INI": "PRODUCTO_RANK_END"}, inplace=True)
        df_clientes_upgrades_ranked = pd.merge(df_clientes_upgrades_ranked,
                                               df_product_rank,
                                               on="PRODUCTO_ID",
                                               how="left",
                                               validate="m:1")
        
        # Calculate target based on initial and end product plus tecnology
        mask=(df_clientes_upgrades_ranked["PRODUCTO_RANK_END"] > df_clientes_upgrades_ranked["PRODUCTO_RANK_INI"]) & (df_clientes_upgrades_ranked["tecno_eop"] ==df_clientes_upgrades_ranked["tecno_up"])
        df_clientes_upgrades_ranked["TARGET"] = np.where(mask, 1, 0)
        log.info(f" Number of events 108 ending as upgrades {df_clientes_upgrades_ranked.TARGET.sum()}")
        
        # Merge with target df to check for activation period
        df_target = pd.merge(df_clientes_upgrades_ranked,
                             df_cancelations[["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"]],
                             on=["CUSTOMER_ID", "PRODUCTO_ID"],
                             how="left")
        
        del df_clientes_upgrades_ranked,df_cancelations;
        gc.collect()


        # Compute time difference between events
        df_target["DATE_DIFF"] = (df_target["FECHA_y"] - df_target["FECHA_x"]) / np.timedelta64(1, "D")
        df_target["TARGET"] = np.where((df_target["DATE_DIFF"] > 0) & \
                                       (df_target["DATE_DIFF"] <= parameters["targets"]["target_upsell"][
                                           "activation_window"]),
                                       0,
                                       df_target["TARGET"])
        log.info(f" Number of events 108 ending as upgrades after cancelation rule {df_target.TARGET.sum()}")
        df_target = drop_extra_rename_remaining(df_target)
        
        # Remove duplicates prioritizing upgrades
        df_target.sort_values(["CUSTOMER_ID", "TARGET"], ascending=False,inplace=True)
        df_target.drop_duplicates(subset=["CUSTOMER_ID"], keep="first", inplace=True)


        # quitar upgrades agendados el mes anterior
        df_final = pd.merge(df_target,
                        df_agenda,
                        left_on=['CUSTOMER_ID','PRC_CODIGO'],
                        right_on=['CUSTOMER_ID','PRODUCTO_ID'],
                        how='left')
        
        # quitar agendas mes anterior
        upgrades_agendados_antes = df_final[(df_final.FECHA_AGENDA)<(pd.to_datetime(start_date)).strftime("%Y%m%d")]
        df_final = df_final.drop(upgrades_agendados_antes.index)
        log.info(f" Number of events 108 ending as upgrades after agenda rule {df_final.TARGET.sum()}")
        
        # quitar upgrades mes futuro no agendados este mes
        upgrades_futuros = df_final[df_final.FECHA>(pd.to_datetime(start_date)+timedelta(days=28)).strftime("%Y%m%d")]
        df_final = df_final.drop(upgrades_futuros[upgrades_futuros.FECHA_AGENDA.isna()].index)
        log.info(f" Number of events 108 ending as upgrades after upgrades future rule {df_final.TARGET.sum()}")

        df_final.sort_values(["CUSTOMER_ID", "TARGET"], ascending=False,inplace=True)
        df_final.drop_duplicates(subset=["CUSTOMER_ID"], keep="first", inplace=True)
        
        # Merge back to EOP
        df_final= drop_extra_rename_remaining(df_final) 
       
        df_final = pd.merge(df_clientes[["CUSTOMER_ID", "PRC_CODIGO"]],
                            df_final[["CUSTOMER_ID", "TARGET", "FECHA", "PRODUCTO_ID"]],
                            on="CUSTOMER_ID",
                            how="left",
                            validate="1:1")

        target=df_final.loc[df_final.CUSTOMER_ID.isin(cliente_activo.CUSTOMER_ID.unique())]
        
        del df_target, df_final;
        gc.collect()
        
        target["TARGET"].fillna(0, inplace=True)
        target["TARGET"] =  target["TARGET"].astype(np.int32)
        target["DATE_EXP"] = period_to_load
        target["DATE_CALC"] = date
        target.rename({"FECHA": "FECHA_TARGET"}, inplace=True)
        
        if write_to_parquet:
            file = f"{parameters['paths']['target_path']}{table_name}/{table_name}_{date}.parquet"
            target.to_parquet(file, engine="pyarrow")

        # Return
        log.info(f"size {target.shape[0]}")
        log.info(
            f"""Exporting target for period {start_date} and rate {
            np.round(100 * target.loc[target['TARGET'] == 1]['CUSTOMER_ID'].nunique() / target['CUSTOMER_ID'].nunique(), 2)
            }%""")

    return None

# %%
dates=calculate_dates_to_process_for_target(parameters,'target_upsell')
print(dates)
# Out:
# ['20181203', '20181231', '20190128', '20190225', '20190325', '20190422', '20190520', '20190617', '20190715', '20190812', '20190909', '20191007', '20191104', '20191202', '20191230', '20200127', '20200224', '20200323', '20200420', '20200518', '20200615', '20200713', '20200810', '20200907', '20201005', '20201102', '20201130', '20201228', '20210125', '20210222', '20210322', '20210419', '20210517', '20210614', '20210712']

# %%
for date in dates:
    cliente_activo_df=create_cliente_activo(cliente_activo,date)
    create_target_upsell(upgrades_basicos,
                         eop,
                         agendas_basicos,
                         cliente_activo_df,
                         parameters,
                         date)
# Out:
# 2021-03-25 21:03:05,748 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# 2021-03-25 21:03:08,458 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20181203
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201811 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:03:09,537 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 18942
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190128235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20181105', 'yyyymmdd') and FECHA < to_date('20181231', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190331235900', 'yyyymmddhh24miss')
# 2021-03-25 21:03:11,482 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 296
# 2021-03-25 21:03:11,553 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 265
# 2021-03-25 21:03:11,572 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 256
# 2021-03-25 21:03:11,576 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 135
# 2021-03-25 21:03:11,714 - aa_engine_pkg.assets.utils.utilities - INFO - size 18942
# 2021-03-25 21:03:11,718 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181203 and rate 0.7%
# 2021-03-25 21:03:11,722 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# 2021-03-25 21:03:16,611 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20181231
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201811 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:03:17,736 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 18942
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190225235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20181203', 'yyyymmdd') and FECHA < to_date('20190128', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190428235900', 'yyyymmddhh24miss')
# 2021-03-25 21:03:19,722 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 333
# 2021-03-25 21:03:19,797 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 314
# 2021-03-25 21:03:19,815 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 287
# 2021-03-25 21:03:19,820 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 148
# 2021-03-25 21:03:19,957 - aa_engine_pkg.assets.utils.utilities - INFO - size 18942
# 2021-03-25 21:03:19,960 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181231 and rate 0.78%
# 2021-03-25 21:03:19,964 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201812
# 2021-03-25 21:03:24,995 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190128
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201812 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:03:26,076 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 18924
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190325235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20181231', 'yyyymmdd') and FECHA < to_date('20190225', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190526235900', 'yyyymmddhh24miss')
# 2021-03-25 21:03:29,033 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 365
# 2021-03-25 21:03:29,113 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 341
# 2021-03-25 21:03:29,131 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 298
# 2021-03-25 21:03:29,136 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 150
# 2021-03-25 21:03:29,276 - aa_engine_pkg.assets.utils.utilities - INFO - size 18924
# 2021-03-25 21:03:29,280 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190128 and rate 0.79%
# 2021-03-25 21:03:29,283 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201901
# 2021-03-25 21:03:33,465 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190225
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201901 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:03:34,807 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 18859
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190422235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190128', 'yyyymmdd') and FECHA < to_date('20190325', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190623235900', 'yyyymmddhh24miss')
# 2021-03-25 21:03:37,241 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 341
# 2021-03-25 21:03:37,313 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 317
# 2021-03-25 21:03:37,331 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 287
# 2021-03-25 21:03:37,335 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 166
# 2021-03-25 21:03:37,481 - aa_engine_pkg.assets.utils.utilities - INFO - size 18858
# 2021-03-25 21:03:37,484 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190225 and rate 0.88%
# 2021-03-25 21:03:37,490 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201902
# 2021-03-25 21:03:42,084 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190325
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201902 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:03:43,905 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 18917
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190520235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190225', 'yyyymmdd') and FECHA < to_date('20190422', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190721235900', 'yyyymmddhh24miss')
# 2021-03-25 21:03:47,346 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 300
# 2021-03-25 21:03:47,417 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 271
# 2021-03-25 21:03:47,435 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 247
# 2021-03-25 21:03:47,439 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 132
# 2021-03-25 21:03:47,582 - aa_engine_pkg.assets.utils.utilities - INFO - size 18917
# 2021-03-25 21:03:47,586 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190325 and rate 0.69%
# 2021-03-25 21:03:47,590 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201903
# 2021-03-25 21:03:52,063 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190422
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201903 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:03:54,286 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 18933
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190617235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190325', 'yyyymmdd') and FECHA < to_date('20190520', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190818235900', 'yyyymmddhh24miss')
# 2021-03-25 21:03:59,424 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 364
# 2021-03-25 21:03:59,497 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 335
# 2021-03-25 21:03:59,515 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 311
# 2021-03-25 21:03:59,519 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 131
# 2021-03-25 21:03:59,657 - aa_engine_pkg.assets.utils.utilities - INFO - size 18933
# 2021-03-25 21:03:59,661 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190422 and rate 0.69%
# 2021-03-25 21:03:59,665 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201904
# 2021-03-25 21:04:04,254 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190520
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201904 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:04:05,569 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 19277
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190715235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190422', 'yyyymmdd') and FECHA < to_date('20190617', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190915235900', 'yyyymmddhh24miss')
# 2021-03-25 21:04:09,637 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 370
# 2021-03-25 21:04:09,710 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 334
# 2021-03-25 21:04:09,730 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 316
# 2021-03-25 21:04:09,735 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 183
# 2021-03-25 21:04:09,878 - aa_engine_pkg.assets.utils.utilities - INFO - size 19277
# 2021-03-25 21:04:09,882 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190520 and rate 0.94%
# 2021-03-25 21:04:09,885 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201905
# 2021-03-25 21:04:14,865 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190617
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201905 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:04:16,315 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 19493
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190812235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190520', 'yyyymmdd') and FECHA < to_date('20190715', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191013235900', 'yyyymmddhh24miss')
# 2021-03-25 21:04:18,939 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 414
# 2021-03-25 21:04:19,014 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 389
# 2021-03-25 21:04:19,032 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 376
# 2021-03-25 21:04:19,036 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 135
# 2021-03-25 21:04:19,178 - aa_engine_pkg.assets.utils.utilities - INFO - size 19493
# 2021-03-25 21:04:19,181 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190617 and rate 0.68%
# 2021-03-25 21:04:19,185 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201906
# 2021-03-25 21:04:24,087 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190715
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201906 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:04:25,689 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 19652
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190909235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190617', 'yyyymmdd') and FECHA < to_date('20190812', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191110235900', 'yyyymmddhh24miss')
# 2021-03-25 21:04:27,619 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 428
# 2021-03-25 21:04:27,692 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 408
# 2021-03-25 21:04:27,710 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 398
# 2021-03-25 21:04:27,715 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 231
# 2021-03-25 21:04:27,856 - aa_engine_pkg.assets.utils.utilities - INFO - size 19652
# 2021-03-25 21:04:27,859 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190715 and rate 1.18%
# 2021-03-25 21:04:27,863 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201907
# 2021-03-25 21:04:33,090 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190812
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201907 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:04:35,815 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 19928
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191007235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190715', 'yyyymmdd') and FECHA < to_date('20190909', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191208235900', 'yyyymmddhh24miss')
# 2021-03-25 21:04:38,156 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 344
# 2021-03-25 21:04:38,230 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 328
# 2021-03-25 21:04:38,248 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 322
# 2021-03-25 21:04:38,252 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 152
# 2021-03-25 21:04:38,392 - aa_engine_pkg.assets.utils.utilities - INFO - size 19928
# 2021-03-25 21:04:38,396 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190812 and rate 0.75%
# 2021-03-25 21:04:38,400 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201908
# 2021-03-25 21:04:43,820 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20190909
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201908 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:04:45,641 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 20243
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191104235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190812', 'yyyymmdd') and FECHA < to_date('20191007', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200105235900', 'yyyymmddhh24miss')
# 2021-03-25 21:04:48,304 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 366
# 2021-03-25 21:04:48,373 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 337
# 2021-03-25 21:04:48,391 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 332
# 2021-03-25 21:04:48,396 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 168
# 2021-03-25 21:04:48,539 - aa_engine_pkg.assets.utils.utilities - INFO - size 20243
# 2021-03-25 21:04:48,543 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190909 and rate 0.82%
# 2021-03-25 21:04:48,547 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201909
# 2021-03-25 21:04:53,495 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191007
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201909 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:04:54,631 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 20628
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191202235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20190909', 'yyyymmdd') and FECHA < to_date('20191104', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200202235900', 'yyyymmddhh24miss')
# 2021-03-25 21:04:56,545 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 310
# 2021-03-25 21:04:56,616 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 289
# 2021-03-25 21:04:56,634 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 281
# 2021-03-25 21:04:56,639 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 145
# 2021-03-25 21:04:56,772 - aa_engine_pkg.assets.utils.utilities - INFO - size 20628
# 2021-03-25 21:04:56,776 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191007 and rate 0.7%
# 2021-03-25 21:04:56,780 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201910
# 2021-03-25 21:05:03,163 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191104
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201910 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:05,996 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 21017
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191230235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191007', 'yyyymmdd') and FECHA < to_date('20191202', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200301235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:08,858 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 263
# 2021-03-25 21:05:08,930 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 242
# 2021-03-25 21:05:08,948 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 241
# 2021-03-25 21:05:08,952 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 124
# 2021-03-25 21:05:09,089 - aa_engine_pkg.assets.utils.utilities - INFO - size 21016
# 2021-03-25 21:05:09,092 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191104 and rate 0.59%
# 2021-03-25 21:05:09,097 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# 2021-03-25 21:05:13,003 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191202
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201911 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:14,228 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 21287
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200127235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191104', 'yyyymmdd') and FECHA < to_date('20191230', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200329235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:18,707 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 277
# 2021-03-25 21:05:18,783 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 247
# 2021-03-25 21:05:18,801 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 247
# 2021-03-25 21:05:18,805 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 130
# 2021-03-25 21:05:18,948 - aa_engine_pkg.assets.utils.utilities - INFO - size 21286
# 2021-03-25 21:05:18,952 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191202 and rate 0.6%
# 2021-03-25 21:05:18,956 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# 2021-03-25 21:05:21,663 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20191230
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201911 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:22,519 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 21287
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200224235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191202', 'yyyymmdd') and FECHA < to_date('20200127', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200426235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:24,237 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 283
# 2021-03-25 21:05:24,306 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 258
# 2021-03-25 21:05:24,324 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 238
# 2021-03-25 21:05:24,329 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 119
# 2021-03-25 21:05:24,471 - aa_engine_pkg.assets.utils.utilities - INFO - size 21286
# 2021-03-25 21:05:24,475 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191230 and rate 0.56%
# 2021-03-25 21:05:24,480 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201912
# 2021-03-25 21:05:29,675 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200127
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 201912 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:30,648 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 21543
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200323235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20191230', 'yyyymmdd') and FECHA < to_date('20200224', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200524235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:32,279 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 297
# 2021-03-25 21:05:32,348 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 280
# 2021-03-25 21:05:32,366 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 264
# 2021-03-25 21:05:32,370 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 140
# 2021-03-25 21:05:32,513 - aa_engine_pkg.assets.utils.utilities - INFO - size 21542
# 2021-03-25 21:05:32,517 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200127 and rate 0.62%
# 2021-03-25 21:05:32,521 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202001
# 2021-03-25 21:05:35,184 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200224
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202001 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:36,371 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 21822
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200420235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200127', 'yyyymmdd') and FECHA < to_date('20200323', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200621235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:38,449 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 284
# 2021-03-25 21:05:38,526 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 261
# 2021-03-25 21:05:38,545 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 249
# 2021-03-25 21:05:38,550 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 144
# 2021-03-25 21:05:38,701 - aa_engine_pkg.assets.utils.utilities - INFO - size 21822
# 2021-03-25 21:05:38,705 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200224 and rate 0.66%
# 2021-03-25 21:05:38,709 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202002
# 2021-03-25 21:05:41,607 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200323
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202002 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:42,428 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 22250
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200518235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200224', 'yyyymmdd') and FECHA < to_date('20200420', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200719235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:44,205 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 218
# 2021-03-25 21:05:44,274 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 195
# 2021-03-25 21:05:44,292 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 179
# 2021-03-25 21:05:44,296 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 113
# 2021-03-25 21:05:44,434 - aa_engine_pkg.assets.utils.utilities - INFO - size 22250
# 2021-03-25 21:05:44,437 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200323 and rate 0.5%
# 2021-03-25 21:05:44,441 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202003
# 2021-03-25 21:05:49,576 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200420
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202003 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:50,811 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 22718
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200615235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200323', 'yyyymmdd') and FECHA < to_date('20200518', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200816235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:52,506 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 304
# 2021-03-25 21:05:52,577 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 276
# 2021-03-25 21:05:52,595 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 263
# 2021-03-25 21:05:52,600 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 71
# 2021-03-25 21:05:52,744 - aa_engine_pkg.assets.utils.utilities - INFO - size 22718
# 2021-03-25 21:05:52,748 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200420 and rate 0.31%
# 2021-03-25 21:05:52,752 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202004
# 2021-03-25 21:05:55,696 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200518
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202004 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:05:56,594 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 23006
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200713235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200420', 'yyyymmdd') and FECHA < to_date('20200615', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200913235900', 'yyyymmddhh24miss')
# 2021-03-25 21:05:58,597 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 391
# 2021-03-25 21:05:58,666 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 363
# 2021-03-25 21:05:58,684 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 355
# 2021-03-25 21:05:58,688 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 209
# 2021-03-25 21:05:58,833 - aa_engine_pkg.assets.utils.utilities - INFO - size 23006
# 2021-03-25 21:05:58,836 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200518 and rate 0.9%
# 2021-03-25 21:05:58,841 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202005
# 2021-03-25 21:06:02,215 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200615
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202005 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:06:03,224 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 23835
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200810235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200518', 'yyyymmdd') and FECHA < to_date('20200713', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201011235900', 'yyyymmddhh24miss')
# 2021-03-25 21:06:05,756 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 313
# 2021-03-25 21:06:05,823 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 285
# 2021-03-25 21:06:05,841 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 276
# 2021-03-25 21:06:05,846 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 152
# 2021-03-25 21:06:05,989 - aa_engine_pkg.assets.utils.utilities - INFO - size 23835
# 2021-03-25 21:06:05,993 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200615 and rate 0.63%
# 2021-03-25 21:06:05,998 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202006
# 2021-03-25 21:06:09,548 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200713
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202006 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:06:14,093 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 24452
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200907235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200615', 'yyyymmdd') and FECHA < to_date('20200810', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201108235900', 'yyyymmddhh24miss')
# 2021-03-25 21:06:18,867 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 341
# 2021-03-25 21:06:18,936 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 311
# 2021-03-25 21:06:18,953 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 303
# 2021-03-25 21:06:18,958 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 127
# 2021-03-25 21:06:19,113 - aa_engine_pkg.assets.utils.utilities - INFO - size 24452
# 2021-03-25 21:06:19,117 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200713 and rate 0.51%
# 2021-03-25 21:06:19,121 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202007
# 2021-03-25 21:06:23,567 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200810
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202007 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:06:24,946 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 25305
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201005235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200713', 'yyyymmdd') and FECHA < to_date('20200907', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201206235900', 'yyyymmddhh24miss')
# 2021-03-25 21:06:28,141 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 398
# 2021-03-25 21:06:28,217 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 362
# 2021-03-25 21:06:28,235 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 356
# 2021-03-25 21:06:28,240 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 191
# 2021-03-25 21:06:28,398 - aa_engine_pkg.assets.utils.utilities - INFO - size 25305
# 2021-03-25 21:06:28,402 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200810 and rate 0.75%
# 2021-03-25 21:06:28,408 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202008
# 2021-03-25 21:06:32,890 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20200907
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202008 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:06:34,564 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 25826
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201102235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200810', 'yyyymmdd') and FECHA < to_date('20201005', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20210103235900', 'yyyymmddhh24miss')
# 2021-03-25 21:06:38,263 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 288
# 2021-03-25 21:06:38,338 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 267
# 2021-03-25 21:06:38,357 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 261
# 2021-03-25 21:06:38,362 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 150
# 2021-03-25 21:06:38,522 - aa_engine_pkg.assets.utils.utilities - INFO - size 25825
# 2021-03-25 21:06:38,527 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200907 and rate 0.58%
# 2021-03-25 21:06:38,532 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202009
# 2021-03-25 21:06:43,054 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20201005
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202009 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:06:44,427 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 26251
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20201005235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201130235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20200907', 'yyyymmdd') and FECHA < to_date('20201102', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20201005235900', 'yyyymmddhh24miss') and FECHA <= to_date('20210131235900', 'yyyymmddhh24miss')
# 2021-03-25 21:06:47,374 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 191
# 2021-03-25 21:06:47,452 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 181
# 2021-03-25 21:06:47,471 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 178
# 2021-03-25 21:06:47,475 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 99
# 2021-03-25 21:06:47,643 - aa_engine_pkg.assets.utils.utilities - INFO - size 26250
# 2021-03-25 21:06:47,648 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20201005 and rate 0.38%
# 2021-03-25 21:06:47,653 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202010
# 2021-03-25 21:06:52,554 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20201102
# select DATE_EXP, CUSTOMER_ID, PRC_CODIGO, PRODUCTO, PRC_TIPO_ID, TEC_ID, MOP, TENURE from stg_uy_eop_customer where DATE_EXP = 202010 and PRC_TIPO_ID = 3 AND PRC_CODIGO  IN (135, 216, 217, 147, 169)
# 2021-03-25 21:06:54,394 - aa_engine_pkg.assets.utils.utilities - INFO - EOP shape 27044
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20201102235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201228235900', 'yyyymmddhh24miss') and EVENTO_ID = 108 AND PRODUCTO_ID IN (135, 216, 217, 147, 169, 132, 139)
# select CUSTOMER_ID, PRODUCTO_ID, PRODUCTO, TRUNC(FECHA) FECHA_AGENDA from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID=100108 and FECHA >= to_date('20201005', 'yyyymmdd') and FECHA < to_date('20201130', 'yyyymmdd')
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID IN (107,108,133,142) and FECHA > to_date('20201102235900', 'yyyymmddhh24miss') and FECHA <= to_date('20210228235900', 'yyyymmddhh24miss')
# 2021-03-25 21:06:56,941 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades 213
# 2021-03-25 21:06:57,017 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after cancelation rule 198
# 2021-03-25 21:06:57,035 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after agenda rule 198
# 2021-03-25 21:06:57,040 - aa_engine_pkg.assets.utils.utilities - INFO -  Number of events 108 ending as upgrades after upgrades future rule 83
# 2021-03-25 21:06:57,197 - aa_engine_pkg.assets.utils.utilities - INFO - size 27043
# 2021-03-25 21:06:57,202 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20201102 and rate 0.31%
# 2021-03-25 21:06:57,207 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202010
# 2021-03-25 21:07:01,949 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20201130
# 2021-03-25 21:07:01,951 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20201130: Not enough future information
# 2021-03-25 21:07:01,951 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202011
# 2021-03-25 21:07:07,139 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20201228
# 2021-03-25 21:07:07,141 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20201228: Not enough future information
# 2021-03-25 21:07:07,142 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202012
# 2021-03-25 21:07:12,854 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20210125
# 2021-03-25 21:07:12,856 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20210125: Not enough future information
# 2021-03-25 21:07:12,857 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202101
# 2021-03-25 21:07:17,327 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20210222
# 2021-03-25 21:07:17,329 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20210222: Not enough future information
# 2021-03-25 21:07:17,330 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202102
# 2021-03-25 21:07:21,786 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20210322
# 2021-03-25 21:07:21,788 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20210322: Not enough future information
# 2021-03-25 21:07:21,789 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202103
# 2021-03-25 21:07:22,680 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20210419
# 2021-03-25 21:07:22,681 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20210419: Not enough future information
# 2021-03-25 21:07:22,682 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202104
# 2021-03-25 21:07:23,297 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20210517
# 2021-03-25 21:07:23,299 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20210517: Not enough future information
# 2021-03-25 21:07:23,299 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202105
# 2021-03-25 21:07:23,929 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20210614
# 2021-03-25 21:07:23,931 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20210614: Not enough future information
# 2021-03-25 21:07:23,931 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202106
# 2021-03-25 21:07:24,499 - aa_engine_pkg.assets.utils.utilities - INFO - Start the process of create upsell target for 20210712
# 2021-03-25 21:07:24,501 - aa_engine_pkg.assets.utils.utilities - INFO - Cannot create upsell target for 20210712: Not enough future information

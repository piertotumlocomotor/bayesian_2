# %% [markdown]
# ### Este notebook se uso para generar el target de xsell en Uruguay

# %%
# Load kedro environment (not needed in .py)
from pathlib import Path
from kedro.framework.context import load_context

# Load a context to be able to work in the notebook
#current_dir = Path.cwd()
current_dir = Path("/u01/share/cesar/aa_engine_uy/notebooks/")
proj_path = current_dir.parent
context = load_context(proj_path)
catalog = context.catalog
credentials = context.config_loader.get("credentials*","credentials*/**")
parameters = context.config_loader.get("parameters*","parameters*/**")

from aa_engine_pkg.assets.utils import *
from aa_engine_pkg.assets.core.data.kedro.catalog_expansion.partitioned_sql import SQLPartitionedDataSet

# %%
vars_to_string = ["PRODUCTO_ID",
                  "EVENTO_ID",
                  "PROD_CATEGORY_ID"]
vars_to_merge = ["CUSTOMER_ID", "FECHA"]

# %%
activaciones_premium=catalog.load('activaciones_premium')
reconexiones_basicos=catalog.load('reconexiones_basicos')
cancelaciones_premium=catalog.load('cancelaciones_premium')
cliente_activo=catalog.load("cliente_activo")
# Out:
# 2021-01-06 13:44:51,038 - kedro.io.data_catalog - INFO - Loading data from `activaciones_premium` (SQLPartitionedDataSet)...
# 2021-01-06 13:44:51,040 - kedro.io.data_catalog - INFO - Loading data from `reconexiones_basicos` (SQLPartitionedDataSet)...
# 2021-01-06 13:44:51,041 - kedro.io.data_catalog - INFO - Loading data from `cancelaciones_premium` (SQLPartitionedDataSet)...
# 2021-01-06 13:44:51,041 - kedro.io.data_catalog - INFO - Loading data from `cliente_activo` (SQLPartitionedDataSet)...

# %%
def create_cliente_activo(cliente_activo: SQLPartitionedDataSet,
                          date: str) -> pd.DataFrame:
    """Creates master table with features related to EoP state of customers for one period of data

    Parameters
    ----------
    cliente_activo:
        dataset defined in ´catalog.yml´ - list of active customers at EoP for the given period
    date:
        period to process
    
    Returns
    -------
        Mastertable with information of clientes at EoP
    """

    # Initialize logger
    log = initialize_logger()

    # Load active clientes for period
    log.info(f"Creating cliente_activo...")
    period_to_load = get_previous_month(date)
    df_clientes_activos = cliente_activo.filter_by(date=period_to_load)

    # Return
    return df_clientes_activos

# %%
def create_target_xsell(activaciones_premium: SQLPartitionedDataSet,
                        reconexiones_basicos: SQLPartitionedDataSet,
                        cancelaciones_premium: SQLPartitionedDataSet,
                        cliente_activo: pd.DataFrame,
                        parameters: Dict,
                        date: str) -> pd.DataFrame:
    
    """The following function will define the target variable for the xsell model of Premium products, considering:
    #### Products including:
        - FOX
        - HBO
        - Pack Adultos
    #### Target definition:
        - Existing customer acquires Premium product
        - Stays active for 3 or more months (end of discount price period)
    ---
    ## Target methodology
        1. Identify events 5229 (activation) and 171 (reconnection of product) related to product category 1 (Premium)
    and exclude products that are out of scope
        2. Identify events 171 (reconnection of product) related to category 3 (basic) products
        3. Exclude events from (1.) that happen on the same day as events on (2.) -> Reconnections of basic means churn
    involuntario
        4. Filter (get latest event) customers that have multiple events on the same product during the same period
        5. Check if product was canceled during the following 90 days
        6. Create target: "customer buys any premium product"
        7. Create target_product: "customer buys this product"
    Parameters
    ----------
    activaciones_premium:
        dataset defined in ``catalog_raw.yml`` with raw data information related to new activations of the set of
        Premium products defined above
    reconexiones_basicos:
        dataset defined in ``catalog_raw.yml`` with raw data information related to reconnections of programming
        services after a disconnection due to payment defaults
    cancelaciones_premium:
        dataset defined in ``catalog_raw.yml`` with raw data information related to product cancelations of the set of
        Premium products defined above
    cliente_activo:
        pandas dataframe with active customers for period
    date:
        period to process
    parameters:
        set of project parameters defined in ``parameters.yml``
    Returns
    -------
    pd.DataFrame
        pandas dataframe with xsell target for period
    """

    # Initialize logger
    log = initialize_logger()

    table_name = "target_xsell"
    write_to_parquet = parameters["write_to_parquet"]
    overwrite = parameters["targets"][table_name]["overwrite"]
    end_date = str(parameters["end_date"])

    # Check if target can be created (date + max window < end_date)
    target_parameters = parameters["targets"][table_name]
    max_window = max([target_parameters[x] for x in target_parameters.keys() if x.endswith("window")])
    upper_bound = (pd.to_datetime(date) + timedelta(days=max_window)).strftime("%Y%m%d")
    previous_sunday = dt.today() - timedelta(days=dt.today().weekday()+1)
    
    if pd.to_datetime(upper_bound, format="%Y%m%d") > previous_sunday:
        log.info(f"Cannot create xsell target for {date}: Not enough future information")
        return None

    # Compare with what is already processed
    path = f"{parameters['paths']['target_path']}{table_name}/"
    os.makedirs(path, exist_ok=True)
    processed_dates = os.listdir(path)
    match = [file for file in processed_dates if str(date) in file]

    if len(match) > 0 and overwrite is False:
        # If table is found, read parquet:
        log.info(f"Reading {match[0]} table")
        target = pd.read_parquet(path + match[0], engine="pyarrow")

    else:
        start_date = date
        end_date = (pd.to_datetime(date) + timedelta(
            days=parameters["targets"][table_name]["calculation_window"])).strftime("%Y%m%d")
        cancel_end_date = (pd.to_datetime(date) + timedelta(
            days=parameters["targets"][table_name]["activation_window"])).strftime("%Y%m%d")

        # Load data for required period
        df_activaciones = activaciones_premium.filter_by(date=[start_date,
                                                               end_date], target=True)
        log.info(f"Read {df_activaciones.shape[0]} activations")
        df_reconexiones = reconexiones_basicos.filter_by(date=[start_date,
                                                               end_date], target=True)
        log.info(f"Read {df_reconexiones.shape[0]} reconnections")
        df_cancelaciones = cancelaciones_premium.filter_by(date=[start_date,
                                                                 cancel_end_date], target=True)
        log.info(f"Read {df_cancelaciones.shape[0]} cancelations")

        # get EoP active clients from previous period to exclude new clients
        prev_period = get_previous_month(start_date)
        df_clientes = cliente_activo

        log.info(f"Read {df_clientes.shape[0]} clients")

        df_activaciones[vars_to_string] = df_activaciones[vars_to_string].astype(str)
        df_reconexiones[vars_to_string] = df_reconexiones[vars_to_string].astype(str)
        df_cancelaciones[vars_to_string] = df_cancelaciones[vars_to_string].astype(str)

        df_activaciones["FECHA"] = df_activaciones["FECHA"].dt.normalize()
        df_reconexiones["FECHA"] = df_reconexiones["FECHA"].dt.normalize()

        if pd.to_datetime(cancel_end_date) > pd.to_datetime(end_date):
            df_cancelaciones["FECHA"] = df_cancelaciones["FECHA"].dt.normalize()

        # 1. Calculate premium product activations in current period
        # merge and keep outer join
        cp_xsells_multi = pd.merge(df_activaciones,
                                   df_reconexiones,
                                   on=vars_to_merge,
                                   how="left"
                                   )

        # keep only customer that are not in both
        cp_xsells_multi["FLAG_ACTIVATION_PREMIUM"] = np.where(cp_xsells_multi["DATE_EXP_y"].isna(), 1, 0)
        cp_xsells_multi = cp_xsells_multi[cp_xsells_multi["FLAG_ACTIVATION_PREMIUM"] == 1]
        cp_xsells_multi = drop_extra_rename_remaining(cp_xsells_multi,
                                                      suffix_extra="_y",
                                                      suffix_remaining="_x",
                                                      suffix_new_name=""
                                                      )

        # keep only last event of xsell in period of interest
        df_cp_xsells = cp_xsells_multi.sort_values(["CUSTOMER_ID", "PRODUCTO_ID", "FECHA"]
                                                   ).drop_duplicates(subset=["CUSTOMER_ID", "PRODUCTO_ID"],
                                                                     keep="last")
        if pd.to_datetime(cancel_end_date) > pd.to_datetime(end_date):
            df_cp_xsells_cancels = pd.merge(df_cp_xsells,
                                            df_cancelaciones,
                                            on=["CUSTOMER_ID", "PRODUCTO_ID"],
                                            how="left",
                                            validate="1:m"
                                            )

            # check time difference between xsell and product cancelation
            df_cp_xsells_cancels["FECHA_DIFF"] = (df_cp_xsells_cancels["FECHA_y"] - df_cp_xsells_cancels[
                "FECHA_x"]) / np.timedelta64(1, "D")
            df_cp_xsells_cancels = drop_extra_rename_remaining(df_cp_xsells_cancels,
                                                               suffix_extra="_y",
                                                               suffix_remaining="_x",
                                                               suffix_new_name=""
                                                               )
            mask_cancels_before_buying = (df_cp_xsells_cancels["FECHA_DIFF"] < 0)
            mask_cancels_before_activation_window = (df_cp_xsells_cancels["FECHA_DIFF"] >= 0) & \
                                                    (df_cp_xsells_cancels["FECHA_DIFF"] <=
                                                     parameters["targets"]["target_xsell"]["activation_window"])
            df_cp_xsells_cancels["TARGET"] = np.where(
                mask_cancels_before_buying | mask_cancels_before_activation_window, 0, 1)
        else:
            df_cp_xsells_cancels = df_cp_xsells.copy()
            df_cp_xsells_cancels["TARGET"] = np.where(df_cp_xsells_cancels["FLAG_ACTIVATION_PREMIUM"] == 1, 1, 0)

        # group target products into super category (fox, hbo, adultos) to create target variable
        cp_xsells_final = df_cp_xsells_cancels.loc[df_cp_xsells_cancels["TARGET"] == 1, \
                                                   ["CUSTOMER_ID", "PRODUCTO_ID", "PRODUCTO", "TARGET", "FECHA"]]
        condlist = [cp_xsells_final["PRODUCTO_ID"].isin(parameters["targets"][table_name]["xsell_products"]["fox"]),
                    cp_xsells_final["PRODUCTO_ID"].isin(parameters["targets"][table_name]["xsell_products"]["hbo"]),
                    cp_xsells_final["PRODUCTO_ID"].isin(parameters["targets"][table_name]["xsell_products"]["adultos"])]

        # Impute product
        choicelist = ["FOX", "HBO", "ADULTOS"]
        cp_xsells_final["TARGET_PRODUCT"] = np.select(condlist, choicelist, default="error")

        agg_dict = {"TARGET": "max",
                    "FECHA": "max",
                    "PRODUCTO_ID": "max"}
        cp_xsells_final = cp_xsells_final.groupby(["CUSTOMER_ID", "TARGET_PRODUCT"]).agg(agg_dict).reset_index()

        target = pd.merge(df_clientes,
                          cp_xsells_final,
                          on="CUSTOMER_ID",
                          how="outer",
                          validate="1:m",
                          indicator=True)

        target["DATE_EXP"] = prev_period
        target["TARGET"].fillna(0, inplace=True)
        target["TARGET_PRODUCT"].fillna("NO_COMPRA", inplace=True)
        target["PRODUCTO_ID"].fillna("NO_COMPRA", inplace=True)
        target["TARGET"] = target["TARGET"].astype(np.int32)
        target.rename({"FECHA": "FECHA_TARGET"}, inplace=True)
        target["DATE_CALC"] = date

        if write_to_parquet:
            file = f"{parameters['paths']['target_path']}{table_name}/{table_name}_{date}.parquet"
            target.to_parquet(file, engine="pyarrow")

        # Return
        log.info(
            f"""Exporting target for period {start_date} and rate {
            np.round(100 * target[target['TARGET'] == 1]['CUSTOMER_ID'].nunique() / target['CUSTOMER_ID'].nunique(), 2)
            }%""")

    return target

# %%
dates=calculate_dates_to_process_for_target(parameters,'target_xsell')

# %%
for date in dates:
    cliente_activo_df= create_cliente_activo(cliente_activo,date)
    create_target_xsell(activaciones_premium,
                        reconexiones_basicos,
                        cancelaciones_premium,
                        cliente_activo_df,
                        parameters,
                        date)
# Out:
# 2021-01-06 13:47:09,609 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20181231235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:14,070 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4335 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20181231235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:14,318 - aa_engine_pkg.assets.utils.utilities - INFO - Read 921 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20181203235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190325235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:14,747 - aa_engine_pkg.assets.utils.utilities - INFO - Read 10540 cancelations
# 2021-01-06 13:47:14,749 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116634 clients
# 2021-01-06 13:47:15,279 - numexpr.utils - INFO - Note: NumExpr detected 32 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-01-06 13:47:15,280 - numexpr.utils - INFO - NumExpr defaulting to 8 threads.
# 2021-01-06 13:47:15,527 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181203 and rate 2.09%
# 2021-01-06 13:47:15,534 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201811
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190128235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:17,721 - aa_engine_pkg.assets.utils.utilities - INFO - Read 3887 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190128235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:18,002 - aa_engine_pkg.assets.utils.utilities - INFO - Read 827 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20181231235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190422235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:18,491 - aa_engine_pkg.assets.utils.utilities - INFO - Read 14034 cancelations
# 2021-01-06 13:47:18,492 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116634 clients
# 2021-01-06 13:47:19,202 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20181231 and rate 1.68%
# 2021-01-06 13:47:19,210 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201812
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190225235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:22,341 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4536 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190225235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:22,609 - aa_engine_pkg.assets.utils.utilities - INFO - Read 759 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190128235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190520235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:23,415 - aa_engine_pkg.assets.utils.utilities - INFO - Read 14098 cancelations
# 2021-01-06 13:47:23,416 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116984 clients
# 2021-01-06 13:47:24,180 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190128 and rate 1.99%
# 2021-01-06 13:47:24,188 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201901
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190325235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:28,807 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4959 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190325235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:29,053 - aa_engine_pkg.assets.utils.utilities - INFO - Read 846 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190225235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190617235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:29,596 - aa_engine_pkg.assets.utils.utilities - INFO - Read 15031 cancelations
# 2021-01-06 13:47:29,598 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116342 clients
# 2021-01-06 13:47:30,420 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190225 and rate 2.19%
# 2021-01-06 13:47:30,428 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201902
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190422235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:34,941 - aa_engine_pkg.assets.utils.utilities - INFO - Read 5864 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190422235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:35,190 - aa_engine_pkg.assets.utils.utilities - INFO - Read 867 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190325235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190715235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:35,773 - aa_engine_pkg.assets.utils.utilities - INFO - Read 16415 cancelations
# 2021-01-06 13:47:35,775 - aa_engine_pkg.assets.utils.utilities - INFO - Read 115807 clients
# 2021-01-06 13:47:36,650 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190325 and rate 2.5%
# 2021-01-06 13:47:36,658 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201903
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190520235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:40,884 - aa_engine_pkg.assets.utils.utilities - INFO - Read 5310 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190520235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:41,337 - aa_engine_pkg.assets.utils.utilities - INFO - Read 735 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190422235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190812235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:42,024 - aa_engine_pkg.assets.utils.utilities - INFO - Read 16863 cancelations
# 2021-01-06 13:47:42,025 - aa_engine_pkg.assets.utils.utilities - INFO - Read 115524 clients
# 2021-01-06 13:47:42,853 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190422 and rate 2.26%
# 2021-01-06 13:47:42,861 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201904
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190617235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:46,820 - aa_engine_pkg.assets.utils.utilities - INFO - Read 6163 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190617235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:47,083 - aa_engine_pkg.assets.utils.utilities - INFO - Read 808 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190520235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190909235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:47,762 - aa_engine_pkg.assets.utils.utilities - INFO - Read 17972 cancelations
# 2021-01-06 13:47:47,764 - aa_engine_pkg.assets.utils.utilities - INFO - Read 115453 clients
# 2021-01-06 13:47:48,624 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190520 and rate 2.4%
# 2021-01-06 13:47:48,633 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201905
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190715235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:53,389 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4050 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190715235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:53,658 - aa_engine_pkg.assets.utils.utilities - INFO - Read 593 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190617235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191007235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:54,561 - aa_engine_pkg.assets.utils.utilities - INFO - Read 19137 cancelations
# 2021-01-06 13:47:54,562 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116233 clients
# 2021-01-06 13:47:55,277 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190617 and rate 1.66%
# 2021-01-06 13:47:55,284 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201906
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190812235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:58,210 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4400 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190812235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:58,450 - aa_engine_pkg.assets.utils.utilities - INFO - Read 415 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190715235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191104235900', 'yyyymmddhh24miss')
# 2021-01-06 13:47:59,409 - aa_engine_pkg.assets.utils.utilities - INFO - Read 18246 cancelations
# 2021-01-06 13:47:59,411 - aa_engine_pkg.assets.utils.utilities - INFO - Read 117318 clients
# 2021-01-06 13:48:00,152 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190715 and rate 1.44%
# 2021-01-06 13:48:00,159 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201907
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190909235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:04,147 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4215 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20190909235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:04,403 - aa_engine_pkg.assets.utils.utilities - INFO - Read 502 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190812235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191202235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:05,078 - aa_engine_pkg.assets.utils.utilities - INFO - Read 18022 cancelations
# 2021-01-06 13:48:05,079 - aa_engine_pkg.assets.utils.utilities - INFO - Read 117242 clients
# 2021-01-06 13:48:05,798 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190812 and rate 1.43%
# 2021-01-06 13:48:05,806 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201908
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191007235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:09,521 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4557 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191007235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:09,800 - aa_engine_pkg.assets.utils.utilities - INFO - Read 760 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20190909235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191230235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:10,594 - aa_engine_pkg.assets.utils.utilities - INFO - Read 14208 cancelations
# 2021-01-06 13:48:10,595 - aa_engine_pkg.assets.utils.utilities - INFO - Read 117172 clients
# 2021-01-06 13:48:11,357 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20190909 and rate 1.66%
# 2021-01-06 13:48:11,365 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201909
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191104235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:13,851 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4704 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191104235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:14,108 - aa_engine_pkg.assets.utils.utilities - INFO - Read 602 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191007235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200127235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:14,728 - aa_engine_pkg.assets.utils.utilities - INFO - Read 14164 cancelations
# 2021-01-06 13:48:14,730 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116912 clients
# 2021-01-06 13:48:15,496 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191007 and rate 1.69%
# 2021-01-06 13:48:15,505 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201910
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191202235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:18,394 - aa_engine_pkg.assets.utils.utilities - INFO - Read 5154 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191202235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:18,654 - aa_engine_pkg.assets.utils.utilities - INFO - Read 604 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191104235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200224235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:19,162 - aa_engine_pkg.assets.utils.utilities - INFO - Read 14291 cancelations
# 2021-01-06 13:48:19,164 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116800 clients
# 2021-01-06 13:48:19,964 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191104 and rate 1.85%
# 2021-01-06 13:48:19,972 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191230235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:23,017 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4311 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20191230235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:23,332 - aa_engine_pkg.assets.utils.utilities - INFO - Read 682 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191202235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200323235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:23,964 - aa_engine_pkg.assets.utils.utilities - INFO - Read 14883 cancelations
# 2021-01-06 13:48:23,966 - aa_engine_pkg.assets.utils.utilities - INFO - Read 117068 clients
# 2021-01-06 13:48:24,711 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191202 and rate 1.65%
# 2021-01-06 13:48:24,718 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201911
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200127235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:27,334 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4515 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200127235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:27,576 - aa_engine_pkg.assets.utils.utilities - INFO - Read 588 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20191230235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200420235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:28,510 - aa_engine_pkg.assets.utils.utilities - INFO - Read 19085 cancelations
# 2021-01-06 13:48:28,511 - aa_engine_pkg.assets.utils.utilities - INFO - Read 117068 clients
# 2021-01-06 13:48:29,286 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20191230 and rate 1.59%
# 2021-01-06 13:48:29,294 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 201912
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200224235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:31,765 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4537 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200224235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:32,265 - aa_engine_pkg.assets.utils.utilities - INFO - Read 777 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200127235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200518235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:32,860 - aa_engine_pkg.assets.utils.utilities - INFO - Read 18815 cancelations
# 2021-01-06 13:48:32,861 - aa_engine_pkg.assets.utils.utilities - INFO - Read 117163 clients
# 2021-01-06 13:48:33,635 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200127 and rate 1.61%
# 2021-01-06 13:48:33,645 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202001
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200323235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:38,942 - aa_engine_pkg.assets.utils.utilities - INFO - Read 5771 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200323235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:39,213 - aa_engine_pkg.assets.utils.utilities - INFO - Read 715 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200224235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200615235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:39,939 - aa_engine_pkg.assets.utils.utilities - INFO - Read 20263 cancelations
# 2021-01-06 13:48:39,941 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116774 clients
# 2021-01-06 13:48:40,839 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200224 and rate 2.03%
# 2021-01-06 13:48:40,848 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202002
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200420235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:46,577 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4619 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200420235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:46,806 - aa_engine_pkg.assets.utils.utilities - INFO - Read 568 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200323235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200713235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:47,880 - aa_engine_pkg.assets.utils.utilities - INFO - Read 21047 cancelations
# 2021-01-06 13:48:47,882 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116537 clients
# 2021-01-06 13:48:48,665 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200323 and rate 1.6%
# 2021-01-06 13:48:48,674 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202003
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200518235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:51,185 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4172 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200518235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:51,465 - aa_engine_pkg.assets.utils.utilities - INFO - Read 627 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200420235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200810235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:52,464 - aa_engine_pkg.assets.utils.utilities - INFO - Read 20878 cancelations
# 2021-01-06 13:48:52,465 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116439 clients
# 2021-01-06 13:48:53,181 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200420 and rate 1.34%
# 2021-01-06 13:48:53,189 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202004
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200615235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:56,231 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4418 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200615235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:56,474 - aa_engine_pkg.assets.utils.utilities - INFO - Read 608 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200518235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200907235900', 'yyyymmddhh24miss')
# 2021-01-06 13:48:57,578 - aa_engine_pkg.assets.utils.utilities - INFO - Read 22361 cancelations
# 2021-01-06 13:48:57,579 - aa_engine_pkg.assets.utils.utilities - INFO - Read 115856 clients
# 2021-01-06 13:48:58,311 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200518 and rate 1.37%
# 2021-01-06 13:48:58,320 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202005
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200713235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:01,844 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4511 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200713235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:02,125 - aa_engine_pkg.assets.utils.utilities - INFO - Read 825 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200615235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201005235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:02,911 - aa_engine_pkg.assets.utils.utilities - INFO - Read 23106 cancelations
# 2021-01-06 13:49:02,913 - aa_engine_pkg.assets.utils.utilities - INFO - Read 115755 clients
# 2021-01-06 13:49:03,633 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200615 and rate 1.38%
# 2021-01-06 13:49:03,642 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202006
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200810235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:08,320 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4472 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200810235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:09,066 - aa_engine_pkg.assets.utils.utilities - INFO - Read 628 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200713235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201102235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:10,181 - aa_engine_pkg.assets.utils.utilities - INFO - Read 22680 cancelations
# 2021-01-06 13:49:10,183 - aa_engine_pkg.assets.utils.utilities - INFO - Read 115886 clients
# 2021-01-06 13:49:10,911 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200713 and rate 1.42%
# 2021-01-06 13:49:10,921 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202007
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200907235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:15,220 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4056 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20200907235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:15,504 - aa_engine_pkg.assets.utils.utilities - INFO - Read 696 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200810235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201130235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:16,684 - aa_engine_pkg.assets.utils.utilities - INFO - Read 18771 cancelations
# 2021-01-06 13:49:16,686 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116188 clients
# 2021-01-06 13:49:17,394 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200810 and rate 1.35%
# 2021-01-06 13:49:17,402 - aa_engine_pkg.assets.utils.utilities - INFO - Creating cliente_activo...
# select distinct CUSTOMER_ID from stg_uy_customer_status where UPPER(STATUS) LIKE '%ACTIVO%' and DATE_EXP = 202008
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID IN (5229,171) and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201005235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:22,042 - aa_engine_pkg.assets.utils.utilities - INFO - Read 4083 activations
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 3 and EVENTO_ID = 171 and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201005235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:22,314 - aa_engine_pkg.assets.utils.utilities - INFO - Read 698 reconnections
# select * from stg_uy_plan_evento where PROD_CATEGORY_ID = 1 and EVENTO_ID = 142 and PRODUCTO_ID IN (130,129,28,31,138,158) and FECHA > to_date('20200907235900', 'yyyymmddhh24miss') and FECHA <= to_date('20201228235900', 'yyyymmddhh24miss')
# 2021-01-06 13:49:23,183 - aa_engine_pkg.assets.utils.utilities - INFO - Read 17410 cancelations
# 2021-01-06 13:49:23,185 - aa_engine_pkg.assets.utils.utilities - INFO - Read 116749 clients
# 2021-01-06 13:49:23,899 - aa_engine_pkg.assets.utils.utilities - INFO - Exporting target for period 20200907 and rate 1.38%
